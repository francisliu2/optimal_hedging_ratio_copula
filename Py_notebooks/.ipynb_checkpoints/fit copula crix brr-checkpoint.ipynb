# %%
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.distributions.empirical_distribution import ECDF
from copulae1 import *
from KDEs import *
from toolbox import *
import warnings
import itertools
import os

warnings.filterwarnings("ignore")

data = pd.read_csv('../processed_data/btc_future_crix.csv')
data.head()

ecdf_brr = ECDF(data.return_brr)
ecdf_btc = ECDF(data.return_btc)

u = ecdf_brr(data.return_brr)
v = ecdf_btc(data.return_btc)

brr = np.array(data.return_brr)
btc = np.array(data.return_btc)

kde_brr = KDE(data.return_brr, "Gaussian")
kde_btc = KDE(data.return_btc, "Gaussian")

kde_brr = KDE(data.return_brr, "Gaussian", kde_brr.h_brot*3)
kde_btc = KDE(data.return_brr, "Gaussian", kde_btc.h_brot*3)

# %%
# Gaussian, t_Copula, Clayton, Frank, Gumbel, Plackett, Gaussian mix Indep
C1  = Gaussian(dict(rho=0.9),       Law_RS=kde_brr, Law_RF=kde_btc) # fix the maringals!
C2  = t_Copula(dict(rho=0.1, nu=4), Law_RS=kde_brr, Law_RF=kde_btc, nu_lowerbound=2) 
C2c = t_Copula(dict(rho=0.1, nu=4), Law_RS=kde_brr, Law_RF=kde_btc, nu_lowerbound=4) 
C3  = Clayton(dict(theta=0.1),      Law_RS=kde_brr, Law_RF=kde_btc)
C4  = Frank(dict(theta=0.1),        Law_RS=kde_brr, Law_RF=kde_btc)
C5  = Gumbel(dict(theta=3),         Law_RS=kde_brr, Law_RF=kde_btc)
C6  = Plackett(dict(theta=10),      Law_RS=kde_brr, Law_RF=kde_btc)
C7  = Gaussian_Mix_Independent(dict(rho=.9,p=0.7),Law_RS=kde_brr, Law_RF=kde_btc)
Copulae_names = ['Gaussian', 't_Copula', 't_Copula_Capped', 'Clayton', 'Frank', 'Gumbel', 'Plackett', 'Gauss Mix Indep']
Copulae_arr   = [C1,C2,C2c,C3,C4,C5,C6,C7]
Copulae = dict(zip(Copulae_names, Copulae_arr))

# %%
results = []
ls = os.listdir('../processed_data/future_brr_v2/train/')
ls = [l for l in ls if l.endswith('.csv')]
for file in ls:
    print(file)
    train = pd.read_csv('../processed_data/future_brr_v2/train/'+file)
    btc = train.loc[:,'log return future']
    brr = train.loc[:,'log return brr']
    u = ECDF(brr)(brr)
    v = ECDF(btc)(btc)
    plt.scatter(u,v)
    paras = []
    likelihood = []
    for C_name in Copulae:
        Copulae[C_name].canonical_calibrate(u,v)
        print(C_name,'is done.\n')
    
    for C_name in Copulae:
        paras.append((C_name,Copulae[C_name].paras))
        
    for C_name in Copulae:
        ln = Copulae[C_name].dependency_likelihood(u,v)
        likelihood.append((C_name,ln))
        
    results.append([paras, likelihood])
# Out:
# 6.csv
# Optimization terminated successfully.
#          Current function value: -0.383775
#          Iterations: 33
#          Function evaluations: 70
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.464242
#          Iterations: 107
#          Function evaluations: 222
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.453317
#          Iterations: 161
#          Function evaluations: 308
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.333959
#          Iterations: 44
#          Function evaluations: 94
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.402138
#          Iterations: 46
#          Function evaluations: 97
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.419431
#          Iterations: 36
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.467222
#          Iterations: 42
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.470476
#          Iterations: 63
#          Function evaluations: 136
# Gauss Mix Indep is done.
#
# 7.csv
# Optimization terminated successfully.
#          Current function value: -0.376550
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.466319
#          Iterations: 136
#          Function evaluations: 261
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.450987
#          Iterations: 119
#          Function evaluations: 237
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.319773
#          Iterations: 33
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.394714
#          Iterations: 33
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.421819
#          Iterations: 32
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.467551
#          Iterations: 35
#          Function evaluations: 81
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.474950
#          Iterations: 63
#          Function evaluations: 130
# Gauss Mix Indep is done.
#
# 5.csv
# Optimization terminated successfully.
#          Current function value: -0.407042
#          Iterations: 30
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.490921
#          Iterations: 63
#          Function evaluations: 138
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.477560
#          Iterations: 140
#          Function evaluations: 265
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.379556
#          Iterations: 34
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.408476
#          Iterations: 33
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.429469
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.474608
#          Iterations: 35
#          Function evaluations: 78
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.491273
#          Iterations: 68
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# 4.csv
# Optimization terminated successfully.
#          Current function value: -0.420753
#          Iterations: 30
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.502478
#          Iterations: 70
#          Function evaluations: 146
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.490501
#          Iterations: 124
#          Function evaluations: 249
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.389706
#          Iterations: 32
#          Function evaluations: 68
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.422145
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.441533
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.485110
#          Iterations: 35
#          Function evaluations: 80
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.499361
#          Iterations: 60
#          Function evaluations: 128
# Gauss Mix Indep is done.
#
# 0.csv
# Optimization terminated successfully.
#          Current function value: -0.433807
#          Iterations: 31
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.486288
#          Iterations: 74
#          Function evaluations: 161
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.482994
#          Iterations: 126
#          Function evaluations: 252
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.421352
#          Iterations: 32
#          Function evaluations: 69
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.429739
#          Iterations: 33
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.420707
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.468415
#          Iterations: 39
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.478617
#          Iterations: 66
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# 1.csv
# Optimization terminated successfully.
#          Current function value: -0.425856
#          Iterations: 31
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.470180
#          Iterations: 65
#          Function evaluations: 149
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.407092
#          Iterations: 32
#          Function evaluations: 70
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.419158
#          Iterations: 33
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.406259
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.453257
#          Iterations: 36
#          Function evaluations: 82
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.460797
#          Iterations: 60
#          Function evaluations: 128
# Gauss Mix Indep is done.
#
# 3.csv
# Optimization terminated successfully.
#          Current function value: -0.430989
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.491405
#          Iterations: 83
#          Function evaluations: 174
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.486991
#          Iterations: 131
#          Function evaluations: 252
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.409907
#          Iterations: 31
#          Function evaluations: 68
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.436686
#          Iterations: 33
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.429851
#          Iterations: 31
#          Function evaluations: 67
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.486122
#          Iterations: 39
#          Function evaluations: 90
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: -0.491632
#          Iterations: 64
#          Function evaluations: 140
# Gauss Mix Indep is done.
#
# 2.csv
# Optimization terminated successfully.
#          Current function value: -0.375434
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.431402
#          Iterations: 70
#          Function evaluations: 151
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.427170
#          Iterations: 133
#          Function evaluations: 260
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.370792
#          Iterations: 32
#          Function evaluations: 71
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.385088
#          Iterations: 35
#          Function evaluations: 77
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.362979
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.426397
#          Iterations: 39
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.427504
#          Iterations: 67
#          Function evaluations: 137
# Gauss Mix Indep is done.
#
# 18.csv
# Optimization terminated successfully.
#          Current function value: -0.398460
#          Iterations: 31
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.460886
#          Iterations: 74
#          Function evaluations: 160
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.451136
#          Iterations: 128
#          Function evaluations: 240
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.382851
#          Iterations: 32
#          Function evaluations: 69
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.375975
#          Iterations: 34
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.423546
#          Iterations: 31
#          Function evaluations: 66
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.436202
#          Iterations: 35
#          Function evaluations: 78
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.473289
#          Iterations: 64
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# 16.csv
# Optimization terminated successfully.
#          Current function value: -0.372590
#          Iterations: 32
#          Function evaluations: 69
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.447315
#          Iterations: 130
#          Function evaluations: 245
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.383198
#          Iterations: 32
#          Function evaluations: 71
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.354650
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.409510
#          Iterations: 32
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.438812
#          Iterations: 37
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.497786
#          Iterations: 63
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# 17.csv
# Optimization terminated successfully.
#          Current function value: -0.418252
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.519823
#          Iterations: 134
#          Function evaluations: 250
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.494434
#          Iterations: 126
#          Function evaluations: 243
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.419540
#          Iterations: 32
#          Function evaluations: 69
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.392190
#          Iterations: 33
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.456559
#          Iterations: 31
#          Function evaluations: 66
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.477379
#          Iterations: 37
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.538427
#          Iterations: 64
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# 15.csv
# Optimization terminated successfully.
#          Current function value: -0.385865
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.537553
#          Iterations: 142
#          Function evaluations: 263
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.492810
#          Iterations: 120
#          Function evaluations: 240
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.386084
#          Iterations: 33
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.364463
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.460599
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.472929
#          Iterations: 37
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.577929
#          Iterations: 66
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# 14.csv
# Optimization terminated successfully.
#          Current function value: -0.453052
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.604572
#          Iterations: 102
#          Function evaluations: 196
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.566874
#          Iterations: 126
#          Function evaluations: 252
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.415666
#          Iterations: 32
#          Function evaluations: 70
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.434935
#          Iterations: 36
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.547069
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.552926
#          Iterations: 41
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.631645
#          Iterations: 64
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# 10.csv
# Optimization terminated successfully.
#          Current function value: -0.362469
#          Iterations: 31
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.455575
#          Iterations: 123
#          Function evaluations: 243
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.435379
#          Iterations: 129
#          Function evaluations: 247
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.292407
#          Iterations: 35
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.367180
#          Iterations: 36
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.417641
#          Iterations: 34
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.446105
#          Iterations: 40
#          Function evaluations: 89
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: -0.469019
#          Iterations: 66
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# 11.csv
# Optimization terminated successfully.
#          Current function value: -0.368478
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.488943
#          Iterations: 127
#          Function evaluations: 243
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.459549
#          Iterations: 146
#          Function evaluations: 277
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.291008
#          Iterations: 31
#          Function evaluations: 70
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.370948
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.469016
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.471949
#          Iterations: 38
#          Function evaluations: 86
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.533633
#          Iterations: 60
#          Function evaluations: 128
# Gauss Mix Indep is done.
#
# 13.csv
# Optimization terminated successfully.
#          Current function value: -0.389821
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.538246
#          Iterations: 165
#          Function evaluations: 316
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.501471
#          Iterations: 119
#          Function evaluations: 229
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.346624
#          Iterations: 33
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.390794
#          Iterations: 33
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.485797
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.509672
#          Iterations: 40
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.583976
#          Iterations: 67
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# 12.csv
# Optimization terminated successfully.
#          Current function value: -0.395864
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.535864
#          Iterations: 130
#          Function evaluations: 243
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.502202
#          Iterations: 115
#          Function evaluations: 227
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.343359
#          Iterations: 31
#          Function evaluations: 66
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.397262
#          Iterations: 33
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.491167
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.512306
#          Iterations: 35
#          Function evaluations: 82
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.576269
#          Iterations: 61
#          Function evaluations: 133
# Gauss Mix Indep is done.
#
# 9.csv
# Optimization terminated successfully.
#          Current function value: -0.373607
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.447796
#          Iterations: 130
#          Function evaluations: 238
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.435449
#          Iterations: 124
#          Function evaluations: 247
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.299553
#          Iterations: 36
#          Function evaluations: 78
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.375265
#          Iterations: 34
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.420430
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.440398
#          Iterations: 40
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.450440
#          Iterations: 68
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# 8.csv
# Optimization terminated successfully.
#          Current function value: -0.350305
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.427504
#          Iterations: 132
#          Function evaluations: 253
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.413588
#          Iterations: 128
#          Function evaluations: 245
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.289206
#          Iterations: 32
#          Function evaluations: 68
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.348385
#          Iterations: 34
#          Function evaluations: 76
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.396657
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.410647
#          Iterations: 37
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.428357
#          Iterations: 63
#          Function evaluations: 130
# Gauss Mix Indep is done.

# %%
c_arr = []
date_range_arr = []
for i, file in enumerate(ls):
    train = pd.read_csv('../processed_data/future_brr_v2/train/'+file)
    a = pd.DataFrame(results[i][0])
    a.columns = ['Copula_name', 'paras']
    a.index = a.iloc[:,0]
    b = pd.DataFrame(results[i][1])
    b.index = b.iloc[:,0]
    c = pd.concat([a.iloc[:,1],b.iloc[:,1]],axis=1)
    c.columns = ['paras', 'likelihood']
    date_range = train.Date.iloc[-1] +' to ' + train.Date.iloc[0]
    date_range_arr.append(date_range)
    print(date_range)
    c_arr.append(c)
# Out:
# 2019-03-01 to 2020-02-28
# 2019-02-01 to 2020-01-31
# 2019-04-01 to 2020-03-31
# 2019-05-01 to 2020-04-30
# 2019-09-03 to 2020-08-31
# 2019-08-01 to 2020-07-31
# 2019-06-03 to 2020-05-29
# 2019-07-01 to 2020-06-30
# 2018-03-01 to 2019-02-28
# 2018-05-01 to 2019-04-30
# 2018-04-02 to 2019-03-29
# 2018-06-01 to 2019-05-31
# 2018-07-02 to 2019-06-28
# 2018-11-01 to 2019-10-31
# 2018-10-01 to 2019-09-30
# 2018-08-01 to 2019-07-31
# 2018-09-04 to 2019-08-30
# 2018-12-03 to 2019-11-29
# 2019-01-02 to 2019-12-31

# %%
result = pd.concat(dict(zip(date_range_arr, c_arr)), axis=1)

# %%
result.iloc[:,[i for i in range(len(result.columns)) if i%2!=0]].style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_eb032408_666e_11eb_9956_acde48001122row1_col0 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col1 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col9 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col10 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col13 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col14 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col15 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col16 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row1_col18 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row2_col17 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col2 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col3 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col4 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col5 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col6 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col7 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col8 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col11 {
#             background-color:  lightgreen;
#         }    #T_eb032408_666e_11eb_9956_acde48001122row7_col12 {
#             background-color:  lightgreen;
#         }</style><table id="T_eb032408_666e_11eb_9956_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2018-03-01 to 2019-02-28</th>        <th class="col_heading level0 col1" >2018-04-02 to 2019-03-29</th>        <th class="col_heading level0 col2" >2018-05-01 to 2019-04-30</th>        <th class="col_heading level0 col3" >2018-06-01 to 2019-05-31</th>        <th class="col_heading level0 col4" >2018-07-02 to 2019-06-28</th>        <th class="col_heading level0 col5" >2018-08-01 to 2019-07-31</th>        <th class="col_heading level0 col6" >2018-09-04 to 2019-08-30</th>        <th class="col_heading level0 col7" >2018-10-01 to 2019-09-30</th>        <th class="col_heading level0 col8" >2018-11-01 to 2019-10-31</th>        <th class="col_heading level0 col9" >2018-12-03 to 2019-11-29</th>        <th class="col_heading level0 col10" >2019-01-02 to 2019-12-31</th>        <th class="col_heading level0 col11" >2019-02-01 to 2020-01-31</th>        <th class="col_heading level0 col12" >2019-03-01 to 2020-02-28</th>        <th class="col_heading level0 col13" >2019-04-01 to 2020-03-31</th>        <th class="col_heading level0 col14" >2019-05-01 to 2020-04-30</th>        <th class="col_heading level0 col15" >2019-06-03 to 2020-05-29</th>        <th class="col_heading level0 col16" >2019-07-01 to 2020-06-30</th>        <th class="col_heading level0 col17" >2019-08-01 to 2020-07-31</th>        <th class="col_heading level0 col18" >2019-09-03 to 2020-08-31</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >likelihood</th>        <th class="col_heading level1 col1" >likelihood</th>        <th class="col_heading level1 col2" >likelihood</th>        <th class="col_heading level1 col3" >likelihood</th>        <th class="col_heading level1 col4" >likelihood</th>        <th class="col_heading level1 col5" >likelihood</th>        <th class="col_heading level1 col6" >likelihood</th>        <th class="col_heading level1 col7" >likelihood</th>        <th class="col_heading level1 col8" >likelihood</th>        <th class="col_heading level1 col9" >likelihood</th>        <th class="col_heading level1 col10" >likelihood</th>        <th class="col_heading level1 col11" >likelihood</th>        <th class="col_heading level1 col12" >likelihood</th>        <th class="col_heading level1 col13" >likelihood</th>        <th class="col_heading level1 col14" >likelihood</th>        <th class="col_heading level1 col15" >likelihood</th>        <th class="col_heading level1 col16" >likelihood</th>        <th class="col_heading level1 col17" >likelihood</th>        <th class="col_heading level1 col18" >likelihood</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb032408_666e_11eb_9956_acde48001122level0_row0" class="row_heading level0 row0" >Gaussian</th>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col0" class="data row0 col0" >0.417644</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col1" class="data row0 col1" >0.437603</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col2" class="data row0 col2" >0.400458</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col3" class="data row0 col3" >0.404937</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col4" class="data row0 col4" >0.472737</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col5" class="data row0 col5" >0.408929</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col6" class="data row0 col6" >0.41509</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col7" class="data row0 col7" >0.387387</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col8" class="data row0 col8" >0.379347</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col9" class="data row0 col9" >0.390892</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col10" class="data row0 col10" >0.368464</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col11" class="data row0 col11" >0.39435</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col12" class="data row0 col12" >0.402113</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col13" class="data row0 col13" >0.424306</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col14" class="data row0 col14" >0.437106</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col15" class="data row0 col15" >0.447862</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col16" class="data row0 col16" >0.390134</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col17" class="data row0 col17" >0.439427</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row0_col18" class="data row0 col18" >0.449524</td>
#             </tr>
#             <tr>
#                         <th id="T_eb032408_666e_11eb_9956_acde48001122level0_row1" class="row_heading level0 row1" >t_Copula</th>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row1_col0" class="data row1 col0" >0.486086</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row1_col1" class="data row1 col1" >0.545291</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row1_col2" class="data row1 col2" >0.494622</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row1_col3" class="data row1 col3" >0.563125</td>
#                         <td id="T_eb032408_666e_11eb_9956_acde48001122row1_col4" class="data row1 col4"

# %%
result.iloc[:,[i for i in range(len(result.columns)) if i%2==0]]
# Out:
#                                           2018-03-01 to 2019-02-28  \
#                                                              paras
# Gaussian                               {'rho': 0.7491536715871145}
# t_Copula         {'rho': 0.7514883691608529, 'nu': 2.0757151464...
# t_Copula_Capped  {'rho': 0.7746109915401356, 'nu': 4.0000000000...
# Clayton                                {'theta': 1.92318636558286}
# Frank                                 {'theta': 6.641118265436119}
# Gumbel                                {'theta': 2.150152424883355}
# Plackett                              {'theta': 18.57774046771413}
# Gauss Mix Indep  {'rho': 0.927132744763395, 'p': 0.693889357542...
#
#                                           2018-04-02 to 2019-03-29  \
#                                                              paras
# Gaussian                               {'rho': 0.7605905707404985}
# t_Copula         {'rho': 0.7845351457500187, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.8006603872221913, 'nu': 4.0000000000...
# Clayton                               {'theta': 2.132990255037317}
# Frank                                 {'theta': 6.926624404387351}
# Gumbel                               {'theta': 2.2494264854783568}
# Plackett                               {'theta': 22.7747447741015}
# Gauss Mix Indep  {'rho': 0.9508866013693656, 'p': 0.66829232629...
#
#                                           2018-05-01 to 2019-04-30  \
#                                                              paras
# Gaussian                               {'rho': 0.7386496953824873}
# t_Copula         {'rho': 0.7657013571896782, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.7816341712872453, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.9620191789810393}
# Frank                                 {'theta': 6.453769652526516}
# Gumbel                                {'theta': 2.122796563089813}
# Plackett                             {'theta': 20.456677610980893}
# Gauss Mix Indep  {'rho': 0.9417120412339, 'p': 0.6702329898406745}
#
#                                           2018-06-01 to 2019-05-31  \
#                                                              paras
# Gaussian                               {'rho': 0.7415624950616582}
# t_Copula         {'rho': 0.7980379856112296, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.8006603872221913, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.9949172695194777}
# Frank                                 {'theta': 6.659695215431711}
# Gumbel                               {'theta': 2.2779720868754723}
# Plackett                             {'theta': 24.321710086888658}
# Gauss Mix Indep  {'rho': 0.9625038355379024, 'p': 0.64877937604...
#
#                                           2018-07-02 to 2019-06-28  \
#                                                              paras
# Gaussian                               {'rho': 0.7792556259806482}
# t_Copula         {'rho': 0.8245612109257718, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.8406934065833009, 'nu': 4.0000000000...
# Clayton                              {'theta': 2.1067091655771146}
# Frank                                 {'theta': 7.595225818172606}
# Gumbel                                {'theta': 2.527755781284354}
# Plackett                             {'theta': 29.592958040949384}
# Gauss Mix Indep  {'rho': 0.9516376318379498, 'p': 0.72910485856...
#
#                                           2018-08-01 to 2019-07-31  \
#                                                              paras
# Gaussian                               {'rho': 0.7440029240760759}
# t_Copula         {'rho': 0.8013798514529065, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.8121535246499673, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.7958722852788405}
# Frank                                 {'theta': 7.095846806861704}
# Gumbel                                {'theta': 2.357308556416179}
# Plackett                             {'theta': 27.143038993164694}
# Gauss Mix Indep  {'rho': 0.9515563050968407, 'p': 0.70692514539...
#
#                                           2018-09-04 to 2019-08-30  \
#                                                              paras
# Gaussian                                {'rho': 0.747680739624065}
# t_Copula         {'rho': 0.8003675615035823, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.8121535246499673, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.7780990420966567}
# Frank                                 {'theta': 7.180280909457036}
# Gumbel                               {'theta': 2.3662033369265316}
# Plackett                             {'theta': 27.331817634024937}
# Gauss Mix Indep  {'rho': 0.9504105469219598, 'p': 0.70438380918...
#
#                                           2018-10-01 to 2019-09-30  \
#                                                              paras
# Gaussian                               {'rho': 0.7305998494895105}
# t_Copula         {'rho': 0.7797970366751265, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.7904798797225683, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.5413780661419094}
# Frank                                 {'theta': 6.810390192778198}
# Gumbel                                {'theta': 2.294169332434194}
# Plackett                             {'theta': 24.066822667542752}
# Gauss Mix Indep  {'rho': 0.9516216355415733, 'p': 0.67287259231...
#
#                                           2018-11-01 to 2019-10-31  \
#                                                              paras
# Gaussian                               {'rho': 0.7302611050525256}
# t_Copula         {'rho': 0.7616346879795014, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.777416927593324, 'nu': 4.00000000000...
# Clayton                              {'theta': 1.5359321640872563}
# Frank                                 {'theta': 6.673989245668377}
# Gumbel                               {'theta': 2.1572449514083765}
# Plackett                             {'theta': 20.667659005796125}
# Gauss Mix Indep  {'rho': 0.938032388832865, 'p': 0.674431925977...
#
#                                           2018-12-03 to 2019-11-29  \
#                                                              paras
# Gaussian                               {'rho': 0.7375031378955139}
# t_Copula         {'rho': 0.7520854745621828, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.771545848417469, 'nu': 4.00000000000...
# Clayton                               {'theta': 1.548342709278131}
# Frank                                 {'theta': 6.723875783961795}
# Gumbel                                 {'theta': 2.15636970701465}
# Plackett                             {'theta': 19.216195920075187}
# Gauss Mix Indep  {'rho': 0.9175308981635621, 'p': 0.71176890092...
#
#                                           2019-01-02 to 2019-12-31  \
#                                                              paras
# Gaussian                                {'rho': 0.722307821428137}
# t_Copula         {'rho': 0.7350085716192072, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.7593616251681491, 'nu': 4.0000000000...
# Clayton                               {'theta': 1.505964596612105}
# Frank                                  {'theta': 6.37148270048343}
# Gumbel                               {'theta': 2.0900509024947205}
# Plackett                              {'theta': 17.31811494870404}
# Gauss Mix Indep  {'rho': 0.909588257196908, 'p': 0.708868091978...
#
#                                           2019-02-01 to 2020-01-31  \
#                                                              paras
# Gaussian                                {'rho': 0.739404765209877}
# t_Copula         {'rho': 0.7682089262153321, 'nu': 2.0000000000...
# t_Copula_Capped  {'rho': 0.7860054112575724, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.6450882407908425}
# Frank                                 {'theta': 7.059751381544418}
# Gumbel                               {'theta': 2.1740047910699065}
# Plackett                             {'theta': 21.597457670961454}
# Gauss Mix Indep  {'rho': 0.9274489758398959, 'p': 0.71054278704...
#
#                                           2019-03-01 to 2020-02-28  \
#                                                              paras
# Gaussian                               {'rho': 0.7439400995615871}
# t_Copula         {'rho': 0.7688778570442225, 'nu': 2.1381694918...
# t_Copula_Capped  {'rho': 0.7860054112575724, 'nu': 4.0000000000...
# Clayton                               {'theta': 1.706804170608527}
# Frank                                 {'theta': 7.121151046752955}
# Gumbel                                {'theta': 2.163630688190458}
# Plackett                             {'theta': 20.979895140975714}
# Gauss Mix Indep  {'rho': 0.9121602682793966, 'p': 0.74410599440...
#
#                                           2019-04-01 to 2020-03-31  \
#                                                              paras
# Gaussian                               {'rho': 0.7576081411246205}
# t_Copula         {'rho': 0.7728759827260258, 'nu': 2.0110192314...
# t_Copula_Capped  {'rho': 0.7947895928717161, 'nu': 4.0000000000...
# Clayton                               {'theta': 1.896004464430347}
# Frank                                {'theta': 7.1723449817950105}
# Gumbel                                 {'theta': 2.18701589385761}
# Plackett                             {'theta': 21.154293895280524}
# Gauss Mix Indep  {'rho': 0.9153813436211624, 'p': 0.74877711721...
#
#                                           2019-05-01 to 2020-04-30  \
#                                                              paras
# Gaussian                               {'rho': 0.7652480130696762}
# t_Copula         {'rho': 0.7803898343738216, 'nu': 2.0796161630...
# t_Copula_Capped  {'rho': 0.7947895928717161, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.9390587053339094}
# Frank                                  {'theta': 7.32642269501515}
# Gumbel                                {'theta': 2.218628288642374}
# Plackett                              {'theta': 21.52823072231646}
# Gauss Mix Indep  {'rho': 0.912032777737243, 'p': 0.762982607051...
#
#                                           2019-06-03 to 2020-05-29  \
#                                                              paras
# Gaussian                               {'rho': 0.7709344682050898}
# t_Copula         {'rho': 0.7854492974543921, 'nu': 2.6034806424...
# t_Copula_Capped  {'rho': 0.7973873628965493, 'nu': 4.0000000000...
# Clayton                              {'theta': 2.0261855758289538}
# Frank                                 {'theta': 7.464858159970866}
# Gumbel                               {'theta': 2.1851733681130026}
# Plackett                              {'theta': 20.64708768435209}
# Gauss Mix Indep  {'rho': 0.8845009636412604, 'p': 0.82150036057...
#
#                                           2019-07-01 to 2020-06-30  \
#                                                              paras
# Gaussian                                {'rho': 0.737828365286701}
# t_Copula         {'rho': 0.7554444252928313, 'nu': 2.6243232554...
# t_Copula_Capped  {'rho': 0.7670036055267591, 'nu': 4.0000000000...
# Clayton                              {'theta': 1.8740234014924135}
# Frank                                {'theta': 6.7749661699435055}
# Gumbel                                {'theta': 2.014968646366854}
# Plackett                              {'theta': 17.05410299543111}
# Gauss Mix Indep  {'rho': 0.8631867019477178, 'p': 0.81173415936...
#
#                                           2019-08-01 to 2020-07-31  \
#                                                              paras
# Gaussian                               {'rho': 0.7673616511760624}
# t_Copula         {'rho': 0.7749880284299885, 'nu': 2.9073463587...
# t_Copula_Capped  {'rho': 0.7839437178859073, 'nu': 4.0000000000...
# Clayton                               {'theta': 2.009227516316374}
# Frank                                 {'theta': 7.132124061642831}
# Gumbel                               {'theta': 2.1158040861512903}
# Plackett                              {'theta': 17.81416097897374}
# Gauss Mix Indep  {'rho': 0.841539916759666, 'p': 0.881696192419...
#
#                                           2019-09-03 to 2020-08-31
#                                                              paras
# Gaussian                               {'rho': 0.7719732030761601}
# t_Copula         {'rho': 0.7815257668487313, 'nu': 2.7065473619...
# t_Copula_Capped  {'rho': 0.7947895928717161, 'nu': 4.0000000000...
# Clayton                               {'theta': 2.060362772827828}
# Frank                                {'theta': 7.2865629620524555}
# Gumbel                                {'theta': 2.159403630745768}
# Plackett                              {'theta': 18.78314730430285}
# Gauss Mix Indep  {'rho': 0.8593909349359685, 'p': 0.86195546832...

# %%
result.iloc[[0,2,3,4,5,6,7],[i for i in range(len(result.columns)) if i%2!=0]].style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_5bfe6b68_666f_11eb_9956_acde48001122row1_col0 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row1_col15 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row1_col16 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row1_col17 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row1_col18 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col1 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col2 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col3 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col4 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col5 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col6 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col7 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col8 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col9 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col10 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col11 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col12 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col13 {
#             background-color:  lightgreen;
#         }    #T_5bfe6b68_666f_11eb_9956_acde48001122row6_col14 {
#             background-color:  lightgreen;
#         }</style><table id="T_5bfe6b68_666f_11eb_9956_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2018-03-01 to 2019-02-28</th>        <th class="col_heading level0 col1" >2018-04-02 to 2019-03-29</th>        <th class="col_heading level0 col2" >2018-05-01 to 2019-04-30</th>        <th class="col_heading level0 col3" >2018-06-01 to 2019-05-31</th>        <th class="col_heading level0 col4" >2018-07-02 to 2019-06-28</th>        <th class="col_heading level0 col5" >2018-08-01 to 2019-07-31</th>        <th class="col_heading level0 col6" >2018-09-04 to 2019-08-30</th>        <th class="col_heading level0 col7" >2018-10-01 to 2019-09-30</th>        <th class="col_heading level0 col8" >2018-11-01 to 2019-10-31</th>        <th class="col_heading level0 col9" >2018-12-03 to 2019-11-29</th>        <th class="col_heading level0 col10" >2019-01-02 to 2019-12-31</th>        <th class="col_heading level0 col11" >2019-02-01 to 2020-01-31</th>        <th class="col_heading level0 col12" >2019-03-01 to 2020-02-28</th>        <th class="col_heading level0 col13" >2019-04-01 to 2020-03-31</th>        <th class="col_heading level0 col14" >2019-05-01 to 2020-04-30</th>        <th class="col_heading level0 col15" >2019-06-03 to 2020-05-29</th>        <th class="col_heading level0 col16" >2019-07-01 to 2020-06-30</th>        <th class="col_heading level0 col17" >2019-08-01 to 2020-07-31</th>        <th class="col_heading level0 col18" >2019-09-03 to 2020-08-31</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >likelihood</th>        <th class="col_heading level1 col1" >likelihood</th>        <th class="col_heading level1 col2" >likelihood</th>        <th class="col_heading level1 col3" >likelihood</th>        <th class="col_heading level1 col4" >likelihood</th>        <th class="col_heading level1 col5" >likelihood</th>        <th class="col_heading level1 col6" >likelihood</th>        <th class="col_heading level1 col7" >likelihood</th>        <th class="col_heading level1 col8" >likelihood</th>        <th class="col_heading level1 col9" >likelihood</th>        <th class="col_heading level1 col10" >likelihood</th>        <th class="col_heading level1 col11" >likelihood</th>        <th class="col_heading level1 col12" >likelihood</th>        <th class="col_heading level1 col13" >likelihood</th>        <th class="col_heading level1 col14" >likelihood</th>        <th class="col_heading level1 col15" >likelihood</th>        <th class="col_heading level1 col16" >likelihood</th>        <th class="col_heading level1 col17" >likelihood</th>        <th class="col_heading level1 col18" >likelihood</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5bfe6b68_666f_11eb_9956_acde48001122level0_row0" class="row_heading level0 row0" >Gaussian</th>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col0" class="data row0 col0" >0.417644</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col1" class="data row0 col1" >0.437603</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col2" class="data row0 col2" >0.400458</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col3" class="data row0 col3" >0.404937</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col4" class="data row0 col4" >0.472737</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col5" class="data row0 col5" >0.408929</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col6" class="data row0 col6" >0.41509</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col7" class="data row0 col7" >0.387387</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col8" class="data row0 col8" >0.379347</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col9" class="data row0 col9" >0.390892</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col10" class="data row0 col10" >0.368464</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col11" class="data row0 col11" >0.39435</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col12" class="data row0 col12" >0.402113</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col13" class="data row0 col13" >0.424306</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col14" class="data row0 col14" >0.437106</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col15" class="data row0 col15" >0.447862</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col16" class="data row0 col16" >0.390134</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col17" class="data row0 col17" >0.439427</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row0_col18" class="data row0 col18" >0.449524</td>
#             </tr>
#             <tr>
#                         <th id="T_5bfe6b68_666f_11eb_9956_acde48001122level0_row1" class="row_heading level0 row1" >t_Copula_Capped</th>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row1_col0" class="data row1 col0" >0.474791</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row1_col1" class="data row1 col1" >0.518299</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row1_col2" class="data row1 col2" >0.471751</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row1_col3" class="data row1 col3" >0.516681</td>
#                         <td id="T_5bfe6b68_666f_11eb_9956_acde48001122row1_col4" class="data row1

# %%
kde_brr = KDE(data.return_brr, "Gaussian")
kde_btc = KDE(data.return_btc, "Gaussian")

kde_brr = KDE(data.return_brr, "Gaussian", kde_brr.h_brot*3)
kde_btc = KDE(data.return_brr, "Gaussian", kde_btc.h_brot*3)
kde_brr.plot_density()

# %%
kde_brr.plot_density()

# %%
plt.figure(figsize=(15,10))
plt.plot(data.iloc[:,6])

# %%
np.argmax(data.return_brr)
# Out:
# 216

# %%
plt.figure(figsize=(15,10))
plt.plot(data.return_brr)

# %%
kde_brr.h_brot
# Out:
# 0.02197382561545512

# %%
s = Gaussian_Mix_Independent(C7.paras, kde_brr, kde_btc).sample(100000)
plt.figure(figsize=(5,5))
plt.scatter(s[:,0],s[:,1])
plt.title("Samples from Gaussian Mix Independent")
plt.xlabel(r"$R^S$")
plt.ylabel(r"$R^F$")
# Out:
# Text(0, 0.5, '$R^F$')

# %%
h=1
rh = s[:,0] - h*s[:,1]
plt.figure(figsize=(6,5))
plt.scatter(s[:,0],s[:,1],c=rh)
plt.title(r"Samples with Color of $R^h$, $h=1$")
plt.xlabel(r"$R^S$")
plt.ylabel(r"$R^F$")
plt.colorbar()

# %%
h=1
rh = s[:,0] - h*s[:,1]
plt.figure(figsize=(6,5))
plt.scatter(s[:,0],s[:,1],c=ECDF(rh)(rh))
plt.title(r"Samples with Color of $F_{R^h}(R^h)$, $h=1$")
plt.xlabel(r"$R^S$")
plt.ylabel(r"$R^F$")
plt.colorbar()

# %%
h=1
rh = s[:,0] - h*s[:,1]
plt.figure(figsize=(6,5))
plt.scatter(s[:,0],s[:,1],c=ERM_weight(10,ECDF(rh)(rh)))
plt.title(r"Samples with Color of ERM weight k=10")
plt.xlabel(r"$R^S$")
plt.ylabel(r"$R^F$")
plt.colorbar()

# %%
h=1
rh = s[:,0] - h*s[:,1]
plt.figure(figsize=(6,5))
plt.scatter(s[:,0],s[:,1],c=-ERM_weight(10,ECDF(rh)(rh))*rh)
plt.title(r"Samples with Color of Contribution to ERM Measure k=10")
plt.xlabel(r"$R^S$")
plt.ylabel(r"$R^F$")
plt.colorbar()

# %%
density = [Gaussian_Mix_Independent(C7.paras, kde_brr, kde_btc).f_RH(1,rh[i]) for i in range(len(rh))]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-198-8acff92115da> in <module>
# ----> 1 density = [Gaussian_Mix_Independent(C7.paras, kde_brr, kde_btc).f_RH(1,rh[i]) for i in range(len(rh))]
#
# <ipython-input-198-8acff92115da> in <listcomp>(.0)
# ----> 1 density = [Gaussian_Mix_Independent(C7.paras, kde_brr, kde_btc).f_RH(1,rh[i]) for i in range(len(rh))]
#
# ~/Google Drive/00_IRTG1792/copula/Py_notebooks/copulae1.py in f_RH(self, h, r_h)
#      42         part2 = lambda u: self.Law_RF.pdf(self.H(w=u, h=h, r_h=r_h))
#      43         integrand = lambda u: part1(u)*part2(u)
# ---> 44         return integrate.quad(integrand, 0.0001, 0.999)[0]/np.abs(h)
#      45
#      46     def _lambda(self, q):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~/Google Drive/00_IRTG1792/copula/Py_notebooks/copulae1.py in <lambda>(u)
#      41         part1 = lambda u: self.c(u, self.g(w=u, h=h, r_h=r_h))
#      42         part2 = lambda u: self.Law_RF.pdf(self.H(w=u, h=h, r_h=r_h))
# ---> 43         integrand = lambda u: part1(u)*part2(u)
#      44         return integrate.quad(integrand, 0.0001, 0.999)[0]/np.abs(h)
#      45
#
# ~/Google Drive/00_IRTG1792/copula/Py_notebooks/copulae1.py in <lambda>(u)
#      40     def f_RH(self, h, r_h):
#      41         part1 = lambda u: self.c(u, self.g(w=u, h=h, r_h=r_h))
# ---> 42         part2 = lambda u: self.Law_RF.pdf(self.H(w=u, h=h, r_h=r_h))
#      43         integrand = lambda u: part1(u)*part2(u)
#      44         return integrate.quad(integrand, 0.0001, 0.999)[0]/np.abs(h)
#
# ~/Google Drive/00_IRTG1792/copula/Py_notebooks/KDEs.py in pdf(self, x)
#      84     def pdf(self, x):
#      85         u = lambda x: (x - self.data)/self.h_brot
# ---> 86         s = np.sum(self.kernel(u(x)))
#      87         return s/(len(self.data)*self.h_brot)
#      88 #     def pdf(self, x):
#
# ~/Google Drive/00_IRTG1792/copula/Py_notebooks/KDEs.py in K_Gaussian(u)
#      21
#      22 def K_Gaussian(u):
# ---> 23     return np.exp(-0.5*u**2)/np.sqrt(2*np.pi)
#      24
#      25 def sample_Uniform(size, data, h):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
# -> 1585                                 index=left.index, name=res_name, dtype=None)
#    1586
#    1587     wrapper.__name__ = op_name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _construct_result(left, result, index, name, dtype)
#    1472     not be enough; we still need to override the name attribute.
#    1473     """
# -> 1474     out = left._constructor(result, index=index, dtype=dtype)
#    1475
#    1476     out.name = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262                                       raise_cast_failure=True)
#     263
# --> 264                 data = SingleBlockManager(data, index, fastpath=True)
#     265
#     266         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1479
#    1480         if not isinstance(block, Block):
# -> 1481             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1482
#    1483         self.blocks = [block]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3086     if klass is None:
#    3087         dtype = dtype or values.dtype
# -> 3088         klass = get_block_type(values, dtype)
#    3089
#    3090     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    3058     elif is_datetime64tz_dtype(values):
#    3059         cls = DatetimeTZBlock
# -> 3060     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    3061         cls = ObjectValuesExtensionBlock
#    3062     elif is_extension_array_dtype(values):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_interval_dtype(arr_or_dtype)
#     567     if arr_or_dtype is None:
#     568         return False
# --> 569     return IntervalDtype.is_dtype(arr_or_dtype)
#     570
#     571
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#     989             else:
#     990                 return False
# --> 991         return super(IntervalDtype, cls).is_dtype(dtype)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#      99
#     100         if isinstance(dtype, (ABCSeries, ABCIndexClass,
# --> 101                               ABCDataFrame, np.dtype)):
#     102             # https://github.com/pandas-dev/pandas/issues/22960
#     103             # avoid passing data to `construct_from_string`. This could
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#       7     @classmethod
#       8     def _check(cls, inst):
# ----> 9         return getattr(inst, attr, '_typ') in comp
#      10
#      11     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
h=1
rh = s[:,0] - h*s[:,1]
plt.figure(figsize=(6,5))
plt.scatter(s[:,0],s[:,1],c=-ERM_weight(10,ECDF(rh)(rh))*rh*density)
plt.title(r"Samples with Color of Contribution to ERM Measure times density k=10")
plt.xlabel(r"$R^S$")
plt.ylabel(r"$R^F$")
plt.colorbar()
