# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import requests
import os
import time
import pandas as pd

# %%
# token = os.getenv("TIINGO_API_KEY")

token = 'dc76ceadd678dd146f345afcb88619b4ab0287e9'

# %%
headers = {
        'Content-Type': 'application/json',
        'Authorization': 'Token ' + token
        }
requestResponse = requests.get("https://api.tiingo.com/api/test/",
                                    headers=headers)
print(requestResponse.json())
# Out:
# {'message': 'You successfully sent a request'}

# %% [markdown]
# Check that dates are UTC (2 hour behind local time)

# %%
import time
time.localtime()
# Out:
# time.struct_time(tm_year=2021, tm_mon=6, tm_mday=1, tm_hour=10, tm_min=57, tm_sec=33, tm_wday=1, tm_yday=152, tm_isdst=1)

# %%
headers = {
    'Content-Type': 'application/json'
}
requestResponse = requests.get("https://api.tiingo.com/tiingo/crypto/top?tickers=btcusd&token=" + token, headers=headers)
requestResponse.json()
# Out:
# [{'quoteCurrency': 'usd',
#   'ticker': 'btcusd',
#   'topOfBookData': [{'bidPrice': 36152.9,
#     'lastPrice': 36148.4,
#     'quoteTimestamp': '2021-06-01T08:57:35.185974+00:00',
#     'bidExchange': 'KRAKEN',
#     'bidSize': 2.08910771,
#     'lastSize': 0.06159872,
#     'askSize': 0.078,
#     'lastSizeNotional': 2226.695170048,
#     'askExchange': 'BITTREX',
#     'askPrice': 36142.598,
#     'lastSaleTimestamp': '2021-06-01T08:57:35.168921+00:00',
#     'lastExchange': 'GDAX'}],
#   'baseCurrency': 'btc'}]

# %% [markdown]
# Below is a snapshot of hourly and 5-minute-frequency data. Open and close at the hour are identical, so it seems that the data at 23:00 would be exact (or at most within 5 minutes of 23:00).

# %%
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Token ' + token
}
requestResponse \
  = requests.get("https://api.tiingo.com/tiingo/crypto/prices?tickers=btcusd&startDate=2021-05-27&resampleFreq=1hour", headers=headers)

# %%
rj=requestResponse.json()

# %%
df=pd.DataFrame(rj[0]['priceData'])

# %%
df.head()
# Out:
#            high           low                       date          open  \
# 0  39256.822699  38372.230249  2021-05-27T00:00:00+00:00  39255.921498
# 1  38713.938390  37507.911716  2021-05-27T01:00:00+00:00  38630.475189
# 2  38045.968798  37502.996077  2021-05-27T02:00:00+00:00  37626.113098
# 3  37828.421176  37139.765075  2021-05-27T03:00:00+00:00  37827.533638
# 4  37809.153467  37231.969688  2021-05-27T04:00:00+00:00  37638.603439
#
#           close  tradesDone  volumeNotional       volume
# 0  38627.434136    108797.0    1.907093e+08  4937.146332
# 1  37632.208750    139082.0    2.619801e+08  6961.593595
# 2  37823.868292     97994.0    1.714719e+08  4533.430642
# 3  37631.607857    110473.0    2.064966e+08  5487.319196
# 4  37745.386035     85188.0    1.355351e+08  3590.772694

# %%
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Token ' + token
}
requestResponse \
  = requests.get("https://api.tiingo.com/tiingo/crypto/prices?tickers=btcusd&startDate=2021-05-27&resampleFreq=5min", headers=headers)
rj2=requestResponse.json()

# %%
df2=pd.DataFrame(rj2[0]['priceData'])

# %%
df2.head(15)
# Out:
#     volumeNotional          open  tradesDone                       date  \
# 0     2.468262e+07  39255.921498     13780.0  2021-05-27T00:00:00+00:00
# 1     1.624596e+07  39194.575580      9631.0  2021-05-27T00:05:00+00:00
# 2     1.282304e+07  39041.132892      8146.0  2021-05-27T00:10:00+00:00
# 3     1.547255e+07  39014.421062     10692.0  2021-05-27T00:15:00+00:00
# 4     1.261100e+07  38805.959400      7961.0  2021-05-27T00:20:00+00:00
# 5     1.513377e+07  38882.708319      8573.0  2021-05-27T00:25:00+00:00
# 6     1.770495e+07  38774.195437     11513.0  2021-05-27T00:30:00+00:00
# 7     2.100803e+07  38552.952571      8133.0  2021-05-27T00:35:00+00:00
# 8     2.322971e+07  38572.883393     11749.0  2021-05-27T00:40:00+00:00
# 9     1.397618e+07  38530.035227      6326.0  2021-05-27T00:45:00+00:00
# 10    1.100951e+07  38586.352556      7133.0  2021-05-27T00:50:00+00:00
# 11    7.574477e+06  38702.884839      5160.0  2021-05-27T00:55:00+00:00
# 12    1.552338e+07  38630.475189      9739.0  2021-05-27T01:00:00+00:00
# 13    9.382512e+06  38669.000541      7596.0  2021-05-27T01:05:00+00:00
# 14    1.437047e+07  38459.753665      9492.0  2021-05-27T01:10:00+00:00
#
#             high         close           low      volume
# 0   39256.822699  39201.863965  39075.726268  629.628647
# 1   39197.738243  39048.814282  38989.248933  416.042275
# 2   39144.518425  39011.150435  38995.248283  328.701945
# 3   39015.922279  38804.534394  38779.548310  398.730436
# 4   38904.621366  38893.636966  38775.439710  324.243276
# 5   38902.155276  38775.198295  38720.202413  390.294993
# 6   38802.231585  38541.454094  38525.962382  459.374280
# 7   38618.064327  38580.803726  38526.230074  544.520248
# 8   38573.159360  38529.053037  38372.230249  602.914232
# 9   38611.830018  38582.244114  38458.207421  362.243845
# 10  38751.730077  38716.591884  38577.237325  284.361545
# 11  38703.562570  38627.434136  38604.194213  196.090610
# 12  38713.938390  38680.785326  38432.755416  401.320283
# 13  38687.155858  38470.637056  38450.675247  243.887617
# 14  38563.038288  38341.501005  38318.462790  374.801975

# %%
dates = pd.date_range(start="2018-06-01", end="2021-05-25", freq="3D")
dates_end=pd.date_range(start="2018-06-04", end="2021-05-28", freq="3D")

# %%
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Token ' + token
}
filename="tiingo_btc.csv"
header=True
if os.path.isfile(filename):
    header=False

for d1, d2 in zip(dates, dates_end):
    print(str(d1).split(' ')[0] + ", " + str(d2).split(' ')[0]);
    requestResponse \
        = requests.get("https://api.tiingo.com/tiingo/crypto/prices?tickers=btcusd&" \
        "startDate=" + str(d1).split(' ')[0] + "&endDate=" + str(d2).split(' ')[0] + "&resampleFreq=1hour", headers=headers)
