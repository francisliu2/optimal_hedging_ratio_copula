# %%
import os, sys
sys.path.append('../src')
from copulae1 import *
from KDEs import *
from toolbox import *
import json
import datetime
import pickle


import matplotlib.pyplot as plt

# %%
# Gaussian, t_Copula, Clayton, Frank, Gumbel, Plackett, Gaussian mix Indep
C1  = Gaussian(dict(rho=0.9),       Law_RS=stats.norm, Law_RF=stats.norm)
C2  = t_Copula(dict(rho=0.1, nu=4), Law_RS=stats.norm, Law_RF=stats.norm, nu_lowerbound=2)
C2c = t_Copula(dict(rho=0.1, nu=4), Law_RS=stats.norm, Law_RF=stats.norm, nu_lowerbound=4)
C3  = Clayton(dict(theta=0.1),      Law_RS=stats.norm, Law_RF=stats.norm)
C4  = Frank(dict(theta=0.1),        Law_RS=stats.norm, Law_RF=stats.norm)
C5  = Gumbel(dict(theta=3),         Law_RS=stats.norm, Law_RF=stats.norm)
C6  = Plackett(dict(theta=10),      Law_RS=stats.norm, Law_RF=stats.norm)
C7  = Gaussian_Mix_Independent(dict(rho=.5,p=0.7),Law_RS=stats.norm, Law_RF=stats.norm)
C8  = rot180Gumbel(dict(theta=3), Law_RS=stats.norm, Law_RF=stats.norm)

# %%
calibration_method = 'MM'
q_arr = [0.05,0.1,0.9,0.95]

# %%
Copulae_names = ['Gaussian', 't_Copula', 't_Copula_Capped', 'Clayton', 'Frank', 'Gumbel', 'Plackett', 'Gauss Mix Indep', 'rotGumbel']
Copulae_arr = [C1, C2, C2c, C3, C4, C5, C6, C7, C8]
Copulae = dict(zip(Copulae_names, Copulae_arr))

# %%
paras_results = []
likelihood_results = []

# %%
spot_name = 'rs'
future_name = 'rf'
data_name = 'deribit_BTCUSD_BTCUSD'
data_path = '/Volumes/external_SSD/copulaData/Deribit_ready/BTCUSD_BTCUSD/'

ls = os.listdir(data_path + 'train/')
ls = [l for l in ls if l.endswith('.csv')]

start = 0

for i, file in enumerate(ls[start:]):
	print('-----', i, len(ls), str(datetime.datetime.now()), '-----')
	# Calibration
	train = pd.read_csv(data_path + 'train/' + file)
	spot = train.loc[:, spot_name]
	future = train.loc[:, future_name]
	u = ECDF(spot)(spot)
	v = ECDF(future)(future)

	kde_brr = KDE(spot, "Gaussian")
	kde_btc = KDE(future, "Gaussian")

	for C_name in Copulae:
		Copulae[C_name].Law_RS = kde_brr
		Copulae[C_name].Law_RF = kde_btc

	paras = []
	likelihood = []
	best_h = []
	for C_name in Copulae:
		if calibration_method == "MLE":
			Copulae[C_name].canonical_calibrate(u, v)

		elif calibration_method == "MM":
			Copulae[C_name].mm_calibrate(u, v, q_arr)

		print(C_name, 'is done.\n')

	for C_name in Copulae:
		paras.append((C_name, Copulae[C_name].paras))

	for C_name in Copulae:
		ln = Copulae[C_name].dependency_likelihood(u, v)
		likelihood.append((C_name, ln))
        
	paras_results.append(paras)
	likelihood_results.append(likelihood)

	if (i%60==0) or (i == 0) or (i==len(ls)):
		print('saved!')
		with open(data_name+'_paras.pickle', 'wb') as f:
			pickle.dump(paras_results, f)

		with open(data_name+'_likelihood.pickle', 'wb') as f:
			pickle.dump(likelihood_results, f)
# Out:
# ----- 0 2116 2022-09-12 11:47:12.289659 -----
# Optimization terminated successfully.
#          Current function value: 0.042251
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042449
#          Iterations: 204
#          Function evaluations: 385
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042449
#          Iterations: 166
#          Function evaluations: 311
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064428
#          Iterations: 49
#          Function evaluations: 108
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047877
#          Iterations: 64
#          Function evaluations: 135
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.153418
#          Iterations: 39
#          Function evaluations: 84
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.037984
#          Iterations: 47
#          Function evaluations: 109
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040927
#          Iterations: 134
#          Function evaluations: 256
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010702
#          Iterations: 36
#          Function evaluations: 78
# rotGumbel is done.
#
# saved!
# ----- 1 2116 2022-09-12 11:47:58.869965 -----
# Optimization terminated successfully.
#          Current function value: 0.022674
#          Iterations: 30
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022785
#          Iterations: 113
#          Function evaluations: 220
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022785
#          Iterations: 110
#          Function evaluations: 217
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.073303
#          Iterations: 37
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.033107
#          Iterations: 47
#          Function evaluations: 97
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.106043
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020933
#          Iterations: 41
#          Function evaluations: 95
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022491
#          Iterations: 66
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010571
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 2 2116 2022-09-12 11:48:34.234976 -----
# Optimization terminated successfully.
#          Current function value: 0.011160
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011164
#          Iterations: 101
#          Function evaluations: 203
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011164
#          Iterations: 109
#          Function evaluations: 219
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.083591
#          Iterations: 36
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034368
#          Iterations: 46
#          Function evaluations: 96
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.082993
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013649
#          Iterations: 42
#          Function evaluations: 99
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011128
#          Iterations: 69
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007879
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 3 2116 2022-09-12 11:49:08.105122 -----
# Optimization terminated successfully.
#          Current function value: 0.011346
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006422
#          Iterations: 177
#          Function evaluations: 334
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008128
#          Iterations: 142
#          Function evaluations: 271
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.095817
#          Iterations: 41
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051142
#          Iterations: 38
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.037729
#          Iterations: 36
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014821
#          Iterations: 46
#          Function evaluations: 105
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007709
#          Iterations: 68
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030812
#          Iterations: 38
#          Function evaluations: 83
# rotGumbel is done.
#
# ----- 4 2116 2022-09-12 11:49:26.103692 -----
# Optimization terminated successfully.
#          Current function value: 0.010504
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009354
#          Iterations: 80
#          Function evaluations: 170
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009471
#          Iterations: 116
#          Function evaluations: 224
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.126520
#          Iterations: 39
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013161
#          Iterations: 52
#          Function evaluations: 106
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010321
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011124
#          Iterations: 40
#          Function evaluations: 93
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008965
#          Iterations: 66
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.054708
#          Iterations: 36
#          Function evaluations: 80
# rotGumbel is done.
#
# ----- 5 2116 2022-09-12 11:49:40.838606 -----
# Optimization terminated successfully.
#          Current function value: 0.018953
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013412
#          Iterations: 127
#          Function evaluations: 238
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015534
#          Iterations: 136
#          Function evaluations: 259
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.120426
#          Iterations: 41
#          Function evaluations: 94
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.032175
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013287
#          Iterations: 35
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022185
#          Iterations: 45
#          Function evaluations: 105
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.014209
#          Iterations: 72
#          Function evaluations: 152
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.059447
#          Iterations: 37
#          Function evaluations: 81
# rotGumbel is done.
#
# ----- 6 2116 2022-09-12 11:49:53.305352 -----
# Optimization terminated successfully.
#          Current function value: 0.013287
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011677
#          Iterations: 79
#          Function evaluations: 169
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011968
#          Iterations: 133
#          Function evaluations: 246
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.137293
#          Iterations: 42
#          Function evaluations: 96
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016737
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005036
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013634
#          Iterations: 45
#          Function evaluations: 103
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011195
#          Iterations: 64
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065065
#          Iterations: 36
#          Function evaluations: 80
# rotGumbel is done.
#
# ----- 7 2116 2022-09-12 11:50:10.056980 -----
# Optimization terminated successfully.
#          Current function value: 0.022337
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022195
#          Iterations: 95
#          Function evaluations: 197
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022195
#          Iterations: 86
#          Function evaluations: 190
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.167608
#          Iterations: 39
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011821
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011218
#          Iterations: 37
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021342
#          Iterations: 42
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021519
#          Iterations: 71
#          Function evaluations: 150
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.082801
#          Iterations: 35
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 8 2116 2022-09-12 11:50:28.442765 -----
# Optimization terminated successfully.
#          Current function value: 0.013753
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013789
#          Iterations: 131
#          Function evaluations: 253
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013789
#          Iterations: 135
#          Function evaluations: 253
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.157699
#          Iterations: 39
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012456
#          Iterations: 36
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017078
#          Iterations: 34
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010790
#          Iterations: 42
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013635
#          Iterations: 70
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.067955
#          Iterations: 36
#          Function evaluations: 79
# rotGumbel is done.
#
# ----- 9 2116 2022-09-12 11:51:06.224891 -----
# Optimization terminated successfully.
#          Current function value: 0.021680
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021391
#          Iterations: 127
#          Function evaluations: 267
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021391
#          Iterations: 130
#          Function evaluations: 268
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.172717
#          Iterations: 40
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012564
#          Iterations: 53
#          Function evaluations: 108
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015586
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022128
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020995
#          Iterations: 70
#          Function evaluations: 147
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.080745
#          Iterations: 34
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 10 2116 2022-09-12 11:51:34.427980 -----
# Optimization terminated successfully.
#          Current function value: 0.017213
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017262
#          Iterations: 135
#          Function evaluations: 258
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017262
#          Iterations: 143
#          Function evaluations: 272
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.148264
#          Iterations: 40
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013988
#          Iterations: 37
#          Function evaluations: 79
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024123
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012912
#          Iterations: 39
#          Function evaluations: 89
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017004
#          Iterations: 63
#          Function evaluations: 133
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065092
#          Iterations: 34
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 11 2116 2022-09-12 11:52:14.450083 -----
# Optimization terminated successfully.
#          Current function value: 0.010770
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009404
#          Iterations: 129
#          Function evaluations: 266
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009596
#          Iterations: 172
#          Function evaluations: 319
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.127668
#          Iterations: 41
#          Function evaluations: 93
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013849
#          Iterations: 53
#          Function evaluations: 108
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010646
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
# Optimization terminated successfully.
#          Current function value: 0.011243
#          Iterations: 43
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008968
#          Iterations: 69
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055168
#          Iterations: 38
#          Function evaluations: 82
# rotGumbel is done.
#
# ----- 12 2116 2022-09-12 11:52:41.550117 -----
# Optimization terminated successfully.
#          Current function value: 0.010461
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009345
#          Iterations: 71
#          Function evaluations: 160
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009451
#          Iterations: 131
#          Function evaluations: 246
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.126326
#          Iterations: 37
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013046
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010267
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011103
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008964
#          Iterations: 66
#          Function evaluations: 137
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.054632
#          Iterations: 36
#          Function evaluations: 78
# rotGumbel is done.
#
# ----- 13 2116 2022-09-12 11:52:55.642277 -----
# Optimization terminated successfully.
#          Current function value: 0.010801
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009453
#          Iterations: 77
#          Function evaluations: 165
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009588
#          Iterations: 139
#          Function evaluations: 265
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.138022
#          Iterations: 40
#          Function evaluations: 92
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013542
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007180
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012938
#          Iterations: 41
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009531
#          Iterations: 70
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060806
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 14 2116 2022-09-12 11:53:11.691590 -----
# Optimization terminated successfully.
#          Current function value: 0.011488
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006452
#          Iterations: 100
#          Function evaluations: 197
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008211
#          Iterations: 134
#          Function evaluations: 262
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.096285
#          Iterations: 39
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051454
#          Iterations: 36
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.037924
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014835
#          Iterations: 42
#          Function evaluations: 100
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007706
#          Iterations: 67
#          Function evaluations: 135
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.031000
#          Iterations: 35
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 15 2116 2022-09-12 11:53:23.031524 -----
# Optimization terminated successfully.
#          Current function value: 0.011168
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009466
#          Iterations: 77
#          Function evaluations: 164
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009727
#          Iterations: 110
#          Function evaluations: 211
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.139835
#          Iterations: 39
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014635
#          Iterations: 50
#          Function evaluations: 102
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007626
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013171
#          Iterations: 42
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009524
#          Iterations: 67
#          Function evaluations: 135
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.061498
#          Iterations: 34
#          Function evaluations: 75
# rotGumbel is done.
#
# ----- 16 2116 2022-09-12 11:53:37.656943 -----
# Optimization terminated successfully.
#          Current function value: 0.006355
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002665
#          Iterations: 88
#          Function evaluations: 177
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003958
#          Iterations: 92
#          Function evaluations: 178
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.098687
#          Iterations: 36
#          Function evaluations: 84
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026046
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015762
#          Iterations: 36
#          Function evaluations: 81
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007521
#          Iterations: 44
#          Function evaluations: 102
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002652
#          Iterations: 67
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036486
#          Iterations: 35
#          Function evaluations: 79
# rotGumbel is done.
#
# ----- 17 2116 2022-09-12 11:53:46.088523 -----
# Optimization terminated successfully.
#          Current function value: 0.007768
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003882
#          Iterations: 128
#          Function evaluations: 240
# t_Copula is done.
# Optimization terminated successfully.
#          Current function value: 0.005349
#          Iterations: 113
#          Function evaluations: 213
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.097596
#          Iterations: 38
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029138
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012768
#          Iterations: 34
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006898
#          Iterations: 40
#          Function evaluations: 93
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002783
#          Iterations: 69
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.039835
#          Iterations: 35
#          Function evaluations: 76
# rotGumbel is done.
#
# ----- 18 2116 2022-09-12 11:53:56.857527 -----
# Optimization terminated successfully.
#          Current function value: 0.016899
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016961
#          Iterations: 166
#          Function evaluations: 317
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016961
#          Iterations: 135
#          Function evaluations: 260
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.146061
#          Iterations: 41
#          Function evaluations: 93
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012548
#          Iterations: 37
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023655
#          Iterations: 37
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012472
#          Iterations: 45
#          Function evaluations: 102
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016844
#          Iterations: 69
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064416
#          Iterations: 36
#          Function evaluations: 78
# rotGumbel is done.
#
# ----- 19 2116 2022-09-12 11:54:39.230659 -----
# Optimization terminated successfully.
#          Current function value: 0.033733
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.193827
#          Iterations: 36
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018174
#          Iterations: 38
#          Function evaluations: 85
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029093
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026835
#          Iterations: 42
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.033942
#          Iterations: 68
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.098435
#          Iterations: 36
#          Function evaluations: 80
# rotGumbel is done.
#
# ----- 20 2116 2022-09-12 11:55:39.255063 -----
# Optimization terminated successfully.
#          Current function value: 0.026736
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026848
#          Iterations: 129
#          Function evaluations: 277
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.206073
#          Iterations: 39
#          Function evaluations: 90
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017219
#          Iterations: 36
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023615
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022429
#          Iterations: 41
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026906
#          Iterations: 67
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.096390
#          Iterations: 35
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 21 2116 2022-09-12 11:56:30.204579 -----
# Optimization terminated successfully.
#          Current function value: 0.026732
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026848
#          Iterations: 93
#          Function evaluations: 195
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026848
#          Iterations: 104
#          Function evaluations: 220
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.205464
#          Iterations: 37
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016535
#          Iterations: 48
#          Function evaluations: 102
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023584
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022403
#          Iterations: 40
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026891
#          Iterations: 73
#          Function evaluations: 148
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.096268
#          Iterations: 34
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 22 2116 2022-09-12 11:57:03.616801 -----
# Optimization terminated successfully.
#          Current function value: 0.026808
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026918
#          Iterations: 37
#          Function evaluations: 147
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.217508
#          Iterations: 37
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018468
#          Iterations: 41
#          Function evaluations: 90
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013705
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022648
#          Iterations: 38
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027015
#          Iterations: 64
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.105973
#          Iterations: 34
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 23 2116 2022-09-12 11:57:46.584271 -----
# Optimization terminated successfully.
#          Current function value: 0.012456
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012447
#          Iterations: 122
#          Function evaluations: 272
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012447
#          Iterations: 105
#          Function evaluations: 234
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.185826
#          Iterations: 36
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016726
#          Iterations: 38
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007979
#          Iterations: 33
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012209
#          Iterations: 40
#          Function evaluations: 96
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012212
#          Iterations: 65
#          Function evaluations: 137
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.080429
#          Iterations: 36
#          Function evaluations: 80
# rotGumbel is done.
#
# ----- 24 2116 2022-09-12 11:58:18.574029 -----
# Optimization terminated successfully.
#          Current function value: 0.012800
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012783
#          Iterations: 97
#          Function evaluations: 219
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012783
#          Iterations: 94
#          Function evaluations: 213
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.174605
#          Iterations: 37
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015887
#          Iterations: 36
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012537
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011035
#          Iterations: 44
#          Function evaluations: 101
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012135
#          Iterations: 66
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.074437
#          Iterations: 35
#          Function evaluations: 78
# rotGumbel is done.
#
# ----- 25 2116 2022-09-12 11:58:44.623164 -----
# Optimization terminated successfully.
#          Current function value: 0.007960
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005110
#          Iterations: 160
#          Function evaluations: 310
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005894
#          Iterations: 142
#          Function evaluations: 261
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.117153
#          Iterations: 38
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.033995
#          Iterations: 43
#          Function evaluations: 90
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020480
#          Iterations: 37
#          Function evaluations: 83
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008786
#          Iterations: 43
#          Function evaluations: 100
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005078
#          Iterations: 72
#          Function evaluations: 147
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.044585
#          Iterations: 37
#          Function evaluations: 82
# rotGumbel is done.
#
# ----- 26 2116 2022-09-12 11:59:01.891925 -----
# Optimization terminated successfully.
#          Current function value: 0.012962
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012920
#          Iterations: 114
#          Function evaluations: 238
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012920
#          Iterations: 108
#          Function evaluations: 226
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.175549
#          Iterations: 39
#          Function evaluations: 89
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016537
#          Iterations: 38
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012739
#          Iterations: 38
#          Function evaluations: 84
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011156
#          Iterations: 45
#          Function evaluations: 108
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012156
#          Iterations: 75
#          Function evaluations: 150
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.074750
#          Iterations: 36
#          Function evaluations: 80
# rotGumbel is done.
#
# ----- 27 2116 2022-09-12 11:59:27.629129 -----
# Optimization terminated successfully.
#          Current function value: 0.014919
#          Iterations: 33
#          Function evaluations: 69
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010242
#          Iterations: 146
#          Function evaluations: 277
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011697
#          Iterations: 158
#          Function evaluations: 294
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.169016
#          Iterations: 40
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024771
#          Iterations: 52
#          Function evaluations: 106
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013121
#          Iterations: 34
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.019188
#          Iterations: 44
#          Function evaluations: 103
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011295
#          Iterations: 68
#          Function evaluations: 147
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.071471
#          Iterations: 35
#          Function evaluations: 79
# rotGumbel is done.
#
# ----- 28 2116 2022-09-12 11:59:43.045265 -----
# Optimization terminated successfully.
#          Current function value: 0.015919
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011436
#          Iterations: 116
#          Function evaluations: 223
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012901
#          Iterations: 120
#          Function evaluations: 228
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.164894
#          Iterations: 38
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024561
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009029
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018331
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.011730
#          Iterations: 68
#          Function evaluations: 149
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.074228
#          Iterations: 35
#          Function evaluations: 78
# rotGumbel is done.
#
# ----- 29 2116 2022-09-12 11:59:55.590169 -----
# Optimization terminated successfully.
#          Current function value: 0.015869
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011425
#          Iterations: 123
#          Function evaluations: 244
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012871
#          Iterations: 124
#          Function evaluations: 245
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.164717
#          Iterations: 37
#          Function evaluations: 84
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024441
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008974
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018327
#          Iterations: 38
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011731
#          Iterations: 63
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.074149
#          Iterations: 35
#          Function evaluations: 79
# rotGumbel is done.
#
# ----- 30 2116 2022-09-12 12:00:05.487022 -----
# Optimization terminated successfully.
#          Current function value: 0.024579
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022638
#          Iterations: 73
#          Function evaluations: 161
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022907
#          Iterations: 171
#          Function evaluations: 333
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.203561
#          Iterations: 37
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021820
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005231
#          Iterations: 36
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025933
#          Iterations: 42
#          Function evaluations: 99
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022246
#          Iterations: 65
#          Function evaluations: 136
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.100142
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 31 2116 2022-09-12 12:00:22.555522 -----
# Optimization terminated successfully.
#          Current function value: 0.024822
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022526
#          Iterations: 75
#          Function evaluations: 163
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022792
#          Iterations: 116
#          Function evaluations: 218
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.223185
#          Iterations: 39
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026745
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006137
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029570
#          Iterations: 42
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023216
#          Iterations: 65
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.105699
#          Iterations: 35
#          Function evaluations: 79
# rotGumbel is done.
#
# ----- 32 2116 2022-09-12 12:00:35.720974 -----
# Optimization terminated successfully.
#          Current function value: 0.007169
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004727
#          Iterations: 75
#          Function evaluations: 162
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005045
#          Iterations: 112
#          Function evaluations: 219
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.171286
#          Iterations: 39
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029688
#          Iterations: 54
#          Function evaluations: 112
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016774
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011897
#          Iterations: 42
# ...
#          Iterations: 122
#          Function evaluations: 237
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.156852
#          Iterations: 37
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022946
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005257
#          Iterations: 33
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018005
#          Iterations: 40
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013959
#          Iterations: 64
#          Function evaluations: 138
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.075983
#          Iterations: 33
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 76 2116 2022-09-12 12:09:36.023656 -----
# Optimization terminated successfully.
#          Current function value: 0.017156
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014050
#          Iterations: 120
#          Function evaluations: 237
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014955
#          Iterations: 108
#          Function evaluations: 209
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.156903
#          Iterations: 38
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022978
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005271
#          Iterations: 34
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018016
#          Iterations: 40
#          Function evaluations: 94
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.013958
#          Iterations: 65
#          Function evaluations: 138
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076006
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 77 2116 2022-09-12 12:09:45.334013 -----
# Optimization terminated successfully.
#          Current function value: 0.017502
#          Iterations: 33
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014124
#          Iterations: 116
#          Function evaluations: 234
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015158
#          Iterations: 113
#          Function evaluations: 213
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.158160
#          Iterations: 36
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023787
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005643
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018183
#          Iterations: 39
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013955
#          Iterations: 68
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076572
#          Iterations: 36
#          Function evaluations: 81
# rotGumbel is done.
#
# ----- 78 2116 2022-09-12 12:09:55.833746 -----
# Optimization terminated successfully.
#          Current function value: 0.013758
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009856
#          Iterations: 135
#          Function evaluations: 260
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011140
#          Iterations: 140
#          Function evaluations: 273
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.149766
#          Iterations: 37
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020993
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010606
#          Iterations: 36
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014115
#          Iterations: 40
#          Function evaluations: 95
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009502
#          Iterations: 65
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065704
#          Iterations: 35
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 79 2116 2022-09-12 12:10:09.327382 -----
# Optimization terminated successfully.
#          Current function value: 0.028060
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022252
#          Iterations: 121
#          Function evaluations: 231
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024469
#          Iterations: 92
#          Function evaluations: 181
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.160991
#          Iterations: 41
#          Function evaluations: 90
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026654
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011909
#          Iterations: 34
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.028932
#          Iterations: 44
#          Function evaluations: 102
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021984
#          Iterations: 75
#          Function evaluations: 152
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.084952
#          Iterations: 35
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 80 2116 2022-09-12 12:10:18.865321 -----
# Optimization terminated successfully.
#          Current function value: 0.007089
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001529
#          Iterations: 127
#          Function evaluations: 240
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003404
#          Iterations: 130
#          Function evaluations: 249
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.129751
#          Iterations: 44
#          Function evaluations: 98
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038694
#          Iterations: 54
#          Function evaluations: 112
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.031213
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013145
#          Iterations: 44
#          Function evaluations: 101
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002172
#          Iterations: 68
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.039896
#          Iterations: 38
#          Function evaluations: 83
# rotGumbel is done.
#
# ----- 81 2116 2022-09-12 12:10:32.100937 -----
# Optimization terminated successfully.
#          Current function value: 0.028588
#          Iterations: 33
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023522
#          Iterations: 115
#          Function evaluations: 229
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025472
#          Iterations: 127
#          Function evaluations: 245
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.153865
#          Iterations: 43
#          Function evaluations: 95
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036111
#          Iterations: 50
#          Function evaluations: 104
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008191
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027922
#          Iterations: 45
#          Function evaluations: 102
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022632
#          Iterations: 65
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.085771
#          Iterations: 37
#          Function evaluations: 82
# rotGumbel is done.
#
# ----- 82 2116 2022-09-12 12:10:43.999806 -----
# Optimization terminated successfully.
#          Current function value: 0.026483
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021353
#          Iterations: 120
#          Function evaluations: 239
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023334
#          Iterations: 118
#          Function evaluations: 230
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.147479
#          Iterations: 42
#          Function evaluations: 96
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025152
#          Iterations: 49
#          Function evaluations: 100
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014061
#          Iterations: 34
#          Function evaluations: 76
# Gumbel is done.
# Optimization terminated successfully.
#          Current function value: 0.025765
#          Iterations: 41
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020407
#          Iterations: 63
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.077261
#          Iterations: 37
#          Function evaluations: 82
# rotGumbel is done.
#
# ----- 83 2116 2022-09-12 12:10:53.549046 -----
# Optimization terminated successfully.
#          Current function value: 0.026455
#          Iterations: 32
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021662
#          Iterations: 150
#          Function evaluations: 291
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023396
#          Iterations: 107
#          Function evaluations: 204
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.156036
#          Iterations: 38
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023605
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010254
#          Iterations: 35
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.028162
#          Iterations: 41
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022056
#          Iterations: 67
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.082465
#          Iterations: 33
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 84 2116 2022-09-12 12:11:05.717443 -----
# Optimization terminated successfully.
#          Current function value: 0.027249
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021935
#          Iterations: 126
#          Function evaluations: 239
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023917
#          Iterations: 109
#          Function evaluations: 209
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.158552
#          Iterations: 39
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025137
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011073
#          Iterations: 33
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.028508
#          Iterations: 39
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022022
#          Iterations: 70
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.083714
#          Iterations: 36
#          Function evaluations: 79
# rotGumbel is done.
#
# ----- 85 2116 2022-09-12 12:11:16.801611 -----
# Optimization terminated successfully.
#          Current function value: 0.029860
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024374
#          Iterations: 122
#          Function evaluations: 227
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026347
#          Iterations: 193
#          Function evaluations: 371
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.171813
#          Iterations: 37
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027328
#          Iterations: 36
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009706
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.033103
#          Iterations: 42
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025405
#          Iterations: 70
#          Function evaluations: 149
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.092223
#          Iterations: 34
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 86 2116 2022-09-12 12:11:32.272416 -----
# Optimization terminated successfully.
#          Current function value: 0.028201
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.

# %%
# Prettify the result
c_arr = []
date_range_arr = []
for i, file in enumerate(ls):
	train = pd.read_csv(data_path + 'train/' + file)
	date_range = train.timestamp.iloc[-1] + ' to ' + train.timestamp.iloc[0]
	date_range_arr.append(date_range)

	c = pd.DataFrame(paras_results[i])
	c.index = c.iloc[:, 0]
	c = pd.DataFrame(c.iloc[:, 1])
	c_arr.append(c)

paras_results_pd = pd.concat(dict(zip(ls, c_arr)), axis=1)
paras_results_pd.columns = paras_results_pd.columns.droplevel(1)
paras_results_pd.index.name = None

l_arr = []
date_range_arr = []
for i, file in enumerate(list(paras_results_pd.columns)):
	train = pd.read_csv(data_path + 'train/' + file)
	date_range = train.timestamp.iloc[-1] + ' to ' + train.timestamp.iloc[0]
	date_range_arr.append(date_range)

	c = pd.DataFrame(likelihood_results[i])
	c.index = c.iloc[:, 0]
	c = pd.DataFrame(c.iloc[:, 1])
	l_arr.append(c)

likelihood_results_pd = pd.concat(dict(zip(ls, l_arr)), axis=1)
likelihood_results_pd.columns = likelihood_results_pd.columns.droplevel(1)
likelihood_results_pd.index.name = None

# %%
# Save results as html for display
display_paras = paras_results_pd.copy()
display_paras.columns = date_range_arr
display_paras = display_paras.reindex(sorted(display_paras.columns), axis=1)

display_likelihood = likelihood_results_pd.copy()
display_likelihood.columns = date_range_arr
display_likelihood = display_likelihood.reindex(sorted(display_likelihood.columns), axis=1)

# Save files to designated directories
if not os.path.exists("../results/" + data_name):
	print("Create new folder for results")
	os.mkdir("../results/" + data_name)
	os.mkdir("../results/" + data_name + "/MLE")
	os.mkdir("../results/" + data_name + "/MM")

if calibration_method == "MLE":
	path = "../results/" + data_name + "/MLE/"
	paras_results_pd.to_json(path + "parameters.json")
	likelihood_results_pd.to_json(path + "likelihood.json")

	display_paras.to_html(path + "paras.html")
	display_likelihood.to_html(path + "likelihood.html")

elif calibration_method == "MM":
	path = "../results/" + data_name + "/MM/"
	paras_results_pd.to_json(path + "parameters.json")
	likelihood_results_pd.to_json(path + "likelihood.json")

	display_paras.to_html(path + "paras.html")
	display_likelihood.to_html(path + "likelihood.html")

print('Done')
