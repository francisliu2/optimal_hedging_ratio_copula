# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd

import requests
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import scipy.stats as ss

sys.path.append('../../src/')
import toolbox

# %%
result_names = ['BBT_Tiingo',
                'BBT_future_Tiingo_ada', 
                'BBT_future_Tiingo_eth',
                'BBT_future_Tiingo_ltc',
                'BBT_future_Tiingo_xrp',
                'BBT_future_BITX',
                'BBT_future_BITW20', 
                'BBT_future_BITW70', 
                'BBT_future_BITW100', 
                'BBT_future_CRIX']

data_name = result_names[-1]
pd.read_csv('../../results/%s/MM/OHR.csv'%data_name)
# Out:
#       Unnamed: 0    file risk measure       OHR           copula
# 0              0  83.csv     Variance  0.959277         Gaussian
# 1              1  83.csv     ERM k=10  0.958887         Gaussian
# 2              2  83.csv    ES q=0.01  0.967773         Gaussian
# 3              3  83.csv    ES q=0.05  0.968262         Gaussian
# 4              4  83.csv   VaR q=0.01  0.976562         Gaussian
# ...          ...     ...          ...       ...              ...
# 4219         523  71.csv     ERM k=10  0.952051  Gauss Mix Indep
# 4220         524  71.csv    ES q=0.01  0.823340  Gauss Mix Indep
# 4221         525  71.csv    ES q=0.05  0.947266  Gauss Mix Indep
# 4222         526  71.csv   VaR q=0.01  0.950391  Gauss Mix Indep
# 4223         527  71.csv   VaR q=0.05  0.964063  Gauss Mix Indep
#
# [4224 rows x 5 columns]

# %%
h_arr = [x for x in os.listdir('../../_mathematica/data_CRIX/') if x.endswith('_h.csv')]
# pd.read_csv('../../_mathematica/data_CRIX/'+h_arr[0])
h_arr
# Out:
# ['73_h.csv',
#  '36_h.csv',
#  '57_h.csv',
#  '12_h.csv',
#  '68_h.csv',
#  '55_h.csv',
#  '10_h.csv',
#  '71_h.csv',
#  '34_h.csv',
#  '75_h.csv',
#  '30_h.csv',
#  '48_h.csv',
#  '29_h.csv',
#  '51_h.csv',
#  '14_h.csv',
#  '8_h.csv',
#  '53_h.csv',
#  '16_h.csv',
#  '77_h.csv',
#  '32_h.csv',
#  '11_h.csv',
#  '54_h.csv',
#  '69_h.csv',
#  '35_h.csv',
#  '70_h.csv',
#  '37_h.csv',
#  '72_h.csv',
#  '13_h.csv',
#  '56_h.csv',
#  '17_h.csv',
#  '52_h.csv',
#  '9_h.csv',
#  '33_h.csv',
#  '76_h.csv',
#  '49_h.csv',
#  '31_h.csv',
#  '74_h.csv',
#  '15_h.csv',
#  '50_h.csv',
#  '28_h.csv',
#  '61_h.csv',
#  '24_h.csv',
#  '19_h.csv',
#  '7_h.csv',
#  '85_h.csv',
#  '78_h.csv',
#  '45_h.csv',
#  '47_h.csv',
#  '87_h.csv',
#  '5_h.csv',
#  '63_h.csv',
#  '26_h.csv',
#  '1_h.csv',
#  '67_h.csv',
#  '22_h.csv',
#  '43_h.csv',
#  '83_h.csv',
#  '39_h.csv',
#  '81_h.csv',
#  '41_h.csv',
#  '65_h.csv',
#  '20_h.csv',
#  '3_h.csv',
#  '58_h.csv',
#  '86_h.csv',
#  '46_h.csv',
#  '27_h.csv',
# ...
