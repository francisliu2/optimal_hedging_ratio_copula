# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss
import seaborn as sns
import sys, os
sys.path.append('../../src/')
# import toolbox
from toolbox import *

result_names = ['BBT_Tiingo',                #0
                'BBT_future_Tiingo_ada', 
                'BBT_future_Tiingo_eth',     #2
                'BBT_future_Tiingo_ltc',
                'BBT_future_Tiingo_xrp',     #4
                'BBT_future_BITX',
                'BBT_future_BITW20',         #6
                'BBT_future_BITW70', 
                'BBT_future_BITW100',        #8
                'BBT_future_CRIX']

risk_measures = ['Variance',
                 'ES q=0.05', 'ES q=0.01',
                 'VaR q=0.05', 'VaR q=0.01', 
                 'ERM k=10', 'CH']

order = ['BBT_Tiingo',    
         'BBT_future_CRIX',  'BBT_future_BITX', 'BBT_future_BITW100', 
         'BBT_future_BITW20',  'BBT_future_BITW70',
         'BBT_future_Tiingo_ada', 'BBT_future_Tiingo_eth',  'BBT_future_Tiingo_ltc','BBT_future_Tiingo_xrp']

coin_names = ['btc', 'CRIX', 'BITX', 'BITW100', 'BITW20', 'BITW70', 'ada', 'eth', 'ltc', 'xrp']

# %%
from arch import arch_model
from arch.univariate import StudentsT
from copulae1 import *

# %%
rn = 'BBT_Tiingo'

path = '../../processed_data/%s/train/0.csv'%rn
df = pd.read_csv(path)

df.Date = pd.to_datetime(df.Date)
df = df.sort_values('Date')

rs = df.loc[:,'log return bitcoin']
rf = df.loc[:,'log return future']

am_rs = arch_model(list(rs), p=2, o=2, q=2, dist='studentst')
res_rs = am_rs.fit(update_freq=5, disp="off")

am_rf = arch_model(list(rf), p=2, o=2, q=2, dist='studentst')
res_rf = am_rf.fit(update_freq=5, disp="off")
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:312: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001796. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   data_scale_warning.format(orig_scale, rescale), DataScaleWarning
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/arch/univariate/base.py:312: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.001992. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 10 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   data_scale_warning.format(orig_scale, rescale), DataScaleWarning

# %%
train_path = '../../processed_data/%s/train/'%rn
test_path = '../../processed_data/%s/train/'%rn

files = [f for f in os.listdir(train_path) if f.endswith('.csv')]

files = list(pd.DataFrame(files, index=[int(f.replace('.csv', '')) for f in files])\
.sort_index().loc[:,0])

# %%
import scipy.stats
# res_rs.params.nu


test_results = []

for f in files:
    print(f)
# fit GJR-GARCH
    path = '../../processed_data/%s/train/%s'%(rn, f)
    df = pd.read_csv(path)
    
    df.Date = pd.to_datetime(df.Date)
    df = df.sort_values('Date')

    rs = df.loc[:,'log return bitcoin']*100
    rf = df.loc[:,'log return future']*100

    am_rs = arch_model(list(rs), p=1, o=1, q=1, dist='studentst')
    res_rs = am_rs.fit(update_freq=0, disp="off")

    am_rf = arch_model(list(rf), p=1, o=1, q=1, dist='studentst')
    res_rf = am_rf.fit(update_freq=0, disp="off")

    u = []
    v = []

    CV_rs = res_rs.conditional_volatility
    nu_rs = res_rs.params.nu
    mu_rs = res_rs.params.mu

    CV_rf = res_rf.conditional_volatility
    nu_rf = res_rf.params.nu
    mu_rf = res_rf.params.mu

    for i in range(len(CV_rf)):
#         if i == len(CV_rf)-1:
#             break
        u.append(stats.t(df=nu_rs, scale=np.sqrt(CV_rs[i])).cdf(rs[i]-mu_rs))
        v.append(stats.t(df=nu_rf, scale=np.sqrt(CV_rf[i])).cdf(rf[i]-mu_rf))

    u_ecdf = ECDF(rs)(rs)
    v_ecdf = ECDF(rf)(rf)

#     C_GARCH = Gaussian({'rho':0.8}, stats.uniform, stats.uniform)
    C_GARCH = t_Copula({'rho':0.8, 'nu':4}, stats.uniform, stats.uniform, nu_lowerbound=2)
    C_GARCH.canonical_calibrate(u,v)

    C_ECDF = t_Copula({'rho':0.8, 'nu':4}, stats.uniform, stats.uniform, nu_lowerbound=2)
    C_ECDF.canonical_calibrate(u_ecdf,v_ecdf)


    # samples
    samples_GARCH = C_GARCH.sample(1000)
    samples_ECDF  = C_ECDF.sample(1000)

    samples_GARCH[:,0] = stats.t(df=nu_rs, scale=np.sqrt(CV_rs[-1])).ppf(samples_GARCH[:,0])\
                            +mu_rs
    samples_GARCH[:,1] = stats.t(df=nu_rf, scale=np.sqrt(CV_rf[-1])).ppf(samples_GARCH[:,1])\
                            +mu_rf

    samples_ECDF[:,0] = np.quantile(rs, samples_ECDF[:,0])
    samples_ECDF[:,1] = np.quantile(rf, samples_ECDF[:,1])

    h_arr = np.linspace(0.5,1.5,1000)

    var_GARCH = []
    var_ECDF = []

    for h in h_arr:
        var_GARCH.append(np.var(samples_GARCH[:,0] - h*samples_GARCH[:,1]))
        var_ECDF.append(np.var(samples_ECDF[:,0] - h*samples_ECDF[:,1]))

    h_GARCH = h_arr[np.argmin(var_GARCH)]
    h_ECDF = h_arr[np.argmin(var_ECDF)]

    print(h_GARCH, h_ECDF)
    
    test_path =  '../../processed_data/%s/test/%s'%(rn, f)
    test      =  pd.read_csv(test_path)
    
    rs_test = test.loc[:, 'log return bitcoin']
    rf_test = test.loc[:, 'log return future']

    test.loc[:, 'h_GARCH'] = h_GARCH
    test.loc[:, 'h_ECDF'] = h_ECDF

    test.loc[:,'rh_GARCH'] = rs_test-h_GARCH*rf_test
    test.loc[:,'rh_ECDF'] = rs_test-h_ECDF*rf_test
    test_results.append(test)
print("DONE")
# Out:
# 0.csv
# Optimization terminated successfully.
#          Current function value: -779.541393
#          Iterations: 93
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: -775.179209
#          Iterations: 97
#          Function evaluations: 213
# 1.0155155155155156 0.9414414414414414
# 1.csv
# Optimization terminated successfully.
#          Current function value: -792.884930
#          Iterations: 95
#          Function evaluations: 206
# Optimization terminated successfully.
#          Current function value: -772.762123
#          Iterations: 91
#          Function evaluations: 199
# 0.9954954954954955 0.9494494494494494
# 2.csv
# Optimization terminated successfully.
#          Current function value: -779.505530
#          Iterations: 94
#          Function evaluations: 205
# Optimization terminated successfully.
#          Current function value: -765.219085
#          Iterations: 86
#          Function evaluations: 188
# 0.9964964964964965 0.9534534534534534
# 3.csv
# Optimization terminated successfully.
#          Current function value: -777.246106
#          Iterations: 93
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: -760.551005
#          Iterations: 88
#          Function evaluations: 192
# 0.9834834834834835 0.9614614614614614
# 4.csv
# Optimization terminated successfully.
#          Current function value: -763.339605
#          Iterations: 92
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: -756.822267
#          Iterations: 89
#          Function evaluations: 200
# 1.0035035035035036 0.9464464464464464
# 5.csv
# Optimization terminated successfully.
#          Current function value: -734.319533
#          Iterations: 90
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: -752.084853
#          Iterations: 96
#          Function evaluations: 206
# 0.9924924924924925 0.9434434434434434
# 6.csv
# Optimization terminated successfully.
#          Current function value: -738.123449
#          Iterations: 88
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: -747.646360
#          Iterations: 97
#          Function evaluations: 212
# 1.0045045045045045 0.9554554554554555
# 7.csv
# Optimization terminated successfully.
#          Current function value: -738.499970
#          Iterations: 84
#          Function evaluations: 184
# Optimization terminated successfully.
#          Current function value: -754.745620
#          Iterations: 119
#          Function evaluations: 228
# 0.9994994994994995 0.9514514514514514
# 8.csv
# Optimization terminated successfully.
#          Current function value: -755.062164
#          Iterations: 92
#          Function evaluations: 194
# Optimization terminated successfully.
#          Current function value: -759.849856
#          Iterations: 134
#          Function evaluations: 260
# 1.0095095095095095 0.9604604604604605
# 9.csv
# Optimization terminated successfully.
#          Current function value: -773.703841
#          Iterations: 100
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: -759.250781
#          Iterations: 156
#          Function evaluations: 307
# 0.9884884884884885 0.9384384384384384
# 10.csv
# Optimization terminated successfully.
#          Current function value: -777.766347
#          Iterations: 81
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: -759.837539
#          Iterations: 126
#          Function evaluations: 247
# 0.9744744744744744 0.9484484484484484
# 11.csv
# Optimization terminated successfully.
#          Current function value: -776.834559
#          Iterations: 101
#          Function evaluations: 210
# Optimization terminated successfully.
#          Current function value: -751.504898
#          Iterations: 144
#          Function evaluations: 269
# 0.9534534534534534 0.9534534534534534
# 12.csv
# Optimization terminated successfully.
#          Current function value: -771.369275
#          Iterations: 96
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: -757.014539
#          Iterations: 140
#          Function evaluations: 267
# 1.0035035035035036 0.9474474474474475
# 13.csv
# Optimization terminated successfully.
#          Current function value: -755.482193
#          Iterations: 89
#          Function evaluations: 185
# Optimization terminated successfully.
#          Current function value: -757.486810
#          Iterations: 135
#          Function evaluations: 252
# 1.0245245245245245 0.9544544544544544
# 14.csv
# Optimization terminated successfully.
#          Current function value: -748.769159
#          Iterations: 93
#          Function evaluations: 207
# Optimization terminated successfully.
#          Current function value: -761.335577
#          Iterations: 154
#          Function evaluations: 295
# 1.0065065065065064 0.9464464464464464
# 15.csv
# Optimization terminated successfully.
#          Current function value: -759.703901
#          Iterations: 90
#          Function evaluations: 200
# Optimization terminated successfully.
#          Current function value: -751.541190
#          Iterations: 138
#          Function evaluations: 252
# 0.9884884884884885 0.9444444444444444
# 16.csv
# Optimization terminated successfully.
#          Current function value: -770.959070
#          Iterations: 87
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: -752.685734
#          Iterations: 141
#          Function evaluations: 267
# 1.0585585585585586 0.9464464464464464
# 17.csv
# Optimization terminated successfully.
#          Current function value: -766.843129
#          Iterations: 96
#          Function evaluations: 202
# Optimization terminated successfully.
#          Current function value: -752.072273
#          Iterations: 133
#          Function evaluations: 251
# 1.0045045045045045 0.9474474474474475
# 18.csv
# Optimization terminated successfully.
#          Current function value: -749.551517
#          Iterations: 81
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: -745.033424
#          Iterations: 138
#          Function evaluations: 258
# 1.0155155155155156 0.9444444444444444
# 19.csv
# Optimization terminated successfully.
#          Current function value: -744.011574
#          Iterations: 98
#          Function evaluations: 209
# Optimization terminated successfully.
#          Current function value: -743.715120
#          Iterations: 142
#          Function evaluations: 275
# 0.9634634634634635 0.9404404404404405
# 20.csv
# Optimization terminated successfully.
#          Current function value: -751.018854
#          Iterations: 102
#          Function evaluations: 224
# Optimization terminated successfully.
#          Current function value: -745.882912
#          Iterations: 162
#          Function evaluations: 300
# 0.9544544544544544 0.9504504504504505
# 21.csv
# Optimization terminated successfully.
#          Current function value: -758.544834
#          Iterations: 101
#          Function evaluations: 218
# Optimization terminated successfully.
#          Current function value: -754.416526
#          Iterations: 141
#          Function evaluations: 266
# 0.9274274274274275 0.9384384384384384
# 22.csv
# Optimization terminated successfully.
#          Current function value: -758.931694
#          Iterations: 94
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: -752.676894
#          Iterations: 137
#          Function evaluations: 260
# 0.8643643643643644 0.9394394394394394
# 23.csv
# Optimization terminated successfully.
#          Current function value: -758.090930
#          Iterations: 102
#          Function evaluations: 216
# Optimization terminated successfully.
#          Current function value: -754.798457
#          Iterations: 150
#          Function evaluations: 283
# 0.9904904904904905 0.9384384384384384
# 24.csv
# Optimization terminated successfully.
#          Current function value: -761.318610
#          Iterations: 152
#          Function evaluations: 287
# Optimization terminated successfully.
#          Current function value: -746.074876
#          Iterations: 115
#          Function evaluations: 224
# 0.9024024024024024 0.9434434434434434
# 25.csv
# Optimization terminated successfully.
#          Current function value: -739.079267
#          Iterations: 104
#          Function evaluations: 223
# Optimization terminated successfully.
#          Current function value: -742.065618
#          Iterations: 138
#          Function evaluations: 257
# 0.9654654654654655 0.9354354354354355
# 26.csv
# Optimization terminated successfully.
#          Current function value: -739.914545
#          Iterations: 97
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: -738.666002
#          Iterations: 179
#          Function evaluations: 336
# 0.9764764764764764 0.9384384384384384
# 27.csv
# Optimization terminated successfully.
#          Current function value: -729.685549
#          Iterations: 95
#          Function evaluations: 207
# Optimization terminated successfully.
#          Current function value: -740.732530
#          Iterations: 154
#          Function evaluations: 284
# 1.0115115115115114 0.9424424424424425
# 28.csv
# Optimization terminated successfully.
#          Current function value: -747.006149
#          Iterations: 109
#          Function evaluations: 216
# Optimization terminated successfully.
#          Current function value: -741.895261
#          Iterations: 188
#          Function evaluations: 362
# 1.0085085085085086 0.9384384384384384
# 29.csv
# Optimization terminated successfully.
#          Current function value: -751.821266
#          Iterations: 134
#          Function evaluations: 255
# Optimization terminated successfully.
#          Current function value: -742.583401
#          Iterations: 142
#          Function evaluations: 266
# 1.0465465465465464 0.9444444444444444
# 30.csv
# Optimization terminated successfully.
#          Current function value: -747.156134
#          Iterations: 132
#          Function evaluations: 249
# Optimization terminated successfully.
#          Current function value: -743.761415
#          Iterations: 145
#          Function evaluations: 276
# 0.9714714714714714 0.9444444444444444
# 31.csv
# Optimization terminated successfully.
#          Current function value: -747.519688
#          Iterations: 102
#          Function evaluations: 216
# Optimization terminated successfully.
#          Current function value: -744.701652
#          Iterations: 164
#          Function evaluations: 306
# 0.9824824824824825 0.9424424424424425
# 32.csv
# Optimization terminated successfully.
#          Current function value: -688.158343
#          Iterations: 93
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: -731.706429
#          Iterations: 142
#          Function evaluations: 267
# 1.0175175175175175 0.9354354354354355
# 33.csv
# Optimization terminated successfully.
#          Current function value: -741.250556
#          Iterations: 141
#          Function evaluations: 262
# Optimization terminated successfully.
#          Current function value: -738.446430
#          Iterations: 134
#          Function evaluations: 265
# 0.8843843843843844 0.9374374374374375
# 34.csv
# Optimization terminated successfully.
#          Current function value: -737.497122
#          Iterations: 98
#          Function evaluations: 208
# Warning: Maximum number of function evaluations has been exceeded.
# 0.9824824824824825 0.9444444444444444
# 35.csv
# Optimization terminated successfully.
#          Current function value: -746.247837
#          Iterations: 115
#          Function evaluations: 221
# Optimization terminated successfully.
#          Current function value: -743.712981
#          Iterations: 141
#          Function evaluations: 268
# 0.9424424424424425 0.9414414414414414
# 36.csv
# Optimization terminated successfully.
#          Current function value: -716.102949
#          Iterations: 95
#          Function evaluations: 209
# Optimization terminated successfully.
#          Current function value: -746.329036
#          Iterations: 147
#          Function evaluations: 280
# 1.0255255255255256 0.9534534534534534
# 37.csv
# Optimization terminated successfully.
#          Current function value: -750.345267
#          Iterations: 91
#          Function evaluations: 191
# Optimization terminated successfully.
#          Current function value: -754.963893
#          Iterations: 138
#          Function evaluations: 263
# 0.9874874874874875 0.9654654654654655
# 38.csv
# Optimization terminated successfully.
#          Current function value: -743.077712
#          Iterations: 81
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: -754.300837
#          Iterations: 147
#          Function evaluations: 277
# 1.0455455455455456 0.9634634634634635
# 39.csv
# Optimization terminated successfully.
#          Current function value: -727.833570
#          Iterations: 92
#          Function evaluations: 204
# Optimization terminated successfully.
#          Current function value: -753.912029
#          Iterations: 146
#          Function evaluations: 277
# 1.0145145145145145 0.9674674674674675
# 40.csv
# Optimization terminated successfully.
#          Current function value: -748.919331
#          Iterations: 87
#          Function evaluations: 193
# Optimization terminated successfully.
#          Current function value: -752.261619
#          Iterations: 117
#          Function evaluations: 228
# 1.0115115115115114 0.9624624624624625
# 41.csv
# Optimization terminated successfully.
#          Current function value: -756.028812
#          Iterations: 108
#          Function evaluations: 233
# Optimization terminated successfully.
#          Current function value: -760.416687
#          Iterations: 128
#          Function evaluations: 244
# 1.0105105105105106 0.9684684684684685
# 42.csv
# Optimization terminated successfully.
#          Current function value: -763.810956
#          Iterations: 97
#          Function evaluations: 209
# Optimization terminated successfully.
#          Current function value: -772.569147
#          Iterations: 142
#          Function evaluations: 273
# 1.0035035035035036 0.9724724724724725
# 43.csv
# Optimization terminated successfully.
#          Current function value: -751.925131
#          Iterations: 146
#          Function evaluations: 275
# Optimization terminated successfully.
#          Current function value: -767.416754
#          Iterations: 171
#          Function evaluations: 329
# 1.0245245245245245 0.9554554554554555
# 44.csv
# Optimization terminated successfully.
#          Current function value: -721.067347
#          Iterations: 104
#          Function evaluations: 223
# Optimization terminated successfully.
#          Current function value: -753.002059
#          Iterations: 125
#          Function evaluations: 234
# 0.9864864864864864 0.9624624624624625
# 45.csv
# Optimization terminated successfully.
#          Current function value: -673.954397
#          Iterations: 79
#          Function evaluations: 172
# Optimization terminated successfully.
#          Current function value: -731.434448
#          Iterations: 140
#          Function evaluations: 266
# 1.1816816816816815 0.9634634634634635
# 46.csv
# Optimization terminated successfully.
#          Current function value: -663.408887
#          Iterations: 84
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: -735.807448
#          Iterations: 142
#          Function evaluations: 270
# 1.0295295295295295 0.9554554554554555
# 47.csv
# Optimization terminated successfully.
#          Current function value: -660.949502
#          Iterations: 90
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: -737.302534
#          Iterations: 168
#          Function evaluations: 312
# 1.1146146146146148 0.9664664664664664
# 48.csv
# Optimization terminated successfully.
#          Current function value: -725.797855
#          Iterations: 179
#          Function evaluations: 342
# Warning: Maximum number of function evaluations has been exceeded.
# 1.1356356356356356 0.9564564564564564
# 49.csv
# Optimization terminated successfully.
#          Current function value: -742.670832
#          Iterations: 139
#          Function evaluations: 264
# Optimization terminated successfully.
#          Current function value: -741.003382
#          Iterations: 159
#          Function evaluations: 298
# 0.8883883883883884 0.9654654654654655
# 50.csv
# Optimization terminated successfully.
#          Current function value: -734.768336
#          Iterations: 120
#          Function evaluations: 236
# Optimization terminated successfully.
#          Current function value: -736.006810
#          Iterations: 144
#          Function evaluations: 276
# 1.0455455455455456 0.9624624624624625
# 51.csv
# Optimization terminated successfully.
#          Current function value: -728.940414
#          Iterations: 159
#          Function evaluations: 299
# Optimization terminated successfully.
#          Current function value: -732.299295
#          Iterations: 159
#          Function evaluations: 301
# 0.9814814814814814 0.9644644644644644
# 52.csv
# Optimization terminated successfully.
#          Current function value: -729.390399
#          Iterations: 123
#          Function evaluations: 238
# Optimization terminated successfully.
#          Current function value: -725.854679
#          Iterations: 167
#          Function evaluations: 304
# 0.9194194194194194 0.9704704704704705
# 53.csv
# Optimization terminated successfully.
#          Current function value: -705.669264
#          Iterations: 109
#          Function evaluations: 212
# Optimization terminated successfully.
#          Current function value: -727.429070
#          Iterations: 157
#          Function evaluations: 292
# 1.0885885885885886 0.9604604604604605
# 54.csv
# Optimization terminated successfully.
#          Current function value: -684.581341
#          Iterations: 95
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: -729.503382
#          Iterations: 152
#          Function evaluations: 290
# 0.9354354354354355 0.9484484484484484
# 55.csv
# Optimization terminated successfully.
#          Current function value: -705.572973
#          Iterations: 149
#          Function evaluations: 274
# Optimization terminated successfully.
#          Current function value: -715.674677
#          Iterations: 165
#          Function evaluations: 312
# 0.9824824824824825 0.9614614614614614
# 56.csv
# Optimization terminated successfully.
#          Current function value: -672.675180
#          Iterations: 92
#          Function evaluations: 197
# Optimization terminated successfully.
#          Current function value: -706.780176
#          Iterations: 126
#          Function evaluations: 249
# 1.0645645645645647 0.9604604604604605
# 57.csv
# Optimization terminated successfully.
#          Current function value: -678.749746
#          Iterations: 83
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: -705.182932
#          Iterations: 206
#          Function evaluations: 388
# 0.9424424424424425 0.9664664664664664
# 58.csv
# Optimization terminated successfully.
#          Current function value: -660.462579
#          Iterations: 88
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: -690.711857
#          Iterations: 115
#          Function evaluations: 222
# 1.1796796796796798 0.9624624624624625
# 59.csv
# Optimization terminated successfully.
#          Current function value: -683.230202
#          Iterations: 134
#          Function evaluations: 255
# Optimization terminated successfully.
#          Current function value: -681.929510
#          Iterations: 145
#          Function evaluations: 266
# 1.1426426426426426 0.9544544544544544
# 60.csv
# Optimization terminated successfully.
#          Current function value: -668.398210
#          Iterations: 150
#          Function evaluations: 272
# Optimization terminated successfully.
#          Current function value: -661.105036
#          Iterations: 152
#          Function evaluations: 293
# 0.5 0.9664664664664664
# 61.csv
# Optimization terminated successfully.
#          Current function value: -581.277131
#          Iterations: 78
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: -638.326629
#          Iterations: 109
#          Function evaluations: 212
# 1.2967967967967968 0.9724724724724725
# 62.csv
# Optimization terminated successfully.
#          Current function value: -588.113207
#          Iterations: 89
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: -629.832701
#          Iterations: 139
#          Function evaluations: 264
# 1.0645645645645647 0.9654654654654655
# 63.csv
# Optimization terminated successfully.
#          Current function value: -591.076989
#          Iterations: 90
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: -630.630692
#          Iterations: 144
#          Function evaluations: 273
# 1.1636636636636637 0.9634634634634635
# 64.csv
# Optimization terminated successfully.
#          Current function value: -571.550287
#          Iterations: 89
#          Function evaluations: 189
# Optimization terminated successfully.
#          Current function value: -629.725044
#          Iterations: 143
#          Function evaluations: 272
# 0.9564564564564564 0.9724724724724725
# 65.csv
# Optimization terminated successfully.
#          Current function value: -608.401592
#          Iterations: 161
#          Function evaluations: 308
# Optimization terminated successfully.
#          Current function value: -616.087820
#          Iterations: 116
#          Function evaluations: 222
# 1.1616616616616615 0.9754754754754755
# 66.csv
# Optimization terminated successfully.
#          Current function value: -603.586348
#          Iterations: 148
#          Function evaluations: 279
# Optimization terminated successfully.
#          Current function value: -618.739867
#          Iterations: 143
#          Function evaluations: 267
# 1.0575575575575575 0.9634634634634635
# 67.csv
# Optimization terminated successfully.
#          Current function value: -603.558033
#          Iterations: 147
#          Function evaluations: 279
# Optimization terminated successfully.
#          Current function value: -611.781935
#          Iterations: 105
#          Function evaluations: 207
# 1.2327327327327327 0.9664664664664664
# 68.csv
# Optimization terminated successfully.
#          Current function value: -597.606477
#          Iterations: 190
#          Function evaluations: 360
# Optimization terminated successfully.
#          Current function value: -605.372893
#          Iterations: 147
#          Function evaluations: 276
# 1.0775775775775776 0.9534534534534534
# 69.csv
# Optimization terminated successfully.
#          Current function value: -605.959272
#          Iterations: 138
#          Function evaluations: 254
# Optimization terminated successfully.
#          Current function value: -601.552296
#          Iterations: 125
#          Function evaluations: 238
# 0.9844844844844844 0.9714714714714714
# 70.csv
# Optimization terminated successfully.
#          Current function value: -593.230683
#          Iterations: 145
#          Function evaluations: 272
# Optimization terminated successfully.
#          Current function value: -596.101593
#          Iterations: 156
#          Function evaluations: 295
# 0.9074074074074074 0.9604604604604605
# 71.csv
# Optimization terminated successfully.
#          Current function value: -588.303031
#          Iterations: 159
#          Function evaluations: 306
# Optimization terminated successfully.
#          Current function value: -581.457130
#          Iterations: 147
#          Function evaluations: 275
# 0.9934934934934935 0.9704704704704705
# 72.csv
# Optimization terminated successfully.
#          Current function value: -555.862076
#          Iterations: 119
#          Function evaluations: 227
# Optimization terminated successfully.
#          Current function value: -568.161896
#          Iterations: 153
#          Function evaluations: 292
# 0.9434434434434434 0.9534534534534534
# 73.csv
# Optimization terminated successfully.
#          Current function value: -536.507940
#          Iterations: 97
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: -567.358885
#          Iterations: 133
#          Function evaluations: 255
# 1.3138138138138138 0.9534534534534534
# 74.csv
# Optimization terminated successfully.
#          Current function value: -526.678006
#          Iterations: 76
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: -564.632207
#          Iterations: 143
#          Function evaluations: 269
# 1.0025025025025025 0.9794794794794794
# 75.csv
# Optimization terminated successfully.
#          Current function value: -529.713529
#          Iterations: 78
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: -562.033433
#          Iterations: 156
#          Function evaluations: 297
# 1.0265265265265264 0.9724724724724725
# 76.csv
# Optimization terminated successfully.
#          Current function value: -527.672232
#          Iterations: 83
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: -561.843446
#          Iterations: 149
#          Function evaluations: 282
# 1.0295295295295295 0.9684684684684685
# 77.csv
# Optimization terminated successfully.
#          Current function value: -527.972331
#          Iterations: 80
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: -562.270785
#          Iterations: 130
#          Function evaluations: 251
# 1.0635635635635636 0.9714714714714714
# 78.csv
# Optimization terminated successfully.
#          Current function value: -529.556314
#          Iterations: 74
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: -563.733944
#          Iterations: 155
#          Function evaluations: 283
# 1.0445445445445445 0.9684684684684685
# 79.csv
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-230-a3a73007e997> in <module>
#      46 #     C_GARCH = Gaussian({'rho':0.8}, stats.uniform, stats.uniform)
#      47     C_GARCH = t_Copula({'rho':0.8, 'nu':4}, stats.uniform, stats.uniform, nu_lowerbound=2)
# ---> 48     C_GARCH.canonical_calibrate(u,v)
#      49
#      50     C_ECDF = t_Copula({'rho':0.8, 'nu':4}, stats.uniform, stats.uniform, nu_lowerbound=2)
#
# ~/Google Drive/00_IRTG1792/copula/src/copulae1.py in canonical_calibrate(self, u, v)
#     271                                                                          xtol=1e-10,
#     272                                                                          maxiter=5000,
# --> 273 									 maxfun=400)
#     274                 self.rho = result[0]
#     275                 self.nu = result[1]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     441             'initial_simplex': initial_simplex}
#     442
# --> 443     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     444     if full_output:
#     445         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     600         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     601         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 602         fxr = func(xr)
#     603         doshrink = 0
#     604
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/Google Drive/00_IRTG1792/copula/src/copulae1.py in <lambda>(theta)
#     267
#     268         def canonical_calibrate(self, u, v):
# --> 269                 fn_toopt = lambda theta: -self.l_fn(theta[0], theta[1], u, v, self.nu_lowerbound)
#     270 		result = scipy.optimize.fmin(fn_toopt, x0=(self.rho, self.nu),
#     271                                                                          xtol=1e-10,
#
# ~/Google Drive/00_IRTG1792/copula/src/copulae1.py in l_fn(self, rho, nu, u, v, nu_lowerbound)
#     245 		_meta_t = multivariate_t(nu=nu,  # DF
#     246 								 Sigma=np.array([[1, rho],  # COV
# --> 247 												 [rho, 1]]))
#     248
#     249                 _t1 = stats.t(df=nu)
#
# ~/Google Drive/00_IRTG1792/copula/src/toolbox.py in __init__(self, nu, Sigma)
#      26                         return print("Sigma must be a square matrix")
#      27 		self.MN = stats.multivariate_normal([0, 0],  # for cdf approximation use
# ---> 28                                             Sigma)
#      29
#      30         def pdf(self, *argv):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/_multivariate.py in __call__(self, mean, cov, allow_singular, seed)
#     361         return multivariate_normal_frozen(mean, cov,
#     362                                           allow_singular=allow_singular,
# --> 363                                           seed=seed)
#     364
#     365     def _process_parameters(self, dim, mean, cov):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/_multivariate.py in __init__(self, mean, cov, allow_singular, seed, maxpts, abseps, releps)
#     734         self.dim, self.mean, self.cov = self._dist._process_parameters(
#     735                                                             None, mean, cov)
# --> 736         self.cov_info = _PSD(self.cov, allow_singular=allow_singular)
#     737         if not maxpts:
#     738             maxpts = 1000000 * self.dim
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/_multivariate.py in __init__(self, M, cond, rcond, lower, check_finite, allow_singular)
#     161         d = s[s > eps]
#     162         if len(d) < len(s) and not allow_singular:
# --> 163             raise np.linalg.LinAlgError('singular matrix')
#     164         s_pinv = _pinv_1d(s, eps)
#     165         U = np.multiply(u, np.sqrt(s_pinv))
#
# LinAlgError: singular matrix

# %%
h_arr = np.linspace(0.5,1.5,1000)

var_GARCH = []
var_ECDF = []

for h in h_arr:
    var_GARCH.append(np.var(samples_GARCH[:,0] - h*samples_GARCH[:,1]))
    var_ECDF.append(np.var(samples_ECDF[:,0] - h*samples_ECDF[:,1]))

h_GARCH = h_arr[np.argmin(var_GARCH)]
h_ECDF = h_arr[np.argmin(var_ECDF)]


plt.plot(h_arr, var_GARCH)
plt.plot(h_arr, var_ECDF)

# %%
print(nu_rs, nu_rf)
# Out:
# 2.567452758436798 2.680377426467978

# %%
print(mu_rs, mu_rf)
# Out:
# 0.08732707334008115 0.11267624835440294

# %%
plt.figure(figsize=(5,5))
plt.scatter(samples_GARCH[:,0], samples_GARCH[:,1], marker='x')
plt.scatter(samples_ECDF[:,0], samples_ECDF[:,1], marker='x')

# %%
sns.distplot(samples_GARCH[:,1])
sns.distplot(samples_ECDF[:,1])
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(5,5))
plt.scatter(u, v)
plt.scatter(u_ecdf, v_ecdf)

# plt.scatter(samples_ECDF[:,0], samples_ECDF[:,1])

# %%
results = pd.concat(test_results)
results.Date = pd.to_datetime(results.Date)
results = results.sort_values('Date')

# %%
sns.distplot(results.rh_GARCH)
sns.distplot(results.rh_ECDF)
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(np.mean(results.rh_GARCH),
      np.mean(results.rh_ECDF))
# Out:
# 0.0008681879857543307 0.00023436646365282917

# %%
print(np.std(results.rh_GARCH),
      np.std(results.rh_ECDF))
# Out:
# 0.008860675992492368 0.003224941957931821

# %%
print(np.mean(results.rh_GARCH)/np.std(results.rh_GARCH),
      np.mean(results.rh_ECDF)/np.std(results.rh_ECDF))
# Out:
# 0.09798213888984819 0.07267307961199095

# %%
print(-np.quantile(results.rh_GARCH, 0.05),
      -np.quantile(results.rh_ECDF, 0.05))
# Out:
# 0.007861567697277942 0.005954220036701558

# %%
plt.plot(results.Date, results.h_GARCH)
plt.plot(results.Date, results.h_ECDF)

# %%
path = '../../data/cleaned_data/BBT_Tiingo.csv'
# path = '../../data/cleaned_data/BBT_future_Tiingo_eth.csv'
df = pd.read_csv(path)
df.Date = pd.to_datetime(df.Date)
df = df.sort_values('Date')
df.reset_index(drop=True, inplace=True)

train_size = int(np.floor(len(df)*2/3))
test_size = train_size
train = df.iloc[:train_size]
test = df.iloc[train_size:]

print(len(train))
# Out:
# 578

# %%
h_GARCH_arr = []
h_ECDF_arr = []


block_size = 100

for i in range(block_size, len(train)):
    print(i)
    rs = np.array(train.iloc[i-block_size:i, :].loc[:, 'log return bitcoin']*1000)
    rf = np.array(train.iloc[i-block_size:i, :].loc[:, 'log return future']*1000)
    
    am_rs = arch_model(rs, p=1, o=1, q=1, dist='studentst')
    res_rs = am_rs.fit(update_freq=0, disp="off")

    am_rf = arch_model(rf, p=1, o=1, q=1, dist='studentst')
    res_rf = am_rf.fit(update_freq=0, disp="off")

    u = []
    v = []

    CV_rs = res_rs.conditional_volatility
    nu_rs = res_rs.params.nu
    mu_rs = res_rs.params.mu

    CV_rf = res_rf.conditional_volatility
    nu_rf = res_rf.params.nu
    mu_rf = res_rf.params.mu

    for i in range(len(CV_rf)):
        if i == len(CV_rf)-1:
            break
        u.append(stats.t(df=nu_rs, scale=np.sqrt(CV_rs[i])).cdf(rs[i+1]-mu_rs))
        v.append(stats.t(df=nu_rf, scale=np.sqrt(CV_rf[i])).cdf(rf[i+1]-mu_rf))

    u_ecdf = ECDF(rs)(rs)
    v_ecdf = ECDF(rf)(rf)

#     C_GARCH = rot180Gumbel({'theta':1.1}, stats.uniform, stats.uniform)
    C_GARCH = Gaussian({'rho':0.8}, stats.uniform, stats.uniform)
   #, q_arr=[0.05,0.1,0.9,0.95])
#     C_GARCH = t_Copula({'rho':0.8, 'nu':4}, stats.uniform, stats.uniform, nu_lowerbound=2)
    C_GARCH.canonical_calibrate(np.array(u), np.array(v))

    C_ECDF = Gaussian({'rho':0.8}, stats.uniform, stats.uniform)
#     C_ECDF = rot180Gumbel({'theta':1.1}, stats.uniform, stats.uniform)

#     C_ECDF = t_Copula({'rho':0.8, 'nu':4}, stats.uniform, stats.uniform, nu_lowerbound=2)
    C_ECDF.canonical_calibrate(np.array(u_ecdf), np.array(v_ecdf) )

    # samples
    samples_GARCH = C_GARCH.sample(1000)
    samples_ECDF  = C_ECDF.sample(1000)

    samples_GARCH[:,0] = stats.t(df=nu_rs, scale=np.sqrt(CV_rs[-1])).ppf(samples_GARCH[:,0])\
                            +mu_rs
    samples_GARCH[:,1] = stats.t(df=nu_rf, scale=np.sqrt(CV_rf[-1])).ppf(samples_GARCH[:,1])\
                            +mu_rf

    samples_ECDF[:,0] = np.quantile(rs, samples_ECDF[:,0])
    samples_ECDF[:,1] = np.quantile(rf, samples_ECDF[:,1])

    h_arr = np.linspace(0.8,1.2,1000)

    var_GARCH = []
    var_ECDF = []

    for h in h_arr:
        var_GARCH.append(np.var(samples_GARCH[:,0] - h*samples_GARCH[:,1]))
        var_ECDF.append(np.var(samples_ECDF[:,0] - h*samples_ECDF[:,1]))

    h_GARCH = h_arr[np.argmin(var_GARCH)]
    h_ECDF = h_arr[np.argmin(var_ECDF)]
    
    h_GARCH_arr.append(h_GARCH)
    h_ECDF_arr.append(h_ECDF)
    print('%.4f %.4f' %(h_GARCH, h_ECDF))
    
print('Done!')
# Out:
# 100
# Optimization terminated successfully.
#          Current function value: -723.465413
#          Iterations: 32
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -168.066354
#          Iterations: 35
#          Function evaluations: 72
# 0.9385 0.9718
# 101
# Optimization terminated successfully.
#          Current function value: -710.416890
#          Iterations: 31
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -225.862953
#          Iterations: 36
#          Function evaluations: 73
# 0.9506 0.9950
# 102
# Optimization terminated successfully.
#          Current function value: -705.467806
#          Iterations: 31
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -226.044885
#          Iterations: 36
#          Function evaluations: 72
# 0.9349 0.9758
# 103
# Optimization terminated successfully.
#          Current function value: -730.679409
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -226.761296
#          Iterations: 36
#          Function evaluations: 73
# 0.8865 0.9902
# 104
# Optimization terminated successfully.
#          Current function value: -683.726532
#          Iterations: 31
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -224.911152
#          Iterations: 36
#          Function evaluations: 73
# 0.9277 1.0002
# 105
# Optimization terminated successfully.
#          Current function value: -656.358531
#          Iterations: 32
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -225.562900
#          Iterations: 36
#          Function evaluations: 73
# 0.9481 0.9942
# 106
# Optimization terminated successfully.
#          Current function value: -609.009790
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -229.531895
#          Iterations: 36
#          Function evaluations: 73
# 0.9766 0.9946
# 107
# Optimization terminated successfully.
#          Current function value: -605.151445
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -229.234724
#          Iterations: 36
#          Function evaluations: 72
# 0.9722 1.0010
# 108
# Optimization terminated successfully.
#          Current function value: -619.226760
#          Iterations: 33
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -228.841261
#          Iterations: 36
#          Function evaluations: 73
# 0.9710 1.0022
# 109
# Optimization terminated successfully.
#          Current function value: -625.502005
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -228.637361
#          Iterations: 36
#          Function evaluations: 73
# 0.9598 0.9986
# 110
# Optimization terminated successfully.
#          Current function value: -654.412971
#          Iterations: 33
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -229.045250
#          Iterations: 36
#          Function evaluations: 73
# 0.9365 0.9946
# 111
# Optimization terminated successfully.
#          Current function value: -693.466468
#          Iterations: 32
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -228.975026
#          Iterations: 36
#          Function evaluations: 73
# 0.9329 0.9998
# 112
# Optimization terminated successfully.
#          Current function value: -736.247817
#          Iterations: 32
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -230.108175
#          Iterations: 36
#          Function evaluations: 72
# 0.9445 1.0046
# 113
# Optimization terminated successfully.
#          Current function value: -682.211937
#          Iterations: 32
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -231.104631
#          Iterations: 36
#          Function evaluations: 73
# 0.9489 1.0050
# 114
# Optimization terminated successfully.
#          Current function value: -629.397780
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -227.327308
#          Iterations: 36
#          Function evaluations: 73
# 0.9429 1.0010
# 115
# Optimization terminated successfully.
#          Current function value: -674.401990
#          Iterations: 33
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -229.133113
#          Iterations: 36
#          Function evaluations: 72
# 0.9818 0.9994
# 116
# Optimization terminated successfully.
#          Current function value: -717.748286
#          Iterations: 33
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -228.531879
#          Iterations: 36
#          Function evaluations: 73
# 0.9241 0.9974
# 117
# Optimization terminated successfully.
#          Current function value: -706.029243
#          Iterations: 32
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -227.533116
#          Iterations: 36
#          Function evaluations: 73
# 0.9385 0.9982
# 118
# Optimization terminated successfully.
#          Current function value: -732.002649
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -229.726650
#          Iterations: 36
#          Function evaluations: 74
# 0.9077 0.9994
# 119
# Optimization terminated successfully.
#          Current function value: -796.349643
#          Iterations: 34
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -226.424795
#          Iterations: 36
#          Function evaluations: 72
# 0.9682 0.9874
# 120
# Optimization terminated successfully.
#          Current function value: -555.581599
#          Iterations: 33
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -237.779185
#          Iterations: 36
#          Function evaluations: 73
# 0.9702 0.9890
# 121
# Optimization terminated successfully.
#          Current function value: -534.011962
#          Iterations: 33
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -235.903074
#          Iterations: 37
#          Function evaluations: 74
# 0.9862 0.9902
# 122
# Optimization terminated successfully.
#          Current function value: -552.433216
#          Iterations: 33
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -236.325740
#          Iterations: 36
#          Function evaluations: 72
# 0.9782 0.9966
# 123
# Optimization terminated successfully.
#          Current function value: -515.956783
#          Iterations: 34
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -234.888784
#          Iterations: 37
#          Function evaluations: 76
# 0.9954 0.9894
# 124
# Optimization terminated successfully.
#          Current function value: -497.947293
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -232.871118
#          Iterations: 36
#          Function evaluations: 73
# 0.9974 0.9902
# 125
# Optimization terminated successfully.
#          Current function value: -533.078883
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -232.266829
#          Iterations: 36
#          Function evaluations: 72
# 1.0014 0.9850
# 126
# Optimization terminated successfully.
#          Current function value: -549.780556
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -233.618444
#          Iterations: 36
#          Function evaluations: 72
# 1.0086 0.9954
# 127
# Optimization terminated successfully.
#          Current function value: -552.338608
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -236.836575
#          Iterations: 36
#          Function evaluations: 73
# 1.0066 0.9890
# 128
# Optimization terminated successfully.
#          Current function value: -537.153459
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -238.016889
#          Iterations: 36
#          Function evaluations: 72
# 0.9898 0.9938
# 129
# Optimization terminated successfully.
#          Current function value: -540.144514
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -232.350212
#          Iterations: 36
#          Function evaluations: 72
# 0.9858 1.0010
# 130
# Optimization terminated successfully.
#          Current function value: -544.592291
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -234.505272
#          Iterations: 37
#          Function evaluations: 75
# 0.9726 0.9946
# 131
# Optimization terminated successfully.
#          Current function value: -509.337505
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -233.356846
#          Iterations: 36
#          Function evaluations: 73
# 0.9790 1.0002
# 132
# Optimization terminated successfully.
#          Current function value: -464.935901
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -233.018595
#          Iterations: 36
#          Function evaluations: 72
# 0.9718 0.9906
# 133
# Optimization terminated successfully.
#          Current function value: -479.616095
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -223.225322
#          Iterations: 36
#          Function evaluations: 73
# 0.9910 0.9902
# 134
# Optimization terminated successfully.
#          Current function value: -478.195030
#          Iterations: 35
#          Function evaluations: 74
# Optimization terminated successfully.
#          Current function value: -223.107131
#          Iterations: 36
#          Function evaluations: 73
# 0.9862 0.9906
# 135
# Optimization terminated successfully.
#          Current function value: -425.229595
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -224.702746
#          Iterations: 36
#          Function evaluations: 73
# 0.9986 0.9834
# 136
# Optimization terminated successfully.
#          Current function value: -415.540981
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -224.330886
#          Iterations: 36
#          Function evaluations: 74
# 0.9906 0.9762
# 137
# Optimization terminated successfully.
#          Current function value: -407.710157
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -222.212092
#          Iterations: 36
#          Function evaluations: 73
# 0.9830 1.0038
# 138
# Optimization terminated successfully.
#          Current function value: -404.341475
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -221.776723
#          Iterations: 36
#          Function evaluations: 73
# 0.9958 0.9990
# 139
# Optimization terminated successfully.
#          Current function value: -409.677023
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -220.264252
#          Iterations: 37
#          Function evaluations: 75
# 1.0058 0.9902
# 140
# Optimization terminated successfully.
#          Current function value: -416.191526
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -225.641976
#          Iterations: 36
#          Function evaluations: 72
# 0.9882 1.0010
# 141
# Optimization terminated successfully.
#          Current function value: -393.638775
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -224.014144
#          Iterations: 36
#          Function evaluations: 73
# 0.9802 0.9942
# 142
# Optimization terminated successfully.
#          Current function value: -400.823489
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -225.886784
#          Iterations: 36
#          Function evaluations: 72
# 1.0178 0.9822
# 143
# Optimization terminated successfully.
#          Current function value: -410.862712
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -224.319332
#          Iterations: 36
#          Function evaluations: 73
# 0.9506 0.9934
# 144
# Optimization terminated successfully.
#          Current function value: -380.570246
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -228.028677
#          Iterations: 36
#          Function evaluations: 73
# 0.9706 0.9934
# 145
# Optimization terminated successfully.
#          Current function value: -384.939607
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -228.744095
#          Iterations: 36
#          Function evaluations: 73
# 0.9666 0.9926
# 146
# Optimization terminated successfully.
#          Current function value: -393.093752
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -231.598085
#          Iterations: 36
#          Function evaluations: 72
# 0.9886 0.9866
# 147
# Optimization terminated successfully.
#          Current function value: -415.982333
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -233.146395
#          Iterations: 36
#          Function evaluations: 73
# 0.9786 0.9946
# 148
# Optimization terminated successfully.
#          Current function value: -403.549715
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -232.611569
#          Iterations: 36
#          Function evaluations: 72
# 0.9654 0.9894
# 149
# Optimization terminated successfully.
#          Current function value: -428.222106
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -233.520698
#          Iterations: 36
#          Function evaluations: 72
# 0.9698 0.9882
# 150
# Optimization terminated successfully.
#          Current function value: -444.230766
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -233.635489
#          Iterations: 36
#          Function evaluations: 72
# 0.9766 0.9890
# 151
# Optimization terminated successfully.
#          Current function value: -443.448539
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -233.154042
#          Iterations: 36
#          Function evaluations: 73
# 0.9790 0.9938
# 152
# Optimization terminated successfully.
#          Current function value: -420.931325
#          Iterations: 35
#          Function evaluations: 74
# Optimization terminated successfully.
#          Current function value: -232.564230
#          Iterations: 36
#          Function evaluations: 72
# 0.9377 0.9826
# 153
# Optimization terminated successfully.
#          Current function value: -392.063016
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -239.540312
#          Iterations: 36
#          Function evaluations: 72
# 0.9722 0.9914
# 154
# Optimization terminated successfully.
#          Current function value: -350.379112
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -240.393742
#          Iterations: 36
#          Function evaluations: 72
# 0.9822 0.9946
# 155
# Optimization terminated successfully.
#          Current function value: -349.011828
#          Iterations: 36
#          Function evaluations: 74
# Optimization terminated successfully.
#          Current function value: -241.195991
#          Iterations: 36
#          Function evaluations: 73
# 0.9930 0.9962
# 156
# Optimization terminated successfully.
#          Current function value: -338.958617
#          Iterations: 34
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -239.955133
#          Iterations: 37
#          Function evaluations: 74
# 0.9113 0.9914
# 157
# Optimization terminated successfully.
#          Current function value: -381.508868
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -241.518013
#          Iterations: 36
#          Function evaluations: 72
# 0.9898 0.9946
# 158
# Optimization terminated successfully.
#          Current function value: -376.558417
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -243.131328
#          Iterations: 36
#          Function evaluations: 72
# 1.0194 0.9982
# 159
# Optimization terminated successfully.
#          Current function value: -354.204169
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -238.346532
#          Iterations: 36
#          Function evaluations: 73
# 0.9834 0.9990
# 160
# Optimization terminated successfully.
#          Current function value: -356.160552
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -242.438269
#          Iterations: 36
#          Function evaluations: 73
# 0.8428 0.9930
# 161
# Optimization terminated successfully.
#          Current function value: -349.290680
#          Iterations: 36
#          Function evaluations: 74
# Optimization terminated successfully.
#          Current function value: -247.363659
#          Iterations: 37
#          Function evaluations: 75
# 1.0374 0.9946
# 162
# Optimization terminated successfully.
#          Current function value: -352.470527
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -245.429982
#          Iterations: 37
#          Function evaluations: 74
# 0.8488 0.9998
# 163
# Optimization terminated successfully.
#          Current function value: -332.509222
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -242.163155
#          Iterations: 36
#          Function evaluations: 72
# 1.0106 0.9902
# 164
# Optimization terminated successfully.
#          Current function value: -390.654455
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -244.860332
#          Iterations: 37
#          Function evaluations: 74
# 0.9918 1.0002
# 165
# Optimization terminated successfully.
#          Current function value: -392.254561
#          Iterations: 36
#          Function evaluations: 74
# Optimization terminated successfully.
#          Current function value: -242.575727
#          Iterations: 36
#          Function evaluations: 72
# 0.9938 0.9942
# 166
# Optimization terminated successfully.
#          Current function value: -406.773199
#          Iterations: 34
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -244.414342
#          Iterations: 36
#          Function evaluations: 73
# 0.9914 0.9906
# 167
# Optimization terminated successfully.
#          Current function value: -352.571158
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -249.253968
#          Iterations: 37
#          Function evaluations: 75
# 0.9842 0.9922
# 168
# Optimization terminated successfully.
#          Current function value: -407.388887
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -249.496140
#          Iterations: 37
#          Function evaluations: 74
# 1.0194 0.9910
# 169
# Optimization terminated successfully.
#          Current function value: -402.637278
#          Iterations: 35
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -248.723903
#          Iterations: 37
#          Function evaluations: 75
# 1.0226 0.9986
# 170
# Optimization terminated successfully.
#          Current function value: -356.291671
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -245.362448
#          Iterations: 37
#          Function evaluations: 74
# 1.0354 0.9886
# 171
# Optimization terminated successfully.
#          Current function value: -337.806890
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -242.433744
#          Iterations: 36
#          Function evaluations: 72
# 1.0298 0.9954
# 172
# Optimization terminated successfully.
#          Current function value: -316.186570
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -238.016274
#          Iterations: 36
#          Function evaluations: 72
# 0.9902 0.9866
# 173
# Optimization terminated successfully.
#          Current function value: -305.570860
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -240.198724
#          Iterations: 36
#          Function evaluations: 72
# 1.0346 0.9894
# 174
# Optimization terminated successfully.
#          Current function value: -316.635506
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -239.678432
#          Iterations: 36
#          Function evaluations: 73
# 1.0326 0.9858
# 175
# Optimization terminated successfully.
#          Current function value: -324.082783
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -241.043644
#          Iterations: 36
#          Function evaluations: 73
# 1.0519 0.9906
# 176
# Optimization terminated successfully.
#          Current function value: -330.675225
#          Iterations: 36
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -237.761394
#          Iterations: 36
#          Function evaluations: 72
# 0.9946 0.9798
# 177
# Optimization terminated successfully.
#          Current function value: -332.919086
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -239.261239
#          Iterations: 36
#          Function evaluations: 73
# 1.0170 0.9866
# 178
# Optimization terminated successfully.
#          Current function value: -348.554372
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -240.205416
#          Iterations: 36
#          Function evaluations: 72
# 1.0118 0.9946
# 179
# Optimization terminated successfully.
#          Current function value: -357.972360
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -239.961574
#          Iterations: 36
#          Function evaluations: 72
# 0.9922 0.9818
# 180
# Optimization terminated successfully.
#          Current function value: -346.569558
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -239.537402
#          Iterations: 36
#          Function evaluations: 72
# 0.9754 0.9846
# 181
# Optimization terminated successfully.
#          Current function value: -358.762448
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -240.262352
#          Iterations: 36
#          Function evaluations: 72
# 0.9974 0.9854
# 182
# Optimization terminated successfully.
#          Current function value: -361.608371
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -239.013426
#          Iterations: 36
#          Function evaluations: 72
# 0.9974 0.9834
# 183
# Optimization terminated successfully.
#          Current function value: -360.426771
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -241.815612
#          Iterations: 36
#          Function evaluations: 73
# 0.9606 0.9894
# 184
# Optimization terminated successfully.
#          Current function value: -353.819233
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -246.813436
#          Iterations: 37
#          Function evaluations: 75
# 0.9522 0.9894
# 185
# Optimization terminated successfully.
#          Current function value: -343.918661
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -245.562135
#          Iterations: 37
#          Function evaluations: 75
# 0.9870 0.9850
# 186
# Optimization terminated successfully.
#          Current function value: -337.856309
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -243.823789
#          Iterations: 36
#          Function evaluations: 72
# 1.0667 0.9854
# 187
# Optimization terminated successfully.
#          Current function value: -326.826719
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -243.058512
#          Iterations: 36
#          Function evaluations: 72
# 1.0270 0.9830
# 188
# Optimization terminated successfully.
#          Current function value: -319.566896
#          Iterations: 35
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -243.058512
#          Iterations: 36
#          Function evaluations: 72
# 1.0002 0.9854
# 189
# Optimization terminated successfully.
#          Current function value: -326.103417
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -244.529323
#          Iterations: 36
#          Function evaluations: 72
# 0.9994 0.9806
# 190
# Optimization terminated successfully.
#          Current function value: -322.990478
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -245.839513
#          Iterations: 37
#          Function evaluations: 76
# 0.9774 0.9794
# 191
# Optimization terminated successfully.
#          Current function value: -314.051972
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -244.331795
#          Iterations: 36
#          Function evaluations: 73
# 1.0102 0.9810
# 192
# Optimization terminated successfully.
#          Current function value: -309.106573
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -245.401166
#          Iterations: 37
#          Function evaluations: 75
# 0.9854 0.9890
# 193
# Optimization terminated successfully.
#          Current function value: -309.793346
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -247.169169
#          Iterations: 37
#          Function evaluations: 74
# 0.9694 0.9830
# 194
# Optimization terminated successfully.
#          Current function value: -267.142853
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -248.739566
#          Iterations: 37
#          Function evaluations: 74
# 1.0943 0.9822
# 195
# Optimization terminated successfully.
#          Current function value: -309.379001
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -249.306740
#          Iterations: 37
#          Function evaluations: 75
# 0.9413 0.9870
# 196
# Optimization terminated successfully.
#          Current function value: -312.130768
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -250.880581
#          Iterations: 37
#          Function evaluations: 74
# 1.0262 0.9862
# 197
# Optimization terminated successfully.
#          Current function value: -302.825372
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -250.266632
#          Iterations: 37
#          Function evaluations: 75
# 0.9578 0.9910
# 198
# Optimization terminated successfully.
#          Current function value: -309.780579
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -245.049901
#          Iterations: 37
#          Function evaluations: 74
# 0.9946 0.9902
# 199
# Optimization terminated successfully.
#          Current function value: -308.438770
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -242.651906
#          Iterations: 36
#          Function evaluations: 72
# 0.9441 0.9838
# 200
# Optimization terminated successfully.
#          Current function value: -290.518124
#          Iterations: 34
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -239.732496
#          Iterations: 36
#          Function evaluations: 72
# 0.9858 0.9810
# 201
# Optimization terminated successfully.
#          Current function value: -290.413691
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -238.502948
#          Iterations: 36
#          Function evaluations: 72
# 0.9950 0.9778
# 202
# Optimization terminated successfully.
#          Current function value: -277.065514
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -231.704356
#          Iterations: 36
#          Function evaluations: 72
# 1.0326 0.9814
# 203
# Optimization terminated successfully.
#          Current function value: -250.376955
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -221.120623
#          Iterations: 36
#          Function evaluations: 73
# 1.1363 0.9850
# 204
# Optimization terminated successfully.
#          Current function value: -264.186816
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -216.263329
#          Iterations: 36
#          Function evaluations: 74
# 0.9506 0.9830
# 205
# Optimization terminated successfully.
#          Current function value: -247.462712
#          Iterations: 33
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -212.184456
#          Iterations: 36
#          Function evaluations: 73
# 0.8000 0.9834
# 206
# Optimization terminated successfully.
#          Current function value: -274.089519
#          Iterations: 34
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -213.052234
#          Iterations: 37
#          Function evaluations: 76
# 0.9962 0.9746
# 207
# Optimization terminated successfully.
#          Current function value: -284.508846
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -212.120620
#          Iterations: 36
#          Function evaluations: 73
# 1.1960 0.9782
# 208
# Optimization terminated successfully.
#          Current function value: -238.650063
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -199.647284
#          Iterations: 36
#          Function evaluations: 73
# 1.0563 1.0006
# 209
# Optimization terminated successfully.
#          Current function value: -197.875367
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -164.055145
#          Iterations: 34
#          Function evaluations: 70
# 1.0887 0.9950
# 210
# Optimization terminated successfully.
#          Current function value: -187.138438
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -163.786671
#          Iterations: 35
#          Function evaluations: 71
# 1.2000 0.9918
# 211
# Optimization terminated successfully.
#          Current function value: -226.686036
#          Iterations: 33
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -161.884902
#          Iterations: 34
#          Function evaluations: 70
# 1.1219 0.9998
# 212
# Optimization terminated successfully.
#          Current function value: -221.694084
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -159.650907
#          Iterations: 34
#          Function evaluations: 70
# 0.9974 0.9966
# 213
# Optimization terminated successfully.
#          Current function value: -208.253767
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -156.361666
#          Iterations: 34
#          Function evaluations: 70
# 0.8476 0.9958
# 214
# Optimization terminated successfully.
#          Current function value: -213.316145
#          Iterations: 32
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -155.281337
#          Iterations: 34
#          Function evaluations: 72
# 1.1247 0.9982
# 215
# Optimization terminated successfully.
#          Current function value: -213.600770
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -154.491687
#          Iterations: 34
#          Function evaluations: 70
# 1.0959 0.9866
# 216
# Optimization terminated successfully.
#          Current function value: -211.113769
#          Iterations: 32
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -152.446646
#          Iterations: 34
#          Function evaluations: 69
# 1.0278 0.9870
# 217
# Optimization terminated successfully.
#          Current function value: -209.453116
#          Iterations: 31
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -151.678751
#          Iterations: 34
#          Function evaluations: 69
# 0.9041 0.9846
# 218
# Optimization terminated successfully.
#          Current function value: -213.102433
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -151.169542
#          Iterations: 34
#          Function evaluations: 71
# 1.2000 0.9810
# 219
# Optimization terminated successfully.
#          Current function value: -208.934202
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -151.947491
#          Iterations: 34
#          Function evaluations: 70
# 0.9522 1.0094
# 220
# Optimization terminated successfully.
#          Current function value: -209.705104
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -150.666752
#          Iterations: 34
#          Function evaluations: 70
# 0.9886 0.9778
# 221
# Optimization terminated successfully.
#          Current function value: -195.802966
#          Iterations: 32
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -148.685134
#          Iterations: 34
#          Function evaluations: 70
# 0.8773 0.9818
# 222
# Optimization terminated successfully.
#          Current function value: -188.608032
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -146.655488
#          Iterations: 34
#          Function evaluations: 71
# 1.1315 0.9806
# 223
# Optimization terminated successfully.
#          Current function value: -182.587979
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -145.805238
#          Iterations: 34
#          Function evaluations: 70
# 1.1139 0.9610
# 224
# Optimization terminated successfully.
#          Current function value: -180.480187
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -145.617578
#          Iterations: 34
#          Function evaluations: 71
# 1.2000 0.9770
# 225
# Optimization terminated successfully.
#          Current function value: -180.992201
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -145.522964
#          Iterations: 34
#          Function evaluations: 71
# 1.1628 0.9750
# 226
# Optimization terminated successfully.
#          Current function value: -189.124659
#          Iterations: 32
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -145.425369
#          Iterations: 34
#          Function evaluations: 70
# 1.0931 0.9858
# 227
# Optimization terminated successfully.
#          Current function value: -196.994971
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -145.794118
#          Iterations: 34
#          Function evaluations: 71
# 0.8000 0.9778
# 228
# Optimization terminated successfully.
#          Current function value: -187.783093
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -139.457401
#          Iterations: 34
#          Function evaluations: 71
# 0.8701 0.9862
# 229
# Optimization terminated successfully.
#          Current function value: -170.106673
#          Iterations: 30
#          Function evaluations: 62
# Optimization terminated successfully.
#          Current function value: -134.246235
#          Iterations: 33
#          Function evaluations: 68
# 0.9353 0.9782
# 230
# Optimization terminated successfully.
#          Current function value: -132.711762
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -135.569817
#          Iterations: 33
#          Function evaluations: 68
# 1.2000 0.9606
# 231
# Optimization terminated successfully.
#          Current function value: -166.894380
#          Iterations: 31
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -135.582585
#          Iterations: 33
#          Function evaluations: 69
# 1.1540 0.9854
# 232
# Optimization terminated successfully.
#          Current function value: -166.350270
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -135.087410
#          Iterations: 34
#          Function evaluations: 70
# 0.8765 0.9766
# 233
# Optimization terminated successfully.
#          Current function value: -169.312209
#          Iterations: 30
#          Function evaluations: 62
# Optimization terminated successfully.
#          Current function value: -137.029540
#          Iterations: 33
#          Function evaluations: 67
# 0.8000 0.9534
# 234
# Optimization terminated successfully.
#          Current function value: -148.899479
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -137.104520
#          Iterations: 33
#          Function evaluations: 69
# 1.2000 0.9493
# 235
# Optimization terminated successfully.
#          Current function value: -155.745334
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -134.518770
#          Iterations: 33
#          Function evaluations: 67
# 1.1067 0.9522
# 236
# Optimization terminated successfully.
#          Current function value: -162.283521
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -137.190048
#          Iterations: 33
#          Function evaluations: 68
# 1.0883 0.9453
# 237
# Optimization terminated successfully.
#          Current function value: -166.375346
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -139.068979
#          Iterations: 33
#          Function evaluations: 68
# 1.0422 0.9409
# 238
# Optimization terminated successfully.
#          Current function value: -170.745580
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -130.406956
#          Iterations: 33
#          Function evaluations: 68
# 0.9273 0.9241
# 239
# Optimization terminated successfully.
#          Current function value: -174.405099
#          Iterations: 30
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -132.716179
#          Iterations: 35
#          Function evaluations: 72
# 0.9614 0.9337
# 240
# Optimization terminated successfully.
#          Current function value: -171.676461
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -132.544106
#          Iterations: 34
#          Function evaluations: 71
# 0.9862 0.9469
# 241
# Optimization terminated successfully.
#          Current function value: -174.962232
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -133.636518
#          Iterations: 34
#          Function evaluations: 71
# 0.8360 0.9077
# 242
# Optimization terminated successfully.
#          Current function value: -176.861442
#          Iterations: 31
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -134.116990
#          Iterations: 33
#          Function evaluations: 68
# 0.9309 0.9017
# 243
# Optimization terminated successfully.
#          Current function value: -174.953898
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -135.460992
#          Iterations: 33
#          Function evaluations: 68
# 0.8400 0.9325
# 244
# Optimization terminated successfully.
#          Current function value: -164.018989
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -132.192107
#          Iterations: 34
#          Function evaluations: 70
# 0.9105 0.9353
# 245
# Optimization terminated successfully.
#          Current function value: -160.373455
#          Iterations: 30
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -130.072577
#          Iterations: 33
#          Function evaluations: 68
# 0.8957 0.9193
# 246
# Optimization terminated successfully.
#          Current function value: -185.285647
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -131.278297
#          Iterations: 35
#          Function evaluations: 73
# 0.9245 0.9405
# 247
# Optimization terminated successfully.
#          Current function value: -186.994454
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -131.919502
#          Iterations: 34
#          Function evaluations: 69
# 0.8340 0.9269
# 248
# Optimization terminated successfully.
#          Current function value: -173.623890
#          Iterations: 30
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -132.008205
#          Iterations: 34
#          Function evaluations: 70
# 0.8000 0.9670
# 249
# Optimization terminated successfully.
#          Current function value: -176.375108
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -132.151896
#          Iterations: 34
#          Function evaluations: 71
# 0.9081 0.9253
# 250
# Optimization terminated successfully.
#          Current function value: -176.427846
#          Iterations: 30
#          Function evaluations: 61
# Optimization terminated successfully.
#          Current function value: -131.678324
#          Iterations: 34
#          Function evaluations: 70
# 0.9630 0.9578
# 251
# Optimization terminated successfully.
#          Current function value: -168.197078
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -126.897424
#          Iterations: 33
#          Function evaluations: 69
# 0.8873 0.9341
# 252
# Optimization terminated successfully.
#          Current function value: -175.995624
#          Iterations: 30
#          Function evaluations: 62
# Optimization terminated successfully.
#          Current function value: -129.632760
#          Iterations: 33
#          Function evaluations: 68
# 0.8000 0.8985
# 253
# Optimization terminated successfully.
#          Current function value: -176.574601
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -129.877661
#          Iterations: 33
#          Function evaluations: 69
# 0.8965 0.8941
# 254
# Optimization terminated successfully.
#          Current function value: -179.256276
#          Iterations: 30
#          Function evaluations: 65
# Optimization terminated successfully.
#          Current function value: -131.321344
#          Iterations: 34
#          Function evaluations: 71
# 0.8280 0.8993
# 255
# Optimization terminated successfully.
#          Current function value: -181.897679
#          Iterations: 30
#          Function evaluations: 62
# Optimization terminated successfully.
#          Current function value: -131.176648
#          Iterations: 34
#          Function evaluations: 70
# 0.8000 0.8873
# 256
# Optimization terminated successfully.
#          Current function value: -180.984098
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -131.489678
#          Iterations: 34
#          Function evaluations: 70
# 0.8000 0.9337
# 257
# Optimization terminated successfully.
#          Current function value: -190.393251
#          Iterations: 30
#          Function evaluations: 63
# Optimization terminated successfully.
#          Current function value: -133.501586
#          Iterations: 33
#          Function evaluations: 69
# 0.8601 0.9089
# 258
# Optimization terminated successfully.
#          Current function value: -192.234444
#          Iterations: 30
#          Function evaluations: 64
# Optimization terminated successfully.
#          Current function value: -134.079517
#          Iterations: 33
#          Function evaluations: 69
# 0.8000 0.9125
# 259
# Optimization terminated successfully.
#          Current function value: -197.538817
#          Iterations: 30
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -134.086164
#          Iterations: 33
#          Function evaluations: 68
# 0.8000 0.9297
# ...
#          Iterations: 36
#          Function evaluations: 73
# 0.9614 0.9329
# 525
# Optimization terminated successfully.
#          Current function value: -223.695701
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -218.754842
#          Iterations: 36
#          Function evaluations: 73
# 1.0671 0.9377
# 526
# Optimization terminated successfully.
#          Current function value: -215.224614
#          Iterations: 33
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -219.549251
#          Iterations: 36
#          Function evaluations: 72
# 1.0354 0.9389
# 527
# Optimization terminated successfully.
#          Current function value: -221.638489
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -216.319003
#          Iterations: 36
#          Function evaluations: 74
# 1.0314 0.9241
# 528
# Optimization terminated successfully.
#          Current function value: -222.474790
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -217.614721
#          Iterations: 36
#          Function evaluations: 72
# 0.9309 0.9281
# 529
# Optimization terminated successfully.
#          Current function value: -186.137113
#          Iterations: 33
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -218.060978
#          Iterations: 36
#          Function evaluations: 73
# 0.8000 0.9377
# 530
# Optimization terminated successfully.
#          Current function value: -213.928072
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -217.903952
#          Iterations: 36
#          Function evaluations: 73
# 0.9061 0.9237
# 531
# Optimization terminated successfully.
#          Current function value: -213.696840
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -219.035576
#          Iterations: 36
#          Function evaluations: 73
# 1.0098 0.9149
# 532
# Optimization terminated successfully.
#          Current function value: -215.120080
#          Iterations: 35
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -220.338465
#          Iterations: 36
#          Function evaluations: 73
# 1.0158 0.9209
# 533
# Optimization terminated successfully.
#          Current function value: -217.606221
#          Iterations: 35
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -222.729791
#          Iterations: 36
#          Function evaluations: 73
# 1.0206 0.9417
# 534
# Optimization terminated successfully.
#          Current function value: -218.705948
#          Iterations: 34
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -220.677008
#          Iterations: 36
#          Function evaluations: 73
# 1.2000 0.9381
# 535
# Optimization terminated successfully.
#          Current function value: -216.261793
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -218.106073
#          Iterations: 36
#          Function evaluations: 72
# 0.9349 0.9309
# 536
# Optimization terminated successfully.
#          Current function value: -212.821862
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -215.482113
#          Iterations: 36
#          Function evaluations: 73
# 0.9502 0.9349
# 537
# Optimization terminated successfully.
#          Current function value: -212.727071
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -215.337934
#          Iterations: 36
#          Function evaluations: 72
# 1.1996 0.9217
# 538
# Optimization terminated successfully.
#          Current function value: -214.926647
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -215.879972
#          Iterations: 36
#          Function evaluations: 73
# 0.9441 0.9285
# 539
# Optimization terminated successfully.
#          Current function value: -216.411228
#          Iterations: 35
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -214.342719
#          Iterations: 36
#          Function evaluations: 73
# 0.8000 0.9293
# 540
# Optimization terminated successfully.
#          Current function value: -216.179922
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -214.579774
#          Iterations: 36
#          Function evaluations: 74
# 0.8529 0.9257
# 541
# Optimization terminated successfully.
#          Current function value: -219.760632
#          Iterations: 35
#          Function evaluations: 73
# Optimization terminated successfully.
#          Current function value: -215.877026
#          Iterations: 36
#          Function evaluations: 72
# 0.8316 0.9345
# 542
# Optimization terminated successfully.
#          Current function value: -196.317705
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -217.217365
#          Iterations: 36
#          Function evaluations: 73
# 0.8000 0.9233
# 543
# Optimization terminated successfully.
#          Current function value: -257.428125
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -214.111170
#          Iterations: 36
#          Function evaluations: 73
# 1.0038 0.9193
# 544
# Optimization terminated successfully.
#          Current function value: -163.507454
#          Iterations: 32
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -214.100545
#          Iterations: 36
#          Function evaluations: 73
# 0.8000 0.9257
# 545
# Optimization terminated successfully.
#          Current function value: -291.258693
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -211.443498
#          Iterations: 36
#          Function evaluations: 73
# 0.9321 0.9365
# 546
# Optimization terminated successfully.
#          Current function value: -288.442835
#          Iterations: 33
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -218.933530
#          Iterations: 36
#          Function evaluations: 73
# 0.8529 0.9321
# 547
# Optimization terminated successfully.
#          Current function value: -279.884269
#          Iterations: 33
#          Function evaluations: 67
# Optimization terminated successfully.
#          Current function value: -219.486295
#          Iterations: 37
#          Function evaluations: 75
# 0.9790 0.9269
# 548
# Optimization terminated successfully.
#          Current function value: -285.783140
#          Iterations: 33
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -225.797146
#          Iterations: 36
#          Function evaluations: 74
# 0.9017 0.9297
# 549
# Optimization terminated successfully.
#          Current function value: -221.406584
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -223.843811
#          Iterations: 36
#          Function evaluations: 72
# 0.8000 0.9385
# 550
# Optimization terminated successfully.
#          Current function value: -231.794819
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -226.960348
#          Iterations: 36
#          Function evaluations: 73
# 0.9393 0.9185
# 551
# Optimization terminated successfully.
#          Current function value: -225.593094
#          Iterations: 33
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -227.206058
#          Iterations: 36
#          Function evaluations: 72
# 1.2000 0.9349
# 552
# Optimization terminated successfully.
#          Current function value: -160.007377
#          Iterations: 31
#          Function evaluations: 66
# Optimization terminated successfully.
#          Current function value: -228.340214
#          Iterations: 36
#          Function evaluations: 73
# 1.2000 0.9273
# 553
# Optimization terminated successfully.
#          Current function value: -272.488341
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -211.253348
#          Iterations: 36
#          Function evaluations: 74
# 0.9858 0.9301
# 554
# Optimization terminated successfully.
#          Current function value: -310.032881
#          Iterations: 33
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -210.914821
#          Iterations: 36
#          Function evaluations: 73
# 0.9998 0.9289
# 555
# Optimization terminated successfully.
#          Current function value: -318.411071
#          Iterations: 33
#          Function evaluations: 68
# Optimization terminated successfully.
#          Current function value: -207.830552
#          Iterations: 35
#          Function evaluations: 71
# 0.9782 0.9325
# 556
# Optimization terminated successfully.
#          Current function value: -280.058788
#          Iterations: 34
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -205.448935
#          Iterations: 35
#          Function evaluations: 72
# 0.9762 0.9241
# 557
# Optimization terminated successfully.
#          Current function value: -306.398223
#          Iterations: 33
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -207.577186
#          Iterations: 35
#          Function evaluations: 71
# 0.9542 0.9141
# 558
# Optimization terminated successfully.
#          Current function value: -299.636763
#          Iterations: 33
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -206.779403
#          Iterations: 35
#          Function evaluations: 71
# 0.9201 0.9397
# 559
# Optimization terminated successfully.
#          Current function value: -257.813842
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -211.930525
#          Iterations: 36
#          Function evaluations: 73
# 1.0915 0.9329
# 560
# Optimization terminated successfully.
#          Current function value: -265.880406
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -215.293481
#          Iterations: 36
#          Function evaluations: 72
# 1.1027 0.9357
# 561
# Optimization terminated successfully.
#          Current function value: -255.544338
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -213.703466
#          Iterations: 36
#          Function evaluations: 72
# 1.0414 0.9365
# 562
# Optimization terminated successfully.
#          Current function value: -251.899444
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -216.375493
#          Iterations: 36
#          Function evaluations: 72
# 1.1784 0.9409
# 563
# Optimization terminated successfully.
#          Current function value: -279.852346
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -218.713830
#          Iterations: 36
#          Function evaluations: 72
# 1.0126 0.9249
# 564
# Optimization terminated successfully.
#          Current function value: -277.427173
#          Iterations: 34
#          Function evaluations: 69
# Optimization terminated successfully.
#          Current function value: -220.631823
#          Iterations: 36
#          Function evaluations: 74
# 1.0807 0.9469
# 565
# Optimization terminated successfully.
#          Current function value: -300.332124
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -223.260165
#          Iterations: 36
#          Function evaluations: 72
# 1.0110 0.9461
# 566
# Optimization terminated successfully.
#          Current function value: -279.813220
#          Iterations: 34
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -222.601775
#          Iterations: 36
#          Function evaluations: 73
# 0.9890 0.9393
# 567
# Optimization terminated successfully.
#          Current function value: -294.870416
#          Iterations: 35
#          Function evaluations: 72
# Optimization terminated successfully.
#          Current function value: -225.570311
#          Iterations: 36
#          Function evaluations: 73
# 0.9926 0.9437
# 568
# Optimization terminated successfully.
#          Current function value: -289.994317
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -222.602788
#          Iterations: 36
#          Function evaluations: 73
# 0.9534 0.9365
# 569
# Optimization terminated successfully.
#          Current function value: -280.144641
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -221.681769
#          Iterations: 36
#          Function evaluations: 73
# 0.9590 0.9397
# 570
# Optimization terminated successfully.
#          Current function value: -280.541072
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -224.262076
#          Iterations: 36
#          Function evaluations: 72
# 0.9085 0.9441
# 571
# Optimization terminated successfully.
#          Current function value: -267.954831
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -224.698304
#          Iterations: 36
#          Function evaluations: 72
# 0.8545 0.9321
# 572
# Optimization terminated successfully.
#          Current function value: -287.797269
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -225.135065
#          Iterations: 36
#          Function evaluations: 73
# 1.0426 0.9381
# 573
# Optimization terminated successfully.
#          Current function value: -293.338780
#          Iterations: 34
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -227.537882
#          Iterations: 36
#          Function evaluations: 72
# 0.9730 0.9397
# 574
# Optimization terminated successfully.
#          Current function value: -275.594287
#          Iterations: 35
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -229.776751
#          Iterations: 36
#          Function evaluations: 72
# 0.9033 0.9538
# 575
# Optimization terminated successfully.
#          Current function value: -284.603400
#          Iterations: 35
#          Function evaluations: 71
# Optimization terminated successfully.
#          Current function value: -230.835669
#          Iterations: 36
#          Function evaluations: 73
# 0.8949 0.9465
# 576
# Optimization terminated successfully.
#          Current function value: -304.777114
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -232.712599
#          Iterations: 36
#          Function evaluations: 72
# 0.9349 0.9510
# 577
# Optimization terminated successfully.
#          Current function value: -311.913105
#          Iterations: 34
#          Function evaluations: 70
# Optimization terminated successfully.
#          Current function value: -235.082729
#          Iterations: 37
#          Function evaluations: 74
# 0.9085 0.9514
# Done!

# %%
plt.plot(h_GARCH_arr)
plt.plot(h_ECDF_arr)

# %%
rh_GARCH = train.iloc[block_size+1:, -1] - \
            np.array(h_GARCH_arr)[1:]*train.iloc[block_size+1:,-2]

rh_ECDF = train.iloc[block_size+1:, -1] - \
            np.array(h_ECDF_arr)[:-1]*train.iloc[block_size+1:,-2]

rh_naive = train.iloc[block_size+1:, -1] - train.iloc[block_size+1:,-2]


rh_GARCH *= 100 
rh_ECDF *= 100 
rh_naive *= 100

# %%
sns.distplot(rh_GARCH)
sns.distplot(rh_ECDF)
sns.distplot(rh_naive)
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(np.mean(rh_GARCH),
      np.mean(rh_ECDF), 
      np.mean(rh_naive))

print(np.std(rh_GARCH),
      np.std(rh_ECDF), 
      np.std(rh_naive))

print(np.mean(rh_GARCH)/np.std(rh_GARCH),
      np.mean(rh_ECDF)/np.std(rh_ECDF), 
      np.mean(rh_naive)/np.std(rh_naive))
# Out:
# 0.033586033484788745 0.010487188807188153 -0.0015899758282242695
# 0.9271118509593802 0.6616512709111947 0.6739585861209921
# 0.03622651727516345 0.01585002442864758 -0.002359159540314588
