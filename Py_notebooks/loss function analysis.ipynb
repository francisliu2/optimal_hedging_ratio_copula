# %%
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.distributions.empirical_distribution import ECDF
from copulae1 import *
from KDEs import *
from toolbox import *
import warnings
import itertools
import os
warnings.filterwarnings("ignore")

data = pd.read_csv('../processed_data/btc_future_crix.csv')
brr = np.array(data.return_brr)
btc = np.array(data.return_btc)

# %%
kde_brr = KDE(brr, 'Gaussian')
kde_brr.plot_density()

# %%
sns.distplot(kde_brr.rvs(100000))

# %%
h_arr = np.linspace(0.3,1,500)
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, q_rm)]
    rho_arr.append(ES(0.05, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])

rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, 0.0)]
    rho_arr.append(ES(0.05, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
# Out:
# 0.7839679358717435
# 0.7418837675350701

# %%
q_rm = 0.05 # threshold of removal
h_arr = np.linspace(0.3,1,500)
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, q_rm)]
    rho_arr.append(ES(0.01, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, 0.0)]
    rho_arr.append(ES(0.01, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
# Out:
# 0.8288577154308616
# 0.6745490981963927

# %%
h_arr = np.linspace(0.3,1,500)
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, q_rm)]
    rho_arr.append(VaR(0.05, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, 0.0)]
    rho_arr.append(VaR(0.05, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
# Out:
# 0.7867735470941883
# 0.8064128256513026

# %%
h_arr = np.linspace(0.3,1,500)
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, q_rm)]
    rho_arr.append(VaR(0.01, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, 0.0)]
    rho_arr.append(VaR(0.01, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
# Out:
# 0.6955911823647294
# 0.7615230460921844

# %%
h_arr = np.linspace(0.3,1,500)
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, q_rm)]
    rho_arr.append(ERM_estimate_trapezoidal(10, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
rho_arr = []
for h in h_arr:
    rh = brr - h*btc
    _rh = rh[rh > np.quantile(rh, 0.0)]
    rho_arr.append(ERM_estimate_trapezoidal(10, _rh))
plt.plot(h_arr, rho_arr)
print(h_arr[np.argmin(rho_arr)])
# Out:
# 0.7881763527054109
# 0.7531062124248497
