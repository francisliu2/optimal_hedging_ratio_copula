# %%
import os

# %%
# !python calibration.py --config configs/config_CRIX_future_Open_v3_MM.json
# !python get_OHR.py --config configs/config_CRIX_future_Open_v3_MM.json
# !python get_HEs.py --config configs/config_CRIX_future_Open_v3_MM.json
# Out:
# Optimization terminated successfully.
#          Current function value: 0.020834
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010544
#          Iterations: 181
#          Function evaluations: 342
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013514
#          Iterations: 149
#          Function evaluations: 284
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.259645
#          Iterations: 49
#          Function evaluations: 106
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.097005
#          Iterations: 57
#          Function evaluations: 123
# Frank is done.
#
# ...

# %%
# !python calibration.py --config configs/config_coingecko_future_v5_MM.json
# !python get_OHR.py --config configs/config_coingecko_future_v5_MM.json
# !python get_HEs.py --config configs/config_coingecko_future_v5_MM.json
# Out:
# Optimization terminated successfully.
#          Current function value: 0.057027
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045197
#          Iterations: 161
#          Function evaluations: 312
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050195
#          Iterations: 146
#          Function evaluations: 277
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.184211
#          Iterations: 54
#          Function evaluations: 119
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.067172
#          Iterations: 67
#          Function evaluations: 136
# Frank is done.
#
# ...
