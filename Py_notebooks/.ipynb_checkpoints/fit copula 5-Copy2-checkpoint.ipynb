# %%
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.distributions.empirical_distribution import ECDF
from copulae1 import *
from KDEs import *
from toolbox import *
import warnings
import itertools
import os
warnings.filterwarnings("ignore")

data = pd.read_csv('../processed_data/btc_future_crix.csv')
data.head()

ecdf_brr = ECDF(data.return_brr)
ecdf_btc = ECDF(data.return_btc)

u = ecdf_brr(data.return_brr)
v = ecdf_btc(data.return_btc)

brr = np.array(data.return_brr)
btc = np.array(data.return_btc)

kde_brr = KDE(data.return_brr, "Gaussian")
kde_btc = KDE(data.return_btc, "Gaussian")

kde_brr = KDE(data.return_brr, "Gaussian", kde_brr.h_brot*3)
kde_btc = KDE(data.return_brr, "Gaussian", kde_btc.h_brot*3)

# %%
# Gaussian, t_Copula, Clayton, Frank, Gumbel, Plackett, Gaussian mix Indep
C1  = Gaussian(dict(rho=0.9),       Law_RS=kde_brr, Law_RF=kde_btc) # fix the maringals!
C2  = t_Copula(dict(rho=0.1, nu=4), Law_RS=kde_brr, Law_RF=kde_btc, nu_lowerbound=2) 
C2c = t_Copula(dict(rho=0.1, nu=4), Law_RS=kde_brr, Law_RF=kde_btc, nu_lowerbound=4) 
C3  = Clayton(dict(theta=0.1),      Law_RS=kde_brr, Law_RF=kde_btc)
C4  = Frank(dict(theta=0.1),        Law_RS=kde_brr, Law_RF=kde_btc)
C5  = Gumbel(dict(theta=3),         Law_RS=kde_brr, Law_RF=kde_btc)
C6  = Plackett(dict(theta=10),      Law_RS=kde_brr, Law_RF=kde_btc)
C7  = Gaussian_Mix_Independent(dict(rho=.5,p=0.7),Law_RS=kde_brr, Law_RF=kde_btc)
Copulae_names = ['Gaussian', 't_Copula', 't_Copula_Capped', 'Clayton', 'Frank', 'Gumbel', 'Plackett', 'Gauss Mix Indep']
Copulae_arr   = [C1,C2,C2c,C3,C4,C5,C6,C7]
Copulae = dict(zip(Copulae_names, Copulae_arr))
# Out:
# Gaussian
# t_Copula
# t_Copula_Capped
# Clayton
# Frank
# Gumbel
# Plackett
# Gauss Mix Indep

# %%
k_arr = [10,20] # Absolute risk aversion for exponential risk measure
q_arr = [0.01,0.05,0.1] # Quantile level for expected shortfall

best_h = []
for C_name in Copulae:
    best_h.append(optimize_h(Copulae[C_name], k_arr, q_arr))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000448
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.032501
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.041642
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010071
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000840
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000094
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.002236
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.073756
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.096737
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.028009
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.010135
#          Iterations: 18
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.003111
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.002232
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.073526
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.096419
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.027971
#          Iterations: 16
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.010076
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.003014
#          Iterations: 17
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.002241
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.073479
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.096148
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.028015
#          Iterations: 17
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.010138
#          Iterations: 18
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.003062
#          Iterations: 17
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.002255
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.073977
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.097093
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.028117
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.010160
#          Iterations: 19
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.003124
#          Iterations: 17
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.000642
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.040332
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.053442
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.011879
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.001287
#          Iterations: 14
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000115
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.001475
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.059655
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.079945
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.019661
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.006032
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.001707
#          Iterations: 17
#          Function evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.001996
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.069521
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.090998
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.026183
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.008922
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.002470
#          Iterations: 16
#          Function evaluations: 34

# %%
best_h = pd.DataFrame(best_h)
best_h.columns = ['Var'] + ['ERM k=%i'%k for k in k_arr] +  ['ES q=%.2f'%q for q in q_arr]
best_h.index = Copulae_names 
best_h
# Out:
#                       Var  ERM k=10  ERM k=20  ES q=0.01  ES q=0.05  \
# Gaussian         0.884082  0.896289  0.914648   0.842383   0.892480
# t_Copula         0.098047  0.104395  0.105566   0.099902   0.096387
# t_Copula_Capped  0.097754  0.104395  0.104395   0.098633   0.081250
# Clayton          0.078223  0.106250  0.134668   0.064062   0.052930
# Frank            0.015332  0.015234  0.018066   0.016309   0.002539
# Gumbel           0.834375  0.960449  1.014648   0.871094   0.743652
# Plackett         0.580371  0.589062  0.592773   0.601367   0.550000
# Gauss Mix Indep  0.338672  0.356348  0.386426   0.301465   0.301660
#
#                     ES q=0.10
# Gaussian         8.582031e-01
# t_Copula         1.000000e-01
# t_Copula_Capped  8.720703e-02
# Clayton         -8.881784e-16
# Frank           -9.765625e-05
# Gumbel           6.247070e-01
# Plackett         5.404297e-01
# Gauss Mix Indep  3.898437e-01

# %%
data_name = "future_brr_v4"
data_path = "../processed_data/"+data_name+"/"

# Risk Measures
# Variance is automatically included
k_arr = [10,20] # Absolute risk aversion for exponential risk measure
q_arr_ES = [0.01,0.05,0.1] # Quantile level for expected shortfall

spot_name = "log return brr"
future_name = "log return future"

paras_results = []
likelihood_results = []
best_h_results = []

calibration_method = "MLE" # MM or MLE
q_arr = [0.05,0.1,0.9,0.95]

ls = os.listdir(data_path+'train/')
ls = [l for l in ls if l.endswith('.csv')]
for file in ls:
    # Calibration 
    train = pd.read_csv(data_path+'train/'+file)
    spot   = train.loc[:,spot_name]
    future = train.loc[:,future_name]
    u = ECDF(spot)(spot)
    v = ECDF(future)(future)
    
    kde_brr = KDE(spot, "Gaussian")
    kde_btc = KDE(future, "Gaussian")
    
    for C_name in Copulae:
        Copulae[C_name].Law_RS = kde_brr
        Copulae[C_name].Law_RF = kde_btc
    
    paras = []
    likelihood = []
    best_h = []
    for C_name in Copulae:
        if calibration_method == "MLE":
            Copulae[C_name].canonical_calibrate(u,v)
            
        elif calibration_method == "MM":
            Copulae[C_name].mm_calibrate(u,v,q_arr)

        print(C_name,'is done.\n')
    
    for C_name in Copulae:
        paras.append((C_name,Copulae[C_name].paras))
        
    for C_name in Copulae:
        ln = Copulae[C_name].dependency_likelihood(u,v)
        likelihood.append((C_name,ln))
        
    paras_results.append(paras)
    likelihood_results.append(likelihood)
    
    # Get Best h
    best_h = []
    for C_name in Copulae:
        best_h.append(optimize_h(Copulae[C_name], k_arr, q_arr_ES))
    best_h = pd.DataFrame(best_h)
    best_h.columns = ['Var'] + ['ERM k=%i'%k for k in k_arr] +  ['ES q=%.2f'%q for q in q_arr_ES]
    best_h.index = Copulae_names 
    best_h_results.append(best_h)
    
#     # Testing
#     test = pd.read_csv(data_path+'test/'+file)
#     spot_test   = train.loc[:,spot_name]
#     future_test = train.loc[:,future_name]
# Out:
# Optimization terminated successfully.
#          Current function value: -0.416899
#          Iterations: 32
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.522612
#          Iterations: 120
#          Function evaluations: 231
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.502592
#          Iterations: 176
#          Function evaluations: 339
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.388826
#          Iterations: 41
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.422036
#          Iterations: 42
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.449668
#          Iterations: 36
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.503845
#          Iterations: 42
#          Function evaluations: 93
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.524252
#          Iterations: 61
#          Function evaluations: 129
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001020
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.048181
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.064984
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.014598
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.003608
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000406
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000859
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043096
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.059503
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011550
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.002652
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000193
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000785
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042193
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.057074
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011910
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.002589
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000059
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001278
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.047649
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.062337
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.015649
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.005783
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.002135
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001382
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.055275
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.077629
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.014949
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.004941
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001280
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.001020
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.050463
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.069690
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.014390
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.002899
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000205
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001139
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.050322
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.071300
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012438
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.004028
#          Iterations: 15
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000880
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001187
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.051501
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.072383
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.012878
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.004306
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000892
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: -0.368599
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.437328
#          Iterations: 64
#          Function evaluations: 143
# t_Copula is done.
# Optimization terminated successfully.
#          Current function value: -0.428291
#          Iterations: 123
#          Function evaluations: 244
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.307838
#          Iterations: 34
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.371233
#          Iterations: 35
#          Function evaluations: 77
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.404987
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.431727
#          Iterations: 40
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.442052
#          Iterations: 65
#          Function evaluations: 140
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000899
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042346
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.055293
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.013254
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.002472
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.000537
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000748
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.038706
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.052174
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.010723
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.001640
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.000956
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000765
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.039350
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.052209
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011505
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001858
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.000869
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.001231
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.043277
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.054969
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.014750
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.004612
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000650
#          Iterations: 19
#          Function evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.001151
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.047407
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.063764
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.013433
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.003446
#          Iterations: 15
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000091
#          Iterations: 17
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000838
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043990
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.058594
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.013095
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.001736
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.001254
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001003
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.044488
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.060362
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.011787
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.002904
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.000222
#          Iterations: 17
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.001049
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.045967
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.062420
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.012244
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.003131
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.000348
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.430557
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.519839
#          Iterations: 121
#          Function evaluations: 228
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.505821
#          Iterations: 141
#          Function evaluations: 269
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.402116
#          Iterations: 34
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.429814
#          Iterations: 34
#          Function evaluations: 77
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.452294
#          Iterations: 31
#          Function evaluations: 68
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.500816
#          Iterations: 39
#          Function evaluations: 90
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: -0.517188
#          Iterations: 59
#          Function evaluations: 130
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000993
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.047656
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.064136
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.014951
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.002259
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000906
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000890
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043739
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.060627
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012000
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001666
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.000998
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000796
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042264
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.057274
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012268
#          Iterations: 16
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.001444
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: -0.001193
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001223
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.046694
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.060928
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.015682
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.004539
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000491
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.001365
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.055856
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.078594
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.015601
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.003571
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.000135
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001039
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.050788
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.069950
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.015063
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001670
#          Iterations: 15
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.001368
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001157
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.051271
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.072648
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.013152
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.002875
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.000418
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.001187
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.051499
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.072517
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.013460
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.003137
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.000550
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.420117
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.499751
#          Iterations: 64
#          Function evaluations: 139
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.488552
#          Iterations: 128
#          Function evaluations: 257
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.394576
#          Iterations: 32
#          Function evaluations: 71
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.418318
#          Iterations: 35
#          Function evaluations: 79
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.437548
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.479202
#          Iterations: 40
#          Function evaluations: 89
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.495939
#          Iterations: 64
#          Function evaluations: 136
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001025
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.049078
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.065320
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.015862
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.003263
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000187
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000866
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043935
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.060019
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012536
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.002307
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.000053
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000813
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043354
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.058195
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012941
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.002265
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000115
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001256
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.048116
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.062174
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.016720
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.005426
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001589
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.001402
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.057446
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.079799
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.016568
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.004744
#          Iterations: 16
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.001043
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.001086
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.052533
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.071690
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.016016
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.002721
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.000316
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.001211
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.053069
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.074187
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.014291
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.003960
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000724
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.001192
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.052415
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.072862
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.014429
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.003973
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000712
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.516348
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.580225
#          Iterations: 71
#          Function evaluations: 153
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.574576
#          Iterations: 123
#          Function evaluations: 244
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.493556
#          Iterations: 34
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.493067
#          Iterations: 34
#          Function evaluations: 76
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.503184
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.543301
#          Iterations: 38
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.561295
#          Iterations: 69
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000649
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.038089
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.052963
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.010074
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000194
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.001574
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000450
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.031161
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043454
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.007072
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000768
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.002449
#          Iterations: 17
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.000544
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.034883
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.048501
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.008466
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000033
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.001671
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000841
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.038775
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.052398
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.011232
#          Iterations: 18
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.002008
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.001620
#          Iterations: 19
#          Function evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.001006
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.046494
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.067804
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.011042
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.001274
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.001419
#          Iterations: 18
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000745
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042086
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.059911
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.010564
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.000167
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.001787
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000899
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044044
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.064460
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.009682
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000929
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.001337
#          Iterations: 19
#          Function evaluations: 41
# Optimization terminated successfully.
#          Current function value: 0.000716
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.039685
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.056784
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.009448
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000499
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.001561
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: -0.443650
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.495057
#          Iterations: 72
#          Function evaluations: 159
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.492527
#          Iterations: 126
#          Function evaluations: 240
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.416330
#          Iterations: 34
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.436146
#          Iterations: 35
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.437178
#          Iterations: 34
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.474058
#          Iterations: 39
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.488643
#          Iterations: 67
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000702
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.040663
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.056105
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011130
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.001132
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000526
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000394
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.029947
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.040799
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.007190
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.000356
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.001661
#          Iterations: 18
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.000596
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.037466
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.051730
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.009582
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000871
#          Iterations: 18
#          Function evaluations: 39
# Optimization terminated successfully.
#          Current function value: -0.000609
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000829
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.040163
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.053545
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.012148
#          Iterations: 15
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.002752
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.000174
#          Iterations: 17
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000997
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.047732
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.068799
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.011736
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.002158
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.000248
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000792
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044530
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.062883
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.011556
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000787
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: -0.000724
#          Iterations: 17
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.000906
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.045553
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.065814
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.010567
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001843
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: -0.000350
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000746
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.041724
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.059063
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.010393
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.001402
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.000526
#          Iterations: 17
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: -0.418320
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.474767
#          Iterations: 67
#          Function evaluations: 144
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.470949
#          Iterations: 123
#          Function evaluations: 240
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
# ...
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.001872
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000327
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000384
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.029987
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.039894
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.007824
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000178
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: -0.000491
#          Iterations: 17
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.000668
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.040125
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.054834
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.011013
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001629
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000253
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000893
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042606
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.056089
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.013604
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.003527
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000957
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001050
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.050173
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.071205
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.013166
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.003184
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000886
#          Iterations: 15
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.000862
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.047239
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.065835
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.013120
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001711
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000381
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000972
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.048298
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.068755
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.012053
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.002887
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000747
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.000796
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.043876
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.061007
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011969
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.002167
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.000575
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: -0.409580
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.495539
#          Iterations: 143
#          Function evaluations: 279
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.475051
#          Iterations: 132
#          Function evaluations: 253
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.385124
#          Iterations: 32
#          Function evaluations: 70
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.383279
#          Iterations: 35
#          Function evaluations: 76
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.438020
#          Iterations: 31
#          Function evaluations: 66
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.463078
#          Iterations: 38
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.498777
#          Iterations: 70
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000705
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042315
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.054133
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.013434
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.002941
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000787
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000678
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.040563
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.054661
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.010915
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.002740
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001248
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000604
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.039033
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.051168
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011292
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.002467
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000889
#          Iterations: 10
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000885
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.042007
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.052196
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.014349
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.004601
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.001232
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000932
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.048955
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.064550
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.014072
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.004399
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.001531
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000721
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044656
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.058637
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.013232
#          Iterations: 14
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.002468
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.000840
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.000763
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044310
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.059379
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.011550
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.003697
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.001390
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.000909
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.048094
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.065029
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.012150
#          Iterations: 16
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.004381
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.001836
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: -0.384942
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.499329
#          Iterations: 137
#          Function evaluations: 258
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.473912
#          Iterations: 118
#          Function evaluations: 235
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.316532
#          Iterations: 34
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.381404
#          Iterations: 34
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.471245
#          Iterations: 32
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.472043
#          Iterations: 35
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.524232
#          Iterations: 61
#          Function evaluations: 131
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.045467
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.059440
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.014130
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.003699
#          Iterations: 15
#          Function evaluations: 32

# %%
c_arr = []
date_range_arr = []
for i, file in enumerate(ls):
    train = pd.read_csv(data_path+'train/'+file)
    date_range = train.Date.iloc[-1] +' to ' + train.Date.iloc[0]
    date_range_arr.append(date_range)
    
    c = pd.DataFrame(paras_results[i])
    c.index = c.iloc[:,0]
    c = pd.DataFrame(c.iloc[:,1])
#     c.columns = ['paras']
    c_arr.append(c)
    
paras_results_pd = pd.concat(dict(zip(ls, c_arr)), axis=1)
paras_results_pd.columns = paras_results_pd.columns.droplevel(1)
paras_results_pd.index.name= None

l_arr = []
date_range_arr = []
for i, file in enumerate(ls):
    train = pd.read_csv(data_path+'train/'+file)
    date_range = train.Date.iloc[-1] +' to ' + train.Date.iloc[0]
    date_range_arr.append(date_range)
    
    c = pd.DataFrame(likelihood_results[i])
    c.index = c.iloc[:,0]
    c = pd.DataFrame(c.iloc[:,1])
#     c.columns = ['likelihood']
    l_arr.append(c)
    
likelihood_results_pd = pd.concat(dict(zip(ls, l_arr)), axis=1)
likelihood_results_pd.columns = likelihood_results_pd.columns.droplevel(1)
likelihood_results_pd.index.name= None

# %%
paras_results_pd

# %%
likelihood_results_pd

# %%
best_h_results_pd = pd.concat(dict(zip(ls, best_h_results)), axis=1)

# %%
def cap(h):
    if h < 0:
        return 0
    elif h >1:
        return 1
    else:
        return h

# %%
columns = best_h_results_pd.columns
for c in columns:
     best_h_results_pd.loc[:,c] = best_h_results_pd.loc[:,c].apply(cap)

# %%
def hedging_effectiveness(h_arr, spot, future, k_arr, q_arr):
    results = np.ones((len(h_arr),1+len(k_arr)+len(q_arr)))
    for i, h in enumerate(h_arr):
        rh = spot-h*future
        results[i,:]=1-risk_measures(k_arr, q_arr, rh)/risk_measures(k_arr, q_arr, spot)
    return np.array([results[i,i] for i in range(len(h_arr))])

# %%
date_range_arr = []
for i, file in enumerate(ls):
    train = pd.read_csv(data_path+'train/'+file)
    date_range = train.Date.iloc[-1] +' to ' + train.Date.iloc[0]
    date_range_arr.append(date_range)

# %%
display_likelihood = likelihood_results_pd.copy()
display_likelihood.columns = date_range_arr
display_likelihood = display_likelihood.reindex(sorted(display_likelihood.columns), axis=1)

# %%
display_paras = paras_results_pd.copy()
display_paras.columns = date_range_arr
display_paras = display_paras.reindex(sorted(display_paras.columns), axis=1)

# %%
display_best_h = best_h_results_pd.copy()
display_best_h.columns.set_levels(date_range_arr, level=0, inplace=True)
display_best_h = display_best_h.reindex(sorted(display_best_h.columns), axis=1)

# %%
if os.path.exists("../results/" + data_name)==False:
    print("Create new folder for results")
    os.mkdir("../results/" + data_name)
    os.mkdir("../results/" + data_name +"/MLE")
    os.mkdir("../results/" + data_name +"/MM")
    
if calibration_method == "MLE":
    path = "../results/"+ data_name +"/MLE/"
    paras_results_pd.to_json(path+"parameters.json")
    likelihood_results_pd.to_json(path+"likelihood.json")
    best_h_results_pd.to_json(path+"best_h.json")
    
    display_paras.to_html(path+"paras.html")
    display_likelihood.to_html(path+"likelihood.html")
    display_best_h.to_html(path+"best_h.html")

    
elif calibration_method == "MM":
    path = "../results/"+ data_name +"/MM/"
    paras_results_pd.to_json(path+"parameters.json")
    likelihood_results_pd.to_json(path+"likelihood.json")
    best_h_results_pd.to_json(path+"best_h.json")
    
    display_paras.to_html(path+"paras.html")
    display_likelihood.to_html(path+"likelihood.html")
    display_best_h.to_html(path+"best_h.html")

# %%
HE_results = []

for i, file in enumerate(ls):
    test = pd.read_csv(data_path+'train/'+file)
    spot   = test.loc[:,spot_name]
    future = test.loc[:,future_name]
    fn = lambda h_arr: hedging_effectiveness(h_arr, spot, future, k_arr, q_arr)
    HE = pd.DataFrame().reindex_like(best_h_results[0])
    HEs = best_h_results[i].apply(fn, axis=1)
    for i in range(len(HEs)):
        HE.iloc[i,:] = HEs[i]
    HE_results.append(HE)
HE_results_pd = pd.concat(dict(zip(ls, HE_results)), axis=1)
risk_measure_names = HE_results_pd.droplevel(0,axis=1).columns.unique()

fig, ax = plt.subplots(len(risk_measure_names), 1, figsize=(10,5*len(risk_measure_names)))
for i, name in enumerate(risk_measure_names): 
    ax[i].boxplot(HE_results_pd.droplevel(0,axis=1).loc[:,name])
    ax[i].set_xticklabels(Copulae_names)
    ax[i].set_title("In Sample Hedging Effectiveness of %s"%name)
    
if calibration_method == "MLE":
    fig.savefig("../results/"+ data_name +"/MLE/"+"In Sample Hedging Effectiveness.png", transparent=True)    
elif calibration_method == "MM":
    fig.savefig("../results/"+ data_name +"/MM/"+"In Sample Hedging Effectiveness.png", transparent=True)

# %%
HE_results = []

for i, file in enumerate(ls):
    test = pd.read_csv(data_path+'test/'+file)
    spot   = test.loc[:,spot_name]
    future = test.loc[:,future_name]
    fn = lambda h_arr: hedging_effectiveness(h_arr, spot, future, k_arr, q_arr)
    HE = pd.DataFrame().reindex_like(best_h_results[0])
    HEs = best_h_results[i].apply(fn, axis=1)
    for i in range(len(HEs)):
        HE.iloc[i,:] = HEs[i]
    HE_results.append(HE)
HE_results_pd = pd.concat(dict(zip(ls, HE_results)), axis=1)
risk_measure_names = HE_results_pd.droplevel(0,axis=1).columns.unique()

fig, ax = plt.subplots(len(risk_measure_names), 1, figsize=(10,5*len(risk_measure_names)))
for i, name in enumerate(risk_measure_names): 
    ax[i].boxplot(HE_results_pd.droplevel(0,axis=1).loc[:,name])
#     ax[i].set_xticks(np.linspace(1,len(Copulae_names)))
    ax[i].set_xticklabels(Copulae_names)
    ax[i].set_title("Out of Sample Hedging Effectiveness of %s"%name)
if calibration_method == "MLE":
    fig.savefig("../results/"+ data_name +"/MLE/"+"Out of Sample Hedging Effectiveness.png", transparent=True)    
elif calibration_method == "MM":
    fig.savefig("../results/"+ data_name +"/MM/"+"Out of Sample Hedging Effectiveness.png", transparent=True)
