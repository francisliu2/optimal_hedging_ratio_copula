# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f = lambda x: 2*x**3



delta_x = 0.0001

x_arr = np.linspace(0,5,100)
plt.plot(x_arr, f(x_arr))



f_prime = lambda x: 6*x**2



x0 = 4
tangent = f_prime(x0)


# plt.plot(x_arr, f_prime(x_arr))
