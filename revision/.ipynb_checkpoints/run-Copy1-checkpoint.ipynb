# %%
import os, sys
sys.path.append('../src')
from copulae1 import *
from KDEs import *
from toolbox import *
import json
import datetime
import pickle


import matplotlib.pyplot as plt

# %%
# Gaussian, t_Copula, Clayton, Frank, Gumbel, Plackett, Gaussian mix Indep
C1  = Gaussian(dict(rho=0.9),       Law_RS=stats.norm, Law_RF=stats.norm)
C2  = t_Copula(dict(rho=0.1, nu=4), Law_RS=stats.norm, Law_RF=stats.norm, nu_lowerbound=2)
C2c = t_Copula(dict(rho=0.1, nu=4), Law_RS=stats.norm, Law_RF=stats.norm, nu_lowerbound=4)
C3  = Clayton(dict(theta=0.1),      Law_RS=stats.norm, Law_RF=stats.norm)
C4  = Frank(dict(theta=0.1),        Law_RS=stats.norm, Law_RF=stats.norm)
C5  = Gumbel(dict(theta=3),         Law_RS=stats.norm, Law_RF=stats.norm)
C6  = Plackett(dict(theta=10),      Law_RS=stats.norm, Law_RF=stats.norm)
C7  = Gaussian_Mix_Independent(dict(rho=.5,p=0.7),Law_RS=stats.norm, Law_RF=stats.norm)
C8  = rot180Gumbel(dict(theta=3), Law_RS=stats.norm, Law_RF=stats.norm)

# %%
calibration_method = 'MM'
q_arr = [0.05,0.1,0.9,0.95]

# %%
Copulae_names = ['Gaussian', 't_Copula', 't_Copula_Capped', 'Clayton', 'Frank', 'Gumbel', 'Plackett', 'Gauss Mix Indep', 'rotGumbel']
Copulae_arr = [C1, C2, C2c, C3, C4, C5, C6, C7, C8]
Copulae = dict(zip(Copulae_names, Copulae_arr))

# %%
paras_results = []
likelihood_results = []

# %%
spot_name = 'rs'
future_name = 'rf'
data_name = 'deribit_ETHUSD_BTCUSD'
data_path = '/Volumes/external_SSD/copulaData/Deribit_ready/ETHUSD_BTCUSD/'

ls = os.listdir(data_path + 'train/')
ls = [l for l in ls if l.endswith('.csv')]

start = 0

for i, file in enumerate(ls[start:]):
	print('-----', i, len(ls), str(datetime.datetime.now()), '-----')
	# Calibration
	train = pd.read_csv(data_path + 'train/' + file)
	spot = train.loc[:, spot_name]
	future = train.loc[:, future_name]
	u = ECDF(spot)(spot)
	v = ECDF(future)(future)

	kde_brr = KDE(spot, "Gaussian")
	kde_btc = KDE(future, "Gaussian")

	for C_name in Copulae:
		Copulae[C_name].Law_RS = kde_brr
		Copulae[C_name].Law_RF = kde_btc

	paras = []
	likelihood = []
	best_h = []
	for C_name in Copulae:
		if calibration_method == "MLE":
			Copulae[C_name].canonical_calibrate(u, v)

		elif calibration_method == "MM":
			Copulae[C_name].mm_calibrate(u, v, q_arr)

		print(C_name, 'is done.\n')

	for C_name in Copulae:
		paras.append((C_name, Copulae[C_name].paras))

	for C_name in Copulae:
		ln = Copulae[C_name].dependency_likelihood(u, v)
		likelihood.append((C_name, ln))

	paras_results.append(paras)
	likelihood_results.append(likelihood)

	if (i%60==0) or (i == 0) or (i==len(ls)):
		print('saved!')
		with open(data_name+'_paras.pickle', 'wb') as f:
			pickle.dump(paras_results, f)

		with open(data_name+'_likelihood.pickle', 'wb') as f:
			pickle.dump(likelihood_results, f)
# Out:
# ----- 0 2116 2022-09-12 11:46:36.231154 -----
# Optimization terminated successfully.
#          Current function value: 0.011943
#          Iterations: 33
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012135
#          Iterations: 189
#          Function evaluations: 364
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012135
#          Iterations: 174
#          Function evaluations: 332
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.250013
#          Iterations: 42
#          Function evaluations: 93
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036611
#          Iterations: 52
#          Function evaluations: 114
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.122647
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011038
#          Iterations: 43
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011849
#          Iterations: 144
#          Function evaluations: 275
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.054856
#          Iterations: 37
#          Function evaluations: 80
# rotGumbel is done.
#
# saved!
# ----- 1 2116 2022-09-12 11:47:24.189762 -----
# Optimization terminated successfully.
#          Current function value: 0.003099
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003131
#          Iterations: 104
#          Function evaluations: 207
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003131
#          Iterations: 104
#          Function evaluations: 207
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.287687
#          Iterations: 33
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.039581
#          Iterations: 35
#          Function evaluations: 82
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.090379
#          Iterations: 32
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006881
#          Iterations: 36
#          Function evaluations: 81
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003152
#          Iterations: 64
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064168
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 2 2116 2022-09-12 11:47:59.196482 -----
# Optimization terminated successfully.
#          Current function value: 0.012682
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013485
#          Iterations: 41
#          Function evaluations: 152
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013485
#          Iterations: 39
#          Function evaluations: 147
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.220950
#          Iterations: 35
#          Function evaluations: 77
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.031214
#          Iterations: 36
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.138964
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009777
#          Iterations: 36
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012421
#          Iterations: 154
#          Function evaluations: 284
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.041135
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 3 2116 2022-09-12 11:48:25.943836 -----
# Optimization terminated successfully.
#          Current function value: 0.006742
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006757
#          Iterations: 124
#          Function evaluations: 238
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006757
#          Iterations: 122
#          Function evaluations: 234
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.282122
#          Iterations: 42
#          Function evaluations: 94
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040447
#          Iterations: 40
#          Function evaluations: 94
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076721
#          Iterations: 36
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007437
#          Iterations: 42
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006622
#          Iterations: 67
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065797
#          Iterations: 35
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 4 2116 2022-09-12 11:49:03.959683 -----
# Optimization terminated successfully.
#          Current function value: 0.024067
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024188
#          Iterations: 101
#          Function evaluations: 200
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024188
#          Iterations: 97
#          Function evaluations: 191
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.427468
#          Iterations: 39
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049289
#          Iterations: 39
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017054
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023264
#          Iterations: 37
#          Function evaluations: 86
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024066
#          Iterations: 127
#          Function evaluations: 237
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.158550
#          Iterations: 32
#          Function evaluations: 69
# rotGumbel is done.
#
# ----- 5 2116 2022-09-12 11:49:37.150016 -----
# Optimization terminated successfully.
#          Current function value: 0.009567
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009445
#          Iterations: 108
#          Function evaluations: 236
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009445
#          Iterations: 105
#          Function evaluations: 233
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.367770
#          Iterations: 35
#          Function evaluations: 76
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050189
#          Iterations: 40
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026952
#          Iterations: 33
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014635
#          Iterations: 37
#          Function evaluations: 87
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.009455
#          Iterations: 67
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.115932
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 6 2116 2022-09-12 11:50:05.364520 -----
# Optimization terminated successfully.
#          Current function value: 0.020815
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020849
#          Iterations: 117
#          Function evaluations: 227
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020849
#          Iterations: 113
#          Function evaluations: 216
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.450210
#          Iterations: 39
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.057349
#          Iterations: 38
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022120
#          Iterations: 34
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025518
#          Iterations: 41
#          Function evaluations: 95
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020666
#          Iterations: 127
#          Function evaluations: 247
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.153951
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 7 2116 2022-09-12 11:50:40.562587 -----
# Optimization terminated successfully.
#          Current function value: 0.024680
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.479631
#          Iterations: 40
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.039584
#          Iterations: 38
#          Function evaluations: 90
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030403
#          Iterations: 36
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.020654
#          Iterations: 40
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023967
#          Iterations: 80
#          Function evaluations: 158
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.166301
#          Iterations: 35
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 8 2116 2022-09-12 11:51:37.211737 -----
# Optimization terminated successfully.
#          Current function value: 0.036121
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036241
#          Iterations: 106
#          Function evaluations: 213
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036241
#          Iterations: 98
#          Function evaluations: 193
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.516362
#          Iterations: 37
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.066525
#          Iterations: 35
#          Function evaluations: 87
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026950
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038715
#          Iterations: 36
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.035735
#          Iterations: 99
#          Function evaluations: 193
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.187783
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 9 2116 2022-09-12 11:52:08.738686 -----
# Optimization terminated successfully.
#          Current function value: 0.022755
#          Iterations: 33
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025184
#          Iterations: 39
#          Function evaluations: 147
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.441423
#          Iterations: 39
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.043684
#          Iterations: 39
#          Function evaluations: 90
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.044005
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022116
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
# ../src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.021845
#          Iterations: 169
#          Function evaluations: 333
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.151858
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 10 2116 2022-09-12 11:52:52.414612 -----
# Optimization terminated successfully.
#          Current function value: 0.022681
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025144
#          Iterations: 39
#          Function evaluations: 149
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022933
#          Iterations: 123
#          Function evaluations: 285
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.441237
#          Iterations: 33
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.043885
#          Iterations: 35
#          Function evaluations: 85
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.043910
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022130
#          Iterations: 35
#          Function evaluations: 78
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021783
#          Iterations: 120
#          Function evaluations: 240
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.151777
#          Iterations: 33
#          Function evaluations: 71
# rotGumbel is done.
#
# ----- 11 2116 2022-09-12 11:53:28.639653 -----
# Optimization terminated successfully.
#          Current function value: 0.009300
#          Iterations: 31
#          Function evaluations: 62
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009404
#          Iterations: 125
#          Function evaluations: 234
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.408699
#          Iterations: 41
#          Function evaluations: 93
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040845
#          Iterations: 36
#          Function evaluations: 87
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040463
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012231
#          Iterations: 37
#          Function evaluations: 86
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008983
#          Iterations: 125
#          Function evaluations: 247
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.120958
#          Iterations: 32
#          Function evaluations: 69
# rotGumbel is done.
#
# ----- 12 2116 2022-09-12 11:54:17.136038 -----
# Optimization terminated successfully.
#          Current function value: 0.010057
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010172
#          Iterations: 113
#          Function evaluations: 243
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010172
#          Iterations: 118
#          Function evaluations: 252
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.419132
#          Iterations: 37
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.039602
#          Iterations: 35
#          Function evaluations: 82
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.033383
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011582
#          Iterations: 37
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009893
#          Iterations: 104
#          Function evaluations: 200
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.127795
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 13 2116 2022-09-12 11:55:00.154063 -----
# Optimization terminated successfully.
#          Current function value: 0.011378
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.441867
#          Iterations: 35
#          Function evaluations: 78
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.044214
#          Iterations: 35
#          Function evaluations: 85
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027858
#          Iterations: 32
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014845
#          Iterations: 39
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011129
#          Iterations: 168
#          Function evaluations: 325
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.137506
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 14 2116 2022-09-12 11:55:59.892117 -----
# Optimization terminated successfully.
#          Current function value: 0.012609
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012748
#          Iterations: 121
#          Function evaluations: 225
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012748
#          Iterations: 118
#          Function evaluations: 223
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.249691
#          Iterations: 35
#          Function evaluations: 78
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.037682
#          Iterations: 36
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.113718
#          Iterations: 36
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010843
#          Iterations: 38
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012668
#          Iterations: 113
#          Function evaluations: 217
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049010
#          Iterations: 33
#          Function evaluations: 71
# rotGumbel is done.
#
# ----- 15 2116 2022-09-12 11:56:34.300581 -----
# Optimization terminated successfully.
#          Current function value: 0.011248
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013464
#          Iterations: 39
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013464
#          Iterations: 39
#          Function evaluations: 149
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.443135
#          Iterations: 36
#          Function evaluations: 79
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045624
#          Iterations: 39
#          Function evaluations: 90
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027623
#          Iterations: 35
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015192
#          Iterations: 39
#          Function evaluations: 87
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.011127
#          Iterations: 69
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.137389
#          Iterations: 35
#          Function evaluations: 75
# rotGumbel is done.
#
# ----- 16 2116 2022-09-12 11:57:00.609690 -----
# Optimization terminated successfully.
#          Current function value: 0.003913
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003857
#          Iterations: 127
#          Function evaluations: 271
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003857
#          Iterations: 125
#          Function evaluations: 266
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.327056
#          Iterations: 38
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042526
#          Iterations: 38
#          Function evaluations: 87
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.057038
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007342
#          Iterations: 40
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003695
#          Iterations: 67
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.081967
#          Iterations: 34
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 17 2116 2022-09-12 11:57:32.786573 -----
# Optimization terminated successfully.
#          Current function value: 0.001002
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001069
#          Iterations: 126
#          Function evaluations: 236
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001069
#          Iterations: 125
#          Function evaluations: 230
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.331596
#          Iterations: 38
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034126
#          Iterations: 38
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064331
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003702
#          Iterations: 39
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001074
#          Iterations: 65
#          Function evaluations: 138
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.078796
#          Iterations: 36
#          Function evaluations: 77
# rotGumbel is done.
#
# ----- 18 2116 2022-09-12 11:58:09.771031 -----
# Optimization terminated successfully.
#          Current function value: 0.005717
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012260
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012260
#          Iterations: 37
#          Function evaluations: 147
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.314655
#          Iterations: 40
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018046
#          Iterations: 36
#          Function evaluations: 86
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.082924
#          Iterations: 34
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000411
#          Iterations: 39
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004880
#          Iterations: 137
#          Function evaluations: 254
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.082924
#          Iterations: 34
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 19 2116 2022-09-12 11:58:35.994612 -----
# Optimization terminated successfully.
#          Current function value: 0.003531
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009290
#          Iterations: 40
#          Function evaluations: 156
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009290
#          Iterations: 38
#          Function evaluations: 151
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.271831
#          Iterations: 32
#          Function evaluations: 71
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030732
#          Iterations: 34
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.099653
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005716
#          Iterations: 37
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002744
#          Iterations: 120
#          Function evaluations: 240
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.058501
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 20 2116 2022-09-12 11:59:04.899265 -----
# Optimization terminated successfully.
#          Current function value: 0.005428
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010745
#          Iterations: 42
#          Function evaluations: 164
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010745
#          Iterations: 38
#          Function evaluations: 151
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.313167
#          Iterations: 35
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049125
#          Iterations: 34
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.079217
#          Iterations: 34
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015628
#          Iterations: 36
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004779
#          Iterations: 121
#          Function evaluations: 229
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.079217
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 21 2116 2022-09-12 11:59:33.194163 -----
# Optimization terminated successfully.
#          Current function value: 0.005038
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010813
#          Iterations: 42
#          Function evaluations: 164
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010813
#          Iterations: 38
#          Function evaluations: 151
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.311858
#          Iterations: 33
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050975
#          Iterations: 36
#          Function evaluations: 85
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.078640
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016018
#          Iterations: 35
#          Function evaluations: 82
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.004554
#          Iterations: 67
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.078640
#          Iterations: 36
#          Function evaluations: 78
# rotGumbel is done.
#
# ----- 22 2116 2022-09-12 12:00:02.247456 -----
# Optimization terminated successfully.
#          Current function value: 0.009289
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010046
#          Iterations: 38
#          Function evaluations: 148
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.351742
#          Iterations: 35
#          Function evaluations: 79
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.066175
#          Iterations: 36
#          Function evaluations: 87
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.066695
#          Iterations: 32
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023735
#          Iterations: 38
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008727
#          Iterations: 68
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.092628
#          Iterations: 34
#          Function evaluations: 76
# rotGumbel is done.
#
# ----- 23 2116 2022-09-12 12:00:41.800293 -----
# Optimization terminated successfully.
#          Current function value: 0.008505
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007136
#          Iterations: 87
#          Function evaluations: 190
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007136
#          Iterations: 129
#          Function evaluations: 277
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.337286
#          Iterations: 36
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064635
#          Iterations: 34
#          Function evaluations: 79
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.072588
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021741
#          Iterations: 39
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007830
#          Iterations: 68
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.083794
#          Iterations: 33
#          Function evaluations: 70
# rotGumbel is done.
#
# ----- 24 2116 2022-09-12 12:01:04.626472 -----
# Optimization terminated successfully.
#          Current function value: 0.011890
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011526
#          Iterations: 92
#          Function evaluations: 198
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011526
#          Iterations: 92
#          Function evaluations: 195
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.384527
#          Iterations: 37
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060293
#          Iterations: 37
#          Function evaluations: 86
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051023
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022819
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011628
#          Iterations: 64
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.118310
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 25 2116 2022-09-12 12:01:24.451798 -----
# Optimization terminated successfully.
#          Current function value: 0.009845
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010126
#          Iterations: 137
#          Function evaluations: 255
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010126
#          Iterations: 133
#          Function evaluations: 250
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.311713
#          Iterations: 42
#          Function evaluations: 95
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025298
#          Iterations: 36
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.088372
#          Iterations: 34
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005026
#          Iterations: 38
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009575
#          Iterations: 93
#          Function evaluations: 186
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.077184
#          Iterations: 35
#          Function evaluations: 78
# rotGumbel is done.
#
# ----- 26 2116 2022-09-12 12:02:04.243641 -----
# Optimization terminated successfully.
#          Current function value: 0.011883
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014966
#          Iterations: 38
#          Function evaluations: 148
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014966
#          Iterations: 37
#          Function evaluations: 147
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.384379
#          Iterations: 39
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060532
#          Iterations: 37
#          Function evaluations: 88
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050993
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022867
#          Iterations: 39
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011620
#          Iterations: 61
#          Function evaluations: 129
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.118287
#          Iterations: 33
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 27 2116 2022-09-12 12:02:32.237665 -----
# Optimization terminated successfully.
#          Current function value: 0.006114
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017109
#          Iterations: 39
#          Function evaluations: 155
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017109
#          Iterations: 40
#          Function evaluations: 159
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.308596
#          Iterations: 34
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045570
#          Iterations: 37
#          Function evaluations: 88
# Frank is done.
# Optimization terminated successfully.
#          Current function value: 0.076047
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014149
#          Iterations: 40
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005721
#          Iterations: 130
#          Function evaluations: 256
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.087249
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 28 2116 2022-09-12 12:03:00.564840 -----
# Optimization terminated successfully.
#          Current function value: 0.006008
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017259
#          Iterations: 42
#          Function evaluations: 167
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017259
#          Iterations: 40
#          Function evaluations: 159
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.307935
#          Iterations: 31
#          Function evaluations: 70
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.046326
#          Iterations: 34
#          Function evaluations: 82
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.075843
#          Iterations: 32
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014305
#          Iterations: 37
#          Function evaluations: 86
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005693
#          Iterations: 70
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.087042
#          Iterations: 32
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 29 2116 2022-09-12 12:03:30.862756 -----
# Optimization terminated successfully.
#          Current function value: 0.007695
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016031
#          Iterations: 42
#          Function evaluations: 167
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016031
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.299871
#          Iterations: 33
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.046201
#          Iterations: 34
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.084785
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014604
#          Iterations: 36
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007509
#          Iterations: 67
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.080897
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 30 2116 2022-09-12 12:03:59.770169 -----
# Optimization terminated successfully.
#          Current function value: 0.003274
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005120
#          Iterations: 42
#          Function evaluations: 167
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005120
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.284087
#          Iterations: 35
#          Function evaluations: 79
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051626
#          Iterations: 38
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.090295
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013489
#          Iterations: 37
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002957
#          Iterations: 70
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060557
#          Iterations: 32
#          Function evaluations: 70
# rotGumbel is done.
#
# ----- 31 2116 2022-09-12 12:04:28.520405 -----
# Optimization terminated successfully.
#          Current function value: 0.003272
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011540
#          Iterations: 42
#          Function evaluations: 167
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011540
#          Iterations: 40
#          Function evaluations: 159
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.248942
#          Iterations: 36
#          Function evaluations: 79
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.041506
#          Iterations: 36
#          Function evaluations: 82
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.106707
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010134
#          Iterations: 39
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003066
#          Iterations: 66
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050174
#          Iterations: 34
#          Function evaluations: 76
# rotGumbel is done.
#
# ----- 32 2116 2022-09-12 12:04:58.076554 -----
# Optimization terminated successfully.
#          Current function value: 0.005815
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017691
#          Iterations: 42
#          Function evaluations: 167
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017691
#          Iterations: 40
#          Function evaluations: 159
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.230364
#          Iterations: 33
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.048203
#          Iterations: 36
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.116953
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014955
#          Iterations: 37
#          Function evaluations: 82
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005594
#          Iterations: 69
# ...
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.019918
#          Iterations: 40
#          Function evaluations: 159
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.288207
#          Iterations: 31
#          Function evaluations: 69
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027584
#          Iterations: 34
#          Function evaluations: 79
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.079689
#          Iterations: 32
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003869
#          Iterations: 37
#          Function evaluations: 82
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000901
#          Iterations: 120
#          Function evaluations: 240
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.079689
#          Iterations: 33
#          Function evaluations: 70
# rotGumbel is done.
#
# ----- 35 2116 2022-09-12 12:06:25.969254 -----
# Optimization terminated successfully.
#          Current function value: 0.013031
#          Iterations: 32
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024107
#          Iterations: 42
#          Function evaluations: 164
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024107
#          Iterations: 40
#          Function evaluations: 159
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.415936
#          Iterations: 33
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034851
#          Iterations: 34
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034011
#          Iterations: 32
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012242
#          Iterations: 37
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012500
#          Iterations: 108
#          Function evaluations: 211
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.147324
#          Iterations: 35
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 36 2116 2022-09-12 12:06:55.421693 -----
# Optimization terminated successfully.
#          Current function value: 0.017074
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017233
#          Iterations: 118
#          Function evaluations: 227
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017233
#          Iterations: 110
#          Function evaluations: 210
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.280666
#          Iterations: 41
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040571
#          Iterations: 38
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.104031
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014943
#          Iterations: 40
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017067
#          Iterations: 168
#          Function evaluations: 322
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.067716
#          Iterations: 35
#          Function evaluations: 74
# rotGumbel is done.
#
# ----- 37 2116 2022-09-12 12:07:32.125081 -----
# Optimization terminated successfully.
#          Current function value: 0.011169
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038658
#          Iterations: 38
#          Function evaluations: 147
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.393118
#          Iterations: 40
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.033843
#          Iterations: 42
#          Function evaluations: 94
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040054
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011502
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010441
#          Iterations: 175
#          Function evaluations: 331
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.138430
#          Iterations: 37
#          Function evaluations: 81
# rotGumbel is done.
#
# ----- 38 2116 2022-09-12 12:08:16.875616 -----
# Optimization terminated successfully.
#          Current function value: 0.013124
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013378
#          Iterations: 115
#          Function evaluations: 225
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036173
#          Iterations: 39
#          Function evaluations: 155
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.416420
#          Iterations: 33
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034461
#          Iterations: 34
#          Function evaluations: 80
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034162
#          Iterations: 35
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012233
#          Iterations: 35
#          Function evaluations: 77
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.012508
#          Iterations: 124
#          Function evaluations: 239
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.147458
#          Iterations: 33
#          Function evaluations: 70
# rotGumbel is done.
#
# ----- 39 2116 2022-09-12 12:08:49.009840 -----
# Optimization terminated successfully.
#          Current function value: 0.012874
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014005
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045922
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.401002
#          Iterations: 33
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038158
#          Iterations: 37
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034154
#          Iterations: 33
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014947
#          Iterations: 38
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012046
#          Iterations: 102
#          Function evaluations: 190
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.147986
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 40 2116 2022-09-12 12:09:17.376573 -----
# Optimization terminated successfully.
#          Current function value: 0.011721
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014134
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051166
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.376738
#          Iterations: 32
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040008
#          Iterations: 37
#          Function evaluations: 87
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040498
#          Iterations: 33
#          Function evaluations: 69
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015674
#          Iterations: 38
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010902
#          Iterations: 123
#          Function evaluations: 236
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.139214
#          Iterations: 33
#          Function evaluations: 72
# rotGumbel is done.
#
# ----- 41 2116 2022-09-12 12:09:45.405680 -----
# Optimization terminated successfully.
#          Current function value: 0.010322
#          Iterations: 30
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011556
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.044059
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.368750
#          Iterations: 32
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036931
#          Iterations: 37
#          Function evaluations: 87
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.046679
#          Iterations: 32
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012869
#          Iterations: 36
#          Function evaluations: 78
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009579
#          Iterations: 120
#          Function evaluations: 231
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.130017
#          Iterations: 32
#          Function evaluations: 71
# rotGumbel is done.
#
# ----- 42 2116 2022-09-12 12:10:12.679614 -----
# Optimization terminated successfully.
#          Current function value: 0.011389
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013969
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051576
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.347115
#          Iterations: 32
#          Function evaluations: 70
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040962
#          Iterations: 36
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055272
#          Iterations: 32
#          Function evaluations: 68
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015805
#          Iterations: 37
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010657
#          Iterations: 139
#          Function evaluations: 270
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.123390
#          Iterations: 32
#          Function evaluations: 69
# rotGumbel is done.
#
# ----- 43 2116 2022-09-12 12:10:40.893269 -----
# Optimization terminated successfully.
#          Current function value: 0.012627
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013834
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.046183
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.342465
#          Iterations: 33
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038889
#          Iterations: 35
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064295
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014965
#          Iterations: 37
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012009
#          Iterations: 133
#          Function evaluations: 253
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.117110
#          Iterations: 33
#          Function evaluations: 73
# rotGumbel is done.
#
# ----- 44 2116 2022-09-12 12:11:09.056323 -----
# Optimization terminated successfully.
#          Current function value: 0.012547
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013780
#          Iterations: 37
#          Function evaluations: 147
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.046277
#          Iterations: 39
#          Function evaluations: 152
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.342118
#          Iterations: 31
#          Function evaluations: 68
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.039144
#          Iterations: 35
#          Function evaluations: 81
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.064170
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014995
#          Iterations: 36
#          Function evaluations: 81
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: 0.011952
#          Iterations: 120
#          Function evaluations: 240
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.116985
#          Iterations: 32
#          Function evaluations: 68
# rotGumbel is done.
#
# ----- 45 2116 2022-09-12 12:11:36.326842 -----
# Optimization terminated successfully.
#          Current function value: 0.006029
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.

# %%
# Prettify the result
c_arr = []
date_range_arr = []
for i, file in enumerate(ls):
	train = pd.read_csv(data_path + 'train/' + file)
	date_range = train.timestamp.iloc[-1] + ' to ' + train.timestamp.iloc[0]
	date_range_arr.append(date_range)

	c = pd.DataFrame(paras_results[i])
	c.index = c.iloc[:, 0]
	c = pd.DataFrame(c.iloc[:, 1])
	c_arr.append(c)

paras_results_pd = pd.concat(dict(zip(ls, c_arr)), axis=1)
paras_results_pd.columns = paras_results_pd.columns.droplevel(1)
paras_results_pd.index.name = None

l_arr = []
date_range_arr = []
for i, file in enumerate(list(paras_results_pd.columns)):
	train = pd.read_csv(data_path + 'train/' + file)
	date_range = train.timestamp.iloc[-1] + ' to ' + train.timestamp.iloc[0]
	date_range_arr.append(date_range)

	c = pd.DataFrame(likelihood_results[i])
	c.index = c.iloc[:, 0]
	c = pd.DataFrame(c.iloc[:, 1])
	l_arr.append(c)

likelihood_results_pd = pd.concat(dict(zip(ls, l_arr)), axis=1)
likelihood_results_pd.columns = likelihood_results_pd.columns.droplevel(1)
likelihood_results_pd.index.name = None

# %%
# Save results as html for display
display_paras = paras_results_pd.copy()
display_paras.columns = date_range_arr
display_paras = display_paras.reindex(sorted(display_paras.columns), axis=1)

display_likelihood = likelihood_results_pd.copy()
display_likelihood.columns = date_range_arr
display_likelihood = display_likelihood.reindex(sorted(display_likelihood.columns), axis=1)

# Save files to designated directories
if not os.path.exists("../results/" + data_name):
	print("Create new folder for results")
	os.mkdir("../results/" + data_name)
	os.mkdir("../results/" + data_name + "/MLE")
	os.mkdir("../results/" + data_name + "/MM")

if calibration_method == "MLE":
	path = "../results/" + data_name + "/MLE/"
	paras_results_pd.to_json(path + "parameters.json")
	likelihood_results_pd.to_json(path + "likelihood.json")

	display_paras.to_html(path + "paras.html")
	display_likelihood.to_html(path + "likelihood.html")

elif calibration_method == "MM":
	path = "../results/" + data_name + "/MM/"
	paras_results_pd.to_json(path + "parameters.json")
	likelihood_results_pd.to_json(path + "likelihood.json")

	display_paras.to_html(path + "paras.html")
	display_likelihood.to_html(path + "likelihood.html")

print('Done')
