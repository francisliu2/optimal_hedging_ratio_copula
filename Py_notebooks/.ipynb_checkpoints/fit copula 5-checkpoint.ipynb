# %%
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy.stats import norm
import pandas as pd
import numpy as np
import seaborn as sns
from statsmodels.distributions.empirical_distribution import ECDF
from copulae1 import *
from KDEs import *
from toolbox import *
import warnings
import itertools
import os
warnings.filterwarnings("ignore")

data = pd.read_csv('../processed_data/btc_future_crix.csv')
data.head()

ecdf_brr = ECDF(data.return_brr)
ecdf_btc = ECDF(data.return_btc)

u = ecdf_brr(data.return_brr)
v = ecdf_btc(data.return_btc)

brr = np.array(data.return_brr)
btc = np.array(data.return_btc)

kde_brr = KDE(data.return_brr, "Gaussian")
kde_btc = KDE(data.return_btc, "Gaussian")

kde_brr = KDE(data.return_brr, "Gaussian", kde_brr.h_brot*3)
kde_btc = KDE(data.return_brr, "Gaussian", kde_btc.h_brot*3)

# %%
# Gaussian, t_Copula, Clayton, Frank, Gumbel, Plackett, Gaussian mix Indep
C1  = Gaussian(dict(rho=0.9),       Law_RS=kde_brr, Law_RF=kde_btc) # fix the maringals!
C2  = t_Copula(dict(rho=0.1, nu=4), Law_RS=kde_brr, Law_RF=kde_btc, nu_lowerbound=2) 
C2c = t_Copula(dict(rho=0.1, nu=4), Law_RS=kde_brr, Law_RF=kde_btc, nu_lowerbound=4) 
C3  = Clayton(dict(theta=0.1),      Law_RS=kde_brr, Law_RF=kde_btc)
C4  = Frank(dict(theta=0.1),        Law_RS=kde_brr, Law_RF=kde_btc)
C5  = Gumbel(dict(theta=3),         Law_RS=kde_brr, Law_RF=kde_btc)
C6  = Plackett(dict(theta=10),      Law_RS=kde_brr, Law_RF=kde_btc)
C7  = Gaussian_Mix_Independent(dict(rho=.5,p=0.7),Law_RS=kde_brr, Law_RF=kde_btc)
Copulae_names = ['Gaussian', 't_Copula', 't_Copula_Capped', 'Clayton', 'Frank', 'Gumbel', 'Plackett', 'Gauss Mix Indep']
Copulae_arr   = [C1,C2,C2c,C3,C4,C5,C6,C7]
Copulae = dict(zip(Copulae_names, Copulae_arr))

# %%
k_arr = [10,20]
q_arr = [0.01,0.05,0.1]
h_arr = optimize_h(C1, k_arr, q_arr)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.032727
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.041831
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010180
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001184
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000313
#          Iterations: 15
#          Function evaluations: 33

# %%
for h in h_arr:
    rs = data.return_brr
    rf = data.return_btc
    rh = rs - h*rf
    risk_measures()

# %%
data_name = "future_brr_v4"
data_path = "../processed_data/"+data_name+"/"

spot_name = "log return brr"
future_name = "log return future"

paras_results = []
likelihood_results = []

calibration_method = "MLE" # MM or MLE
q_arr = [0.05,0.1,0.9,0.95]

ls = os.listdir(data_path+'train/')
ls = [l for l in ls if l.endswith('.csv')]
for file in ls:
    # Calibration 
    train = pd.read_csv(data_path+'train/'+file)
    spot   = train.loc[:,spot_name]
    future = train.loc[:,future_name]
    u = ECDF(spot)(spot)
    v = ECDF(future)(future)
    
    kde_brr = KDE(spot, "Gaussian")
    kde_btc = KDE(future, "Gaussian")
    
    for C_name in Copulae:
        Copulae[C_name].Law_RS = kde_brr
        Copulae[C_name].Law_RF = kde_btc
    
    paras = []
    likelihood = []
    for C_name in Copulae:
        if calibration_method == "MLE":
            Copulae[C_name].canonical_calibrate(u,v)
            
        elif calibration_method == "MM":
            Copulae[C_name].mm_calibrate(u,v,q_arr)

        print(C_name,'is done.\n')
    
    for C_name in Copulae:
        paras.append((C_name,Copulae[C_name].paras))
        
    for C_name in Copulae:
        ln = Copulae[C_name].dependency_likelihood(u,v)
        likelihood.append((C_name,ln))
        
    paras_results.append(paras)
    likelihood_results.append(likelihood)
    
    # Get Best h

#     # Testing
#     test = pd.read_csv(data_path+'test/'+file)
#     spot_test   = train.loc[:,spot_name]
#     future_test = train.loc[:,future_name]
# Out:
# 6.csv
# Optimization terminated successfully.
#          Current function value: -0.416899
#          Iterations: 33
#          Function evaluations: 71
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.522612
#          Iterations: 119
#          Function evaluations: 224
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.502592
#          Iterations: 175
#          Function evaluations: 338
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.388826
#          Iterations: 41
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.422036
#          Iterations: 41
#          Function evaluations: 88
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.449668
#          Iterations: 36
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.503845
#          Iterations: 41
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.524252
#          Iterations: 61
#          Function evaluations: 134
# Gauss Mix Indep is done.
#
# 7.csv
# Optimization terminated successfully.
#          Current function value: -0.368599
#          Iterations: 31
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.437328
#          Iterations: 73
#          Function evaluations: 154
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.428291
#          Iterations: 123
#          Function evaluations: 244
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.307838
#          Iterations: 35
#          Function evaluations: 76
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.371233
#          Iterations: 36
#          Function evaluations: 77
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.404987
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.431727
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.442052
#          Iterations: 66
#          Function evaluations: 140
# Gauss Mix Indep is done.
#
# 5.csv
# Optimization terminated successfully.
#          Current function value: -0.430557
#          Iterations: 31
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.519839
#          Iterations: 135
#          Function evaluations: 250
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.505821
#          Iterations: 138
#          Function evaluations: 268
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.402116
#          Iterations: 36
#          Function evaluations: 77
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.429814
#          Iterations: 34
#          Function evaluations: 77
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.452294
#          Iterations: 31
#          Function evaluations: 68
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.500816
#          Iterations: 38
#          Function evaluations: 89
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.517188
#          Iterations: 59
#          Function evaluations: 128
# Gauss Mix Indep is done.
#
# 4.csv
# Optimization terminated successfully.
#          Current function value: -0.420117
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.499751
#          Iterations: 66
#          Function evaluations: 141
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.488552
#          Iterations: 128
#          Function evaluations: 257
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.394576
#          Iterations: 32
#          Function evaluations: 68
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.418318
#          Iterations: 34
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.437548
#          Iterations: 33
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.479202
#          Iterations: 37
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.495939
#          Iterations: 61
#          Function evaluations: 129
# Gauss Mix Indep is done.
#
# 0.csv
# Optimization terminated successfully.
#          Current function value: -0.516348
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.580225
#          Iterations: 68
#          Function evaluations: 154
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.574576
#          Iterations: 126
#          Function evaluations: 241
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.493556
#          Iterations: 35
#          Function evaluations: 78
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.493067
#          Iterations: 34
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.503184
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.543301
#          Iterations: 38
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.561295
#          Iterations: 64
#          Function evaluations: 135
# Gauss Mix Indep is done.
#
# 1.csv
# Optimization terminated successfully.
#          Current function value: -0.443650
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.495057
#          Iterations: 66
#          Function evaluations: 141
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.492527
#          Iterations: 124
#          Function evaluations: 240
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.416330
#          Iterations: 34
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.436146
#          Iterations: 36
#          Function evaluations: 79
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.437178
#          Iterations: 34
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.474058
#          Iterations: 39
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.488643
#          Iterations: 67
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# 3.csv
# Optimization terminated successfully.
#          Current function value: -0.418320
#          Iterations: 31
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.474767
#          Iterations: 69
#          Function evaluations: 151
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.470949
#          Iterations: 115
#          Function evaluations: 221
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.389952
#          Iterations: 34
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.416802
#          Iterations: 33
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.420775
#          Iterations: 32
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.461078
#          Iterations: 35
#          Function evaluations: 82
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: -0.472263
#          Iterations: 69
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# 2.csv
# Optimization terminated successfully.
#          Current function value: -0.418842
#          Iterations: 30
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.456023
#          Iterations: 81
#          Function evaluations: 165
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.455310
#          Iterations: 114
#          Function evaluations: 218
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.385864
#          Iterations: 33
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.414520
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.403608
#          Iterations: 32
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.443237
#          Iterations: 37
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.449717
#          Iterations: 69
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# 14.csv
# Optimization terminated successfully.
#          Current function value: -0.409580
#          Iterations: 30
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.495539
#          Iterations: 124
#          Function evaluations: 242
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.475051
#          Iterations: 139
#          Function evaluations: 261
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.385124
#          Iterations: 33
#          Function evaluations: 72
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.383279
#          Iterations: 35
#          Function evaluations: 78
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.438020
#          Iterations: 31
#          Function evaluations: 66
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.463078
#          Iterations: 37
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.498777
#          Iterations: 70
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# 10.csv
# Optimization terminated successfully.
#          Current function value: -0.384942
#          Iterations: 32
#          Function evaluations: 69
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.499329
#          Iterations: 134
#          Function evaluations: 265
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.473912
#          Iterations: 118
#          Function evaluations: 235
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.316532
#          Iterations: 33
#          Function evaluations: 71
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.381404
#          Iterations: 33
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.471245
#          Iterations: 32
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.472043
#          Iterations: 36
#          Function evaluations: 83
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.524232
#          Iterations: 58
#          Function evaluations: 127
# Gauss Mix Indep is done.
#
# 11.csv
# Optimization terminated successfully.
#          Current function value: -0.420365
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.547063
#          Iterations: 129
#          Function evaluations: 240
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.518672
#          Iterations: 127
#          Function evaluations: 242
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.368770
#          Iterations: 35
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.414260
#          Iterations: 33
#          Function evaluations: 72
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.501483
#          Iterations: 32
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.516326
#          Iterations: 38
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.571365
#          Iterations: 61
#          Function evaluations: 128
# Gauss Mix Indep is done.
#
# 13.csv
# Optimization terminated successfully.
#          Current function value: -0.421787
#          Iterations: 30
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.551734
#          Iterations: 107
#          Function evaluations: 205
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.517582
#          Iterations: 85
#          Function evaluations: 168
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.409561
#          Iterations: 32
#          Function evaluations: 68
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.393226
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.484440
#          Iterations: 32
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.492865
#          Iterations: 39
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.573998
#          Iterations: 66
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# 12.csv
# Optimization terminated successfully.
#          Current function value: -0.387018
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.515343
#          Iterations: 122
#          Function evaluations: 233
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.481691
#          Iterations: 130
#          Function evaluations: 253
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.355515
#          Iterations: 34
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.368021
#          Iterations: 34
#          Function evaluations: 75
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.458916
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.471921
#          Iterations: 39
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.549071
#          Iterations: 61
#          Function evaluations: 130
# Gauss Mix Indep is done.
#
# 9.csv
# Optimization terminated successfully.
#          Current function value: -0.370512
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.482167
#          Iterations: 124
#          Function evaluations: 249
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.456625
#          Iterations: 128
#          Function evaluations: 257
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.308915
#          Iterations: 33
#          Function evaluations: 71
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.377141
#          Iterations: 33
#          Function evaluations: 74
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.430489
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.466424
#          Iterations: 36
#          Function evaluations: 81
# Plackett is done.
# Optimization terminated successfully.
#          Current function value: -0.495441
#          Iterations: 66
#          Function evaluations: 133
# Gauss Mix Indep is done.
#
# 8.csv
# Optimization terminated successfully.
#          Current function value: -0.351742
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: -0.434784
#          Iterations: 124
#          Function evaluations: 245
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: -0.418866
#          Iterations: 160
#          Function evaluations: 304
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: -0.295954
#          Iterations: 33
#          Function evaluations: 73
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: -0.351254
#          Iterations: 34
#          Function evaluations: 76
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: -0.394305
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: -0.421612
#          Iterations: 40
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: -0.444567
#          Iterations: 70
#          Function evaluations: 146
# Gauss Mix Indep is done.

# %%
c_arr = []
date_range_arr = []
for i, file in enumerate(ls):
    train = pd.read_csv('../processed_data/crix_brr/train/'+file)
    date_range = train.Date.iloc[-1] +' to ' + train.Date.iloc[0]
    date_range_arr.append(date_range)
    
    c = pd.DataFrame(paras_results[i])
    c.index = c.iloc[:,0]
    c = pd.DataFrame(c.iloc[:,1])
    c.columns = ['paras']
    c_arr.append(c)

# %%
result = pd.concat(dict(zip(ls, c_arr)), axis=1)

# %%
if os.path.exists("../results/" + data_name)==False:
    print("Create new folder for results")
    os.mkdir("../results/" + data_name)
    os.mkdir("../results/" + data_name +"/MLE")
    os.mkdir("../results/" + data_name +"/MM")
    
if calibration_method == "MLE":
    result.to_json("../results/"+ data_name +"/MLE/parameters.json")
    
elif calibration_method == "MM":
    result.to_json("../results/"+ data_name +"/MM/parameters.json")

# %%
Gaussian(a.loc['Gaussian','6.csv'], stats.norm, stats.norm).paras
# Out:
# {'rho': 0.8100593574}
