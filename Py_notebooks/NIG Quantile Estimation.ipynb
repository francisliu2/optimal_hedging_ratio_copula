# %%
import numpy as np
from scipy import integrate
from toolbox import *
import numba as nb
from memorize import memorize
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
alpha = 1
beta = 0
mu = 0
delta = 1
gamma = np.sqrt(alpha**2-beta**2)
x=10

@nb.jit(nopython=True)
def fn(t):
    c = np.exp(1j*mu*t + delta*(gamma-np.sqrt(alpha**2-(beta+1j*t)**2)))
    return (np.exp(-1j*t*x)*c).imag/t

# fn = lambda t: (np.exp(-1j*t*x)*cf(t)).imag/t

@memorize()
def cdf(x):
    return 0.5-integrate.quad(fn, 0, np.inf)[0]/np.pi

# %time cdf(0.1)
# cf = lambda t: (np.exp(-1j*t*x)*np.exp(1j*mu*t + delta*(gamma-np.sqrt(alpha**2-(beta+1j*t)**2)))/t).imag
# Out:
# CPU times: user 341 ms, sys: 16.4 ms, total: 358 ms
# Wall time: 371 ms
# 0.99999865901211

# %%
q_arr = np.linspace(0.001,.99,500)

# %%
# %%time
for q in q_arr:
    fn = lambda x: (NIG.cdf(x)-q)**2
    scipy.optimize.fmin(fn, NIG.ppf_approx(q))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'NIG' is not defined

# %%
# %%time
for q in q_arr:
    fn = lambda x: (NIG.cdf(x)-q)**2
    scipy.optimize.fmin(fn, 0)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 58
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 30
#          Function evaluations: 60
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 56
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 56
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 56
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
#          Function evaluations: 58
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 29
# ...

# %%
# %%time
for q in q_arr:
    NIG.ppf_approx(q)
# Out:
# CPU times: user 99.3 ms, sys: 11.1 ms, total: 110 ms
# Wall time: 111 ms

# %%
result
# Out:
# [array([-1.139]), array([-0.68925]), array([-0.4124375])]

# %%
NIG = norminvgauss(alpha, beta, mu, delta)

# %%
# %%time 
NIG.cdf(10)
# Out:
# CPU times: user 2.2 ms, sys: 47 µs, total: 2.25 ms
# Wall time: 3.16 ms
# 0.9999986590152509

# %%
# %%time
0.5-integrate.quad(fn, 0, np.inf)[0]/np.pi
# Out:
# CPU times: user 7.09 ms, sys: 274 µs, total: 7.36 ms
# Wall time: 7.43 ms
# 0.99999865901211

# %%
a=100000
b = 1000
c = np.inf
x=1

part1 = lambda t: (np.exp(-1j*a*t) - np.exp(-1j*b*t) )/(1j*t)
fn = lambda t: part1(t)*cf(t)
0.5-integrate.quad(fn, -c,c)[0]/np.pi
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   del sys.path[0]
# -0.026530387648687315

# %%
# %%time
0.5-integrate.quad(fn, -c,c)[0]/np.pi
# Out:
# CPU times: user 32 ms, sys: 1.8 ms, total: 33.8 ms
# Wall time: 33.7 ms
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   """Entry point for launching an IPython kernel.
# -0.026530387648687315

# %%
a = -1
c = 10000
cf = lambda t: np.exp(1j*mu*t + delta*(gamma-np.sqrt(alpha**2-(beta+1j*t)**2)))
fn = lambda t: (np.exp(-1j*a*t)- np.exp(-1j*x*t))/(1j*t)*cf(t)

scipy.integrate.quad(fn, -c,c)
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in cdouble_scalars
#   after removing the cwd from sys.path.
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
# (nan, nan)

# %%
# %%time 
NIG.cdf(10)
# Out:
# CPU times: user 2.14 ms, sys: 1 µs, total: 2.14 ms
# Wall time: 2.15 ms
# 0.9999986590152509

# %%
# %%time 
stats.norm.cdf(10)
# Out:
# CPU times: user 267 µs, sys: 47 µs, total: 314 µs
# Wall time: 255 µs
# 1.0

# %%
alpha = 0.2
beta  = 0
mu    = 0
delta = 1

def pdf(x):
    part1 = alpha*delta
    part2 = scipy.special.kv(1.0, alpha*np.sqrt(delta**2 + (x-mu)**2))
    part3 = np.pi * np.sqrt(delta**2 + (x-mu)**2)
    part4 = np.exp(delta*gamma + beta*(x-mu))
    return part1*part2*part4/part3

def cdf(y):
    return scipy.integrate.quad(pdf, -np.inf, y)[0]

# %%
plt.plot(x_arr, [NIG.pdf(x) for x in x_arr])

# %%
sns.distplot(NIG.rvs(10000))
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
NIG = norminvgauss(alpha, beta, mu, delta)
# Out:
# array([46.22136809])

# %%
# %%time
# upper = np.ceil(NIG.ppf(1))
# lower = np.ceil(NIG.ppf(0))

upper = np.array([30])
lower = np.array([-30])

L = upper-lower
d = 10**(-4)
n = int(L/d)
# n = 500000
# d = L/n
x_arr = np.linspace(lower,upper,n)[:,0]

integrand = NIG.pdf(x_arr)
Probabilities = np.cumsum((integrand[:-1] +integrand[1:])*d/2)
# Probabilities = np.append(Probabilities,1)
# q_arr = stats.uniform.rvs(size=200)
# q_arr = np.sort(q_arr)

q_arr = np.linspace(0,1,1000)

# range_ids = (Probabilities<=max(q_arr)) & (Probabilities>=min(q_arr))
# Probabilities = Probabilities[range_ids]
# x_arr = x_arr[1:][range_ids]
result = []
# for q in q_arr:
#     result.append(x_arr[np.argmin((Probabilities-q)**2)])
#     result.append(x_arr[(Probabilities <= q)][-1])
#     result.append(x_arr[np.sum(Probabilities <=q)])
# result2 = x_arr[(np.ceil(q_arr*n)-1).astype(int)]
m=0
for q in q_arr:
    k = np.sum(Probabilities[m:] <=q)
    result.append(x_arr[m+k])
    m += k
result = np.array(result)
# Out:
# CPU times: user 577 ms, sys: 3.67 ms, total: 581 ms
# Wall time: 585 ms

# %%
# %%time
result1 = []
for q in q_arr:
    result1.append(NIG.ppf(q)[0])
result1 = np.array(result1)
# Out:
# CPU times: user 6.28 s, sys: 38.2 ms, total: 6.31 s
# Wall time: 6.34 s

# %%
error = (result - result1)/(result1)

# %%
plt.plot(error)

# %%
plt.plot([NIG.cdf(result[i]) - NIG.cdf(result1[i]) for i in range(len(result))])

# %%
# Out:
# 0.999987968066867
