# %%
import os

# %%
# !python calibration.py --config configs/BBT_future_CRIX_MM.json
# !python get_OHR.py --config configs/BBT_future_CRIX_MM.json
# !python get_HEs.py --config configs/BBT_future_CRIX_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Gaussian {'rho': 0.9658433209}
# t_Copula {'rho': 0.9654705168000001, 'nu': 87.2651321015}
# t_Copula_Capped {'rho': 0.9654705187, 'nu': 87.2651321028}
# Clayton {'theta': 38.4899328614}
# Frank {'theta': 38.4508349705}
# Gumbel {'theta': 6.8822954223}
# Plackett {'theta': 279.8236083984}
# Gauss Mix Indep {'rho': 0.973331421, 'p': 0.9746742939}
# Optimization terminated successfully.
#          Current function value: 0.000208
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.022743
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.049735
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.033868
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040057
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.023668
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000209
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.022792
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.050031
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.033943
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040102
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.023745
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000209
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.022792
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.050031
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.033943
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040102
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.023745
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000187
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016896
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.049845
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.026803
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.028156
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.009980
#          Iterations: 11
#          Function evaluations: 24
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000644
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.045979
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.118501
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.072538
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.085300
#          Iterations: 18
#          Function evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.046948
#          Iterations: 16
#          Function evaluations: 32
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000200
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.022376
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.056001
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.035221
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.041963
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.022368
#          Iterations: 10
#          Function evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000325
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.026331
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.085733
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.044678
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.056546
#          Iterations: 13
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.022827
#          Iterations: 10
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000286
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.024568
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.072753
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.038584
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.042840
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.022808
#          Iterations: 11
#          Function evaluations: 23
# Gaussian {'rho': 0.9822527512}
# t_Copula {'rho': 0.9771762127, 'nu': 3.6634481956}
# t_Copula_Capped {'rho': 0.977616778, 'nu': 4.0}
# Clayton {'theta': 55.0348968087}
# Frank {'theta': 38.3172319679}
# Gumbel {'theta': 10.1240872983}
# Plackett {'theta': 617.1901537687}
# Gauss Mix Indep {'rho': 0.9892686407000001, 'p': 0.9703934867}
# Optimization terminated successfully.
#          Current function value: 0.000110
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016254
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.037813
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.024849
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.029998
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.016628
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000126
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017153
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.043307
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.026531
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.031852
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.017151
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000124
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017073
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.042803
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.026369
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.031592
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.017122
#          Iterations: 11
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000125
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.013179
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.044855
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.022402
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.024816
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.008162
#          Iterations: 12
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000603
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044061
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.121532
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.073306
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.089726
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.044090
#          Iterations: 15
#          Function evaluations: 31
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000100
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015213
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.041408
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024710
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.030247
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.014356
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000187
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.018839
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.068949
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.033116
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.042224
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.015475
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000211
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.018472
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.071341
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.030925
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.033009
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.014835
#          Iterations: 11
#          Function evaluations: 23
# Gaussian {'rho': 0.9901403}
# t_Copula {'rho': 0.9845389800000001, 'nu': 2.0}
# t_Copula_Capped {'rho': 0.9873737571000001, 'nu': 4.0}
# Clayton {'theta': 102.2462308962}
# Frank {'theta': 38.2435110123}
# Gumbel {'theta': 12.917109478}
# Plackett {'theta': 1256.2684591572}
# Gauss Mix Indep {'rho': 0.9949478885, 'p': 0.9730054319}
# Optimization terminated successfully.
#          Current function value: 0.000060
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.011002
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.032742
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.017237
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.018983
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010316
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000086
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.012660
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.041620
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.020594
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.023304
#          Iterations: 10
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.011448
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000067
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.011685
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.034981
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.018488
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.020596
#          Iterations: 10
#          Function evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.011029
#          Iterations: 13
#          Function evaluations: 27
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in multiply
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.007364
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.038519
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.013736
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.019291
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.002810
#          Iterations: 10
#          Function evaluations: 20
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000563
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.039432
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.131220
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.068918
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.079777
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.033150
#          Iterations: 16
#          Function evaluations: 34
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000074
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.011489
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.039324
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.019169
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.020425
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009902
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000118
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.013093
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.059896
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024097
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.028243
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.009249
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000152
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.013343
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.067981
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.023685
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024980
#          Iterations: 10
#          Function evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.008487
#          Iterations: 10
#          Function evaluations: 22
# Gaussian {'rho': 0.9851380799}
# t_Copula {'rho': 0.9849785933, 'nu': 87.2651321028}
# t_Copula_Capped {'rho': 0.9849785936000001, 'nu': 87.2651321025}
# Clayton {'theta': 60.5321305743}
# Frank {'theta': 38.3172319679}
# Gumbel {'theta': 10.9804928292}
# Plackett {'theta': 700.3450258724}
# Gauss Mix Indep {'rho': 0.9871109839000001, 'p': 0.9927183215000001}
# Optimization terminated successfully.
#          Current function value: 0.000098
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015408
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040789
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024356
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.029427
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.014726
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000099
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015443
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040799
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024402
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.029540
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.014807
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000099
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015443
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040799
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024402
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.029540
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.014807
#          Iterations: 13
#          Function evaluations: 26
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000109
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.012511
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.049319
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.022704
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.029040
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.007788
#          Iterations: 11
#          Function evaluations: 23
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000722
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.047098
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.147314
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.081865
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.105068
#          Iterations: 16
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.041171
#          Iterations: 16
#          Function evaluations: 33
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000106
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.014824
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.047786
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.024736
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.029674
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.012583
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000202
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.018975
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.076687
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.034561
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.044542
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.014590
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000122
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015726
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.048121
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.025450
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.029588
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.014192
#          Iterations: 12
#          Function evaluations: 26
# Gaussian {'rho': 0.9941865742}
# t_Copula {'rho': 0.9906682551, 'nu': 2.0}
# t_Copula_Capped {'rho': 0.9924590044, 'nu': 4.0}
# Clayton {'theta': 95.0078994125}
# Frank {'theta': 38.3172319679}
# Gumbel {'theta': 19.1330574046}
# Plackett {'theta': 2412.9186258977}
# Gauss Mix Indep {'rho': 0.9972859331, 'p': 0.9795512559}
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.010140
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.026511
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016088
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.019222
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.009513
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000053
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.011082
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.032312
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017744
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020604
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.010265
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000042
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.010462
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.027843
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016482
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.019406
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.009974
#          Iterations: 12
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in multiply
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000048
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009250
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.037274
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.017227
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.022469
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.005812
#          Iterations: 11
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000643
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044960
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.143955
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.079573
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.100991
#          Iterations: 15
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.037664
#          Iterations: 15
#          Function evaluations: 32
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009390
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.028214
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.015398
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017050
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.007722
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000075
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.011452
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.046944
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020740
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.025251
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.008605
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000114
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.011734
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.055587
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020658
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.019480
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.007798
#          Iterations: 12
#          Function evaluations: 24
# Gaussian {'rho': 0.9941088314000001}
# t_Copula {'rho': 0.9906682551, 'nu': 2.0}
# t_Copula_Capped {'rho': 0.9923475634000001, 'nu': 4.0}
# Clayton {'theta': 94.7457337645}
# Frank {'theta': 38.3172319679}
# Gumbel {'theta': 18.9880491272}
# Plackett {'theta': 2408.3384397853}
# Gauss Mix Indep {'rho': 0.9974617946000001, 'p': 0.977460972}
# Optimization terminated successfully.
#          Current function value: 0.000038
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010409
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.026781
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016583
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.019785
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010021
#          Iterations: 14
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.000054
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.011283
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.032465
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.018086
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.021021
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.010635
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010730
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.028114
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016944
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020002
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.010441
#          Iterations: 12
#          Function evaluations: 26
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in multiply
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000049
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.009596
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.038742
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.017761
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.023095
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.006433
#          Iterations: 12
#          Function evaluations: 24
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000624
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.045014
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.140654
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.079352
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.097883
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.039238
#          Iterations: 16
#          Function evaluations: 34
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000040
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.009675
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.028681
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.016002
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.018008
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.008084
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000075
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.011654
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.047075
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.021125
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.025696
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.009143
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000123
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.012209
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.058781
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.021694
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020390
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.008258
#          Iterations: 13
#          Function evaluations: 28
# Gaussian {'rho': 0.9913574853}
# t_Copula {'rho': 0.9864572834, 'nu': 2.0}
# t_Copula_Capped {'rho': 0.9889408579000001, 'nu': 4.0}
# Clayton {'theta': 103.6478937338}
# Frank {'theta': 38.2435110123}
# Gumbel {'theta': 14.1691550968}
# Plackett {'theta': 1462.0511875361}
# Gauss Mix Indep {'rho': 0.9957464842, 'p': 0.9746704975}
# Optimization terminated successfully.
#          Current function value: 0.000051
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.010772
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.030558
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.016702
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.018967
#          Iterations: 10
#          Function evaluations: 20
# ...
# Gaussian {'rho': 0.9811914062}
# t_Copula {'rho': 0.9791276457, 'nu': 9.1400544079}
# t_Copula_Capped {'rho': 0.9791276462, 'nu': 9.1400586636}
# Clayton {'theta': 55.0555119799}
# Frank {'theta': 37.7057998293}
# Gumbel {'theta': 9.6311611136}
# Plackett {'theta': 558.4365877282}
# Gauss Mix Indep {'rho': 0.9863618957, 'p': 0.9781883393}
# Optimization terminated successfully.
#          Current function value: 0.000112
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.016833
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.038628
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.025448
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.030457
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.017178
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000118
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017173
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040283
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.026035
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.031090
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.017496
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000118
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017173
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.040283
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.026035
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.031090
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.017496
#          Iterations: 11
#          Function evaluations: 23
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000120
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.013341
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.045375
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.022294
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.024940
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.008458
#          Iterations: 11
#          Function evaluations: 22
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000587
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.041997
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.122839
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.071256
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.086136
#          Iterations: 15
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.039750
#          Iterations: 12
#          Function evaluations: 28
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000106
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015974
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.042887
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.025451
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.030513
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015106
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000199
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.019854
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.072140
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.034681
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.044154
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.016457
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000187
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.018619
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.064563
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.030150
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.032470
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.016049
#          Iterations: 11
#          Function evaluations: 24
# Gaussian {'rho': 0.9801205377000001}
# t_Copula {'rho': 0.9701168809, 'nu': 2.1316848556}
# t_Copula_Capped {'rho': 0.9748369077000001, 'nu': 4.0}
# Clayton {'theta': 50.7913735592}
# Frank {'theta': 37.7057998293}
# Gumbel {'theta': 9.653765376900001}
# Plackett {'theta': 551.3784289101}
# Gauss Mix Indep {'rho': 0.9893671434, 'p': 0.9605008915000001}
# Optimization terminated successfully.
#          Current function value: 0.000125
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.018654
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.042268
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.028326
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.034079
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.019214
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000171
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020506
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.056516
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.032068
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.037995
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.019637
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000140
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.019400
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.047638
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.029687
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.035494
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.019452
#          Iterations: 12
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000139
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015519
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.047650
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.025361
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.027845
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.010194
#          Iterations: 11
#          Function evaluations: 22
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000617
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.044643
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.125360
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.075132
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.092659
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.043777
#          Iterations: 12
#          Function evaluations: 26
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000113
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017376
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.045415
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.027709
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.033590
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.016666
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000208
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.021260
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.074030
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.036604
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.046445
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.017925
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000256
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.021482
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.082257
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.035986
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.039726
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.017108
#          Iterations: 11
#          Function evaluations: 23
# get_OHR.py:114: FutureWarning: inplace is deprecated and will be removed in a future version.
#   display_best_h.columns.set_levels(date_range_arr, level=0, inplace=True)
# Done! Please find the OHR in ../results/BBT_future_CRIX/MM/
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Done! Please find the hedging effectiveness in ../results/BBT_future_CRIX/MM/
