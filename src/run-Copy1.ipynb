# %%
import os

# %%
# !python calibration.py --config configs/BBT_future_Tiingo_ltc_MM.json
# !python get_OHR.py --config configs/BBT_future_Tiingo_ltc_MM.json
# !python get_HEs.py --config configs/BBT_future_Tiingo_ltc_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.004138
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001485
#          Iterations: 125
#          Function evaluations: 256
# t_Copula is done.
#
# ...

# %%
# !python calibration.py --config configs/BBT_future_Tiingo_xrp_MM.json
# !python get_OHR.py --config configs/BBT_future_Tiingo_xrp_MM.json
# !python get_HEs.py --config configs/BBT_future_Tiingo_xrp_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.016757
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
# ...

# %%
# !python calibration.py --config configs/BBT_future_BITX_MM.json
# !python get_OHR.py --config configs/BBT_future_BITX_MM.json
# !python get_HEs.py --config configs/BBT_future_BITX_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.014729
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
# ...
