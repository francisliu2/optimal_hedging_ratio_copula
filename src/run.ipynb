# %%
import os

# %%
# !python calibration.py --config configs/BBT_Tiingo_MM.json
# !python get_OHR.py --config configs/BBT_Tiingo_MM.json
# !python get_HEs.py --config configs/BBT_Tiingo_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.005380
#          Iterations: 32
#          Function evaluations: 65
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005386
#          Iterations: 165
#          Function evaluations: 314
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025177
#          Iterations: 54
#          Function evaluations: 118
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.063182
#          Iterations: 67
#          Function evaluations: 137
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017389
#          Iterations: 42
#          Function evaluations: 90
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003567
#          Iterations: 55
#          Function evaluations: 127
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004973
#          Iterations: 82
#          Function evaluations: 168
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008610
#          Iterations: 43
#          Function evaluations: 91
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in multiply
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.010213
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.007725
#          Iterations: 181
#          Function evaluations: 349
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008825
#          Iterations: 157
#          Function evaluations: 304
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# Optimization terminated successfully.
#          Current function value: 0.027954
#          Iterations: 47
#          Function evaluations: 106
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.106681
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011065
#          Iterations: 39
#          Function evaluations: 87
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008391
#          Iterations: 51
#          Function evaluations: 119
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005996
#          Iterations: 158
#          Function evaluations: 299
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016554
#          Iterations: 41
#          Function evaluations: 90
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in multiply
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: divide by zero encountered in log
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.005211
#          Iterations: 32
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003722
#          Iterations: 112
#          Function evaluations: 215
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004282
#          Iterations: 116
#          Function evaluations: 216
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# Optimization terminated successfully.
#          Current function value: 0.022546
#          Iterations: 45
#          Function evaluations: 102
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.086808
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014294
#          Iterations: 38
#          Function evaluations: 83
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006322
#          Iterations: 51
#          Function evaluations: 121
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004203
#          Iterations: 73
#          Function evaluations: 153
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007123
#          Iterations: 39
#          Function evaluations: 86
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.000712
#          Iterations: 31
#          Function evaluations: 62
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.000715
#          Iterations: 159
#          Function evaluations: 296
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000715
#          Iterations: 160
#          Function evaluations: 308
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006540
#          Iterations: 43
#          Function evaluations: 100
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.116459
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002693
#          Iterations: 41
#          Function evaluations: 89
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000229
#          Iterations: 51
#          Function evaluations: 118
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000642
#          Iterations: 127
#          Function evaluations: 241
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002693
#          Iterations: 41
#          Function evaluations: 87
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.000876
#          Iterations: 30
#          Function evaluations: 60
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008610
#          Iterations: 43
#          Function evaluations: 99
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.106784
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004917
#          Iterations: 41
#          Function evaluations: 92
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000641
#          Iterations: 46
#          Function evaluations: 109
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000622
#          Iterations: 72
#          Function evaluations: 160
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002351
#          Iterations: 40
#          Function evaluations: 85
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.003077
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002662
#          Iterations: 128
#          Function evaluations: 241
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002863
#          Iterations: 132
#          Function evaluations: 242
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:360: RuntimeWarning: overflow encountered in multiply
#   A = (1 + self.theta * t)
# Optimization terminated successfully.
#          Current function value: 0.007093
#          Iterations: 59
#          Function evaluations: 118
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.180865
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002979
#          Iterations: 44
#          Function evaluations: 100
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000977
#          Iterations: 61
#          Function evaluations: 147
# Plackett is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003657
#          Iterations: 46
#          Function evaluations: 103
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in multiply
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:655: RuntimeWarning: overflow encountered in power
#   part6 = (t1 ** theta + t2 ** theta) ** (-2 + (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:662: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(part1 * part2 * part3 * part4 * part5 * part6))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:790: RuntimeWarning: overflow encountered in power
#   part6 = (t1 ** theta + t2 ** theta) ** (-2 + (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:797: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(part1 * part2 * part3 * part4 * part5 * part6))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.002879
#          Iterations: 30
#          Function evaluations: 60
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002500
#          Iterations: 114
#          Function evaluations: 219
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002663
#          Iterations: 142
#          Function evaluations: 266
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# Optimization terminated successfully.
#          Current function value: 0.002849
#          Iterations: 41
#          Function evaluations: 93
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.154744
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006113
#          Iterations: 42
#          Function evaluations: 92
# Gumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:909: RuntimeWarning: invalid value encountered in log
#   part2 = 2 * self.theta * np.log(self.theta) / (self.theta - 1) ** 2
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:848: RuntimeWarning: invalid value encountered in sqrt
#   part3 = (part2 ** 2 - 4 * eta * self.theta * u * v) ** 0.5
# Optimization terminated successfully.
#          Current function value: 0.002389
#          Iterations: 58
#          Function evaluations: 134
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002281
#          Iterations: 32
#          Function evaluations: 125
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001431
#          Iterations: 44
#          Function evaluations: 95
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.000697
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.000701
#          Iterations: 156
#          Function evaluations: 293
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000701
#          Iterations: 147
#          Function evaluations: 278
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006462
#          Iterations: 40
#          Function evaluations: 93
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.116553
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002664
#          Iterations: 42
#          Function evaluations: 91
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000229
#          Iterations: 49
#          Function evaluations: 119
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001686
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002664
#          Iterations: 39
#          Function evaluations: 86
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in multiply
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.001291
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001285
#          Iterations: 112
#          Function evaluations: 292
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008353
#          Iterations: 40
#          Function evaluations: 92
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.115042
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003560
#          Iterations: 37
#          Function evaluations: 84
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.000328
#          Iterations: 43
#          Function evaluations: 103
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001802
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003560
#          Iterations: 37
#          Function evaluations: 83
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in multiply
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.002681
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001296
#          Iterations: 113
#          Function evaluations: 217
# t_Copula is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018706
#          Iterations: 43
#          Function evaluations: 98
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.090851
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009167
#          Iterations: 39
#          Function evaluations: 87
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.002705
#          Iterations: 50
#          Function evaluations: 115
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007924
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005831
#          Iterations: 40
#          Function evaluations: 88
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.009065
#          Iterations: 31
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007079
#          Iterations: 148
#          Function evaluations: 286
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008000
#          Iterations: 121
#          Function evaluations: 225
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:360: RuntimeWarning: overflow encountered in multiply
#   A = (1 + self.theta * t)
# Optimization terminated successfully.
#          Current function value: 0.022883
#          Iterations: 60
#          Function evaluations: 120
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.121477
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006614
#          Iterations: 38
#          Function evaluations: 86
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004602
#          Iterations: 51
#          Function evaluations: 123
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004287
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015658
#          Iterations: 40
#          Function evaluations: 89
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: divide by zero encountered in log
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.006230
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005592
#          Iterations: 108
#          Function evaluations: 205
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005818
#          Iterations: 115
#          Function evaluations: 219
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# Optimization terminated successfully.
#          Current function value: 0.030081
#          Iterations: 44
#          Function evaluations: 102
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.069877
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010306
#          Iterations: 39
#          Function evaluations: 91
# Gumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:909: RuntimeWarning: invalid value encountered in log
#   part2 = 2 * self.theta * np.log(self.theta) / (self.theta - 1) ** 2
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:848: RuntimeWarning: invalid value encountered in sqrt
#   part3 = (part2 ** 2 - 4 * eta * self.theta * u * v) ** 0.5
# Optimization terminated successfully.
#          Current function value: 0.004954
#          Iterations: 51
#          Function evaluations: 114
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015346
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013872
#          Iterations: 44
#          Function evaluations: 95
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: divide by zero encountered in log
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.012255
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010477
#          Iterations: 96
#          Function evaluations: 182
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011254
#          Iterations: 98
#          Function evaluations: 192
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:360: RuntimeWarning: overflow encountered in multiply
#   A = (1 + self.theta * t)
# Optimization terminated successfully.
#          Current function value: 0.037629
#          Iterations: 63
#          Function evaluations: 126
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.083377
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006441
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010176
#          Iterations: 49
#          Function evaluations: 119
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.013828
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025250
#          Iterations: 41
#          Function evaluations: 92
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in multiply
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: divide by zero encountered in log
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.012183
#          Iterations: 30
#          Function evaluations: 60
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010496
#          Iterations: 125
#          Function evaluations: 229
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011192
#          Iterations: 156
#          Function evaluations: 308
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# Optimization terminated successfully.
#          Current function value: 0.039746
#          Iterations: 42
#          Function evaluations: 99
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.076903
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
# Optimization terminated successfully.
#          Current function value: 0.008320
#          Iterations: 36
#          Function evaluations: 81
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011828
#          Iterations: 47
#          Function evaluations: 111
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017087
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024945
#          Iterations: 38
#          Function evaluations: 86
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: divide by zero encountered in log
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.004603
#          Iterations: 33
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003864
#          Iterations: 99
#          Function evaluations: 193
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004194
#          Iterations: 98
#          Function evaluations: 195
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:360: RuntimeWarning: overflow encountered in multiply
#   A = (1 + self.theta * t)
# Optimization terminated successfully.
#          Current function value: 0.009455
#          Iterations: 57
#          Function evaluations: 114
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.161717
#          Iterations: 36
#          Function evaluations: 73
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004757
#          Iterations: 43
#          Function evaluations: 96
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003979
#          Iterations: 56
#          Function evaluations: 133
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.004056
#          Iterations: 34
#          Function evaluations: 132
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005963
#          Iterations: 44
#          Function evaluations: 100
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:397: RuntimeWarning: overflow encountered in power
#   part1 = (1 + theta) * (u * v) ** (-1 - theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:398: RuntimeWarning: overflow encountered in power
#   part2 = (-1 + u ** (-theta) + v ** (-theta)) ** (-2 - (1 / theta))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: invalid value encountered in multiply
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:399: RuntimeWarning: divide by zero encountered in log
#   l = np.log(part1 * part2)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.001449
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001219
#          Iterations: 109
#          Function evaluations: 206
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.001310
#          Iterations: 123
#          Function evaluations: 227
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:356: RuntimeWarning: overflow encountered in power
#   B = t ** (-self.theta) - 1
# Optimization terminated successfully.
#          Current function value: 0.008734
#          Iterations: 43
#          Function evaluations: 99
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# ...
#          Current function value: 0.002973
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000023
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.005590
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017947
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009318
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.011168
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.004939
#          Iterations: 11
#          Function evaluations: 22
# Gaussian {'rho': 0.9975934324000001}
# t_Copula {'rho': 0.9960923330000001, 'nu': 2.0}
# t_Copula_Capped {'rho': 0.9968553713, 'nu': 4.0}
# Clayton {'theta': 236.6999120624}
# Frank {'theta': 38.2435110122}
# Gumbel {'theta': 24.0989913459}
# Plackett {'theta': 6123.0913005778}
# Gauss Mix Indep {'rho': 0.999, 'p': 0.999}
# rotGumbel {'theta': 32.3302020977}
# Optimization terminated successfully.
#          Current function value: 0.000018
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.005858
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015892
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.009277
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.011207
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.005450
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000026
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.006748
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.020727
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.010998
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.013068
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.006239
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000020
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.006228
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.017257
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.009909
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.011903
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.005932
#          Iterations: 11
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in multiply
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000454
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.002852
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.014744
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.005019
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.003576
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.000924
#          Iterations: 11
#          Function evaluations: 22
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000737
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.047234
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.146019
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.083175
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.102084
#          Iterations: 16
#          Function evaluations: 33
# Optimization terminated successfully.
#          Current function value: 0.058096
#          Iterations: 10
#          Function evaluations: 20
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000026
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.006311
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.019848
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.010212
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.011458
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.005054
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000041
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.006696
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.030687
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.012368
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.014655
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.004558
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.004104
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.012662
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.006670
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.007660
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.003562
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000012
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.004459
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.012591
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.007412
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009173
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.004261
#          Iterations: 11
#          Function evaluations: 22
# Gaussian {'rho': 0.9970550874}
# t_Copula {'rho': 0.997023163, 'nu': 87.2651321009}
# t_Copula_Capped {'rho': 0.9970231066, 'nu': 87.265132102}
# Clayton {'theta': 170.3289028303}
# Frank {'theta': 38.2435110122}
# Gumbel {'theta': 23.6707414295}
# Plackett {'theta': 3770.266040505}
# Gauss Mix Indep {'rho': 0.999, 'p': 0.999}
# rotGumbel {'theta': 25.8575082209}
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.005926
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015429
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009225
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.011172
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.005724
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.005965
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015522
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009293
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.011253
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.005770
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000014
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.005965
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.015522
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.009293
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.011253
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.005770
#          Iterations: 11
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in power
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:410: RuntimeWarning: overflow encountered in multiply
#   u2 = (u1 ** (-self.theta) * (v2 ** (-self.theta / (1 + self.theta)) - 1) + 1) ** (-1 / self.theta)
# Optimization terminated successfully.
#          Current function value: 0.000039
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.004435
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.018459
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.008922
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.008825
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.002567
#          Iterations: 12
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:547: RuntimeWarning: divide by zero encountered in log
#   part1 = np.log(1 - part1a / part1b)
# Optimization terminated successfully.
#          Current function value: 0.000349
#          Iterations: 14
#          Function evaluations: 28
# ^C
# Traceback (most recent call last):
#   File "get_OHR.py", line 96, in <module>
#     best_h.append(optimize_h(Copulae[C_name], k_arr, q_arr_ES, q_arr_VaR))
#   File "/Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py", line 354, in optimize_h
#     best_h.append(scipy.optimize.fmin(fn, 1)[0])
#   File "/Users/francis/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 416, in fmin
#     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#   File "/Users/francis/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 606, in _minimize_neldermead
#     fxcc = func(xcc)
#   File "/Users/francis/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py", line 353, in <lambda>
#     fn = lambda h: wrapper(rs, rf, h, partial(ERM_estimate_trapezoidal, k))
#   File "/Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py", line 339, in wrapper
#     return risk_measure(rh)
#   File "/Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py", line 325, in ERM_estimate_trapezoidal
#     return -np.sum((toint[:-1] + toint[1:]) * d) / 2
#   File "<__array_function__ internals>", line 6, in sum
#   File "/Users/francis/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2248, in sum
#     initial=initial, where=where)
#   File "/Users/francis/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 87, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !python calibration.py --config configs/BBT_future_Tiingo_ada_MM.json
# !python get_OHR.py --config configs/BBT_future_Tiingo_ada_MM.json
# !python get_HEs.py --config configs/BBT_future_Tiingo_ada_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.024977
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016594
#          Iterations: 175
#          Function evaluations: 335
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.019468
#          Iterations: 173
#          Function evaluations: 325
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.294243
#          Iterations: 49
#          Function evaluations: 109
# Clayton is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:486: RuntimeWarning: divide by zero encountered in log
#   return A * np.log(B)
# Optimization terminated successfully.
#          Current function value: 0.078255
#          Iterations: 58
#          Function evaluations: 127
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045720
#          Iterations: 36
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.028547
#          Iterations: 49
#          Function evaluations: 111
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012494
#          Iterations: 79
#          Function evaluations: 162
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.101370
#          Iterations: 36
#          Function evaluations: 79
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.048469
#          Iterations: 33
#          Function evaluations: 70
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047359
#          Iterations: 90
#          Function evaluations: 195
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047359
#          Iterations: 81
#          Function evaluations: 174
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.179814
#          Iterations: 43
#          Function evaluations: 93
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.092776
#          Iterations: 41
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.208695
#          Iterations: 37
#          Function evaluations: 79
# Gumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:909: RuntimeWarning: invalid value encountered in log
#   part2 = 2 * self.theta * np.log(self.theta) / (self.theta - 1) ** 2
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:848: RuntimeWarning: invalid value encountered in sqrt
#   part3 = (part2 ** 2 - 4 * eta * self.theta * u * v) ** 0.5
# Optimization terminated successfully.
#          Current function value: 0.053633
#          Iterations: 44
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.044045
#          Iterations: 71
#          Function evaluations: 148
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.028032
#          Iterations: 37
#          Function evaluations: 80
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.133220
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.115114
#          Iterations: 135
#          Function evaluations: 261
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.122097
#          Iterations: 136
#          Function evaluations: 257
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.116720
#          Iterations: 38
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.212175
#          Iterations: 42
#          Function evaluations: 97
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.347282
#          Iterations: 36
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.150898
#          Iterations: 42
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.105670
#          Iterations: 78
#          Function evaluations: 161
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034189
#          Iterations: 34
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.052176
#          Iterations: 34
#          Function evaluations: 72
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.048490
#          Iterations: 105
#          Function evaluations: 219
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.048490
#          Iterations: 80
#          Function evaluations: 171
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.075526
#          Iterations: 39
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.108067
#          Iterations: 40
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.235159
#          Iterations: 39
#          Function evaluations: 84
# Gumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:909: RuntimeWarning: invalid value encountered in log
#   part2 = 2 * self.theta * np.log(self.theta) / (self.theta - 1) ** 2
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:848: RuntimeWarning: invalid value encountered in sqrt
#   part3 = (part2 ** 2 - 4 * eta * self.theta * u * v) ** 0.5
# Optimization terminated successfully.
#          Current function value: 0.075213
#          Iterations: 44
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049140
#          Iterations: 66
#          Function evaluations: 138
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007234
#          Iterations: 36
#          Function evaluations: 77
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.124965
#          Iterations: 32
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.104217
#          Iterations: 102
#          Function evaluations: 200
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.111716
#          Iterations: 115
#          Function evaluations: 222
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.107847
#          Iterations: 39
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.217753
#          Iterations: 40
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.348741
#          Iterations: 37
#          Function evaluations: 82
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.150064
#          Iterations: 46
#          Function evaluations: 105
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.100013
#          Iterations: 73
#          Function evaluations: 153
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024001
#          Iterations: 35
#          Function evaluations: 74
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.122340
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.120546
#          Iterations: 84
#          Function evaluations: 184
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.120546
#          Iterations: 86
#          Function evaluations: 185
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.072236
#          Iterations: 38
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.172106
#          Iterations: 40
#          Function evaluations: 88
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.372975
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.130072
#          Iterations: 42
#          Function evaluations: 95
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.117559
#          Iterations: 72
#          Function evaluations: 146
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017344
#          Iterations: 34
#          Function evaluations: 72
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.183438
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.182153
#          Iterations: 73
#          Function evaluations: 161
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.182153
#          Iterations: 76
#          Function evaluations: 165
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.052183
#          Iterations: 34
#          Function evaluations: 74
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.231063
#          Iterations: 37
#          Function evaluations: 86
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.475611
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.189759
#          Iterations: 35
#          Function evaluations: 80
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.179490
#          Iterations: 63
#          Function evaluations: 135
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.037179
#          Iterations: 32
#          Function evaluations: 69
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.059357
#          Iterations: 33
#          Function evaluations: 70
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055847
#          Iterations: 80
#          Function evaluations: 174
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055847
#          Iterations: 81
#          Function evaluations: 175
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.072795
#          Iterations: 38
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.115130
#          Iterations: 42
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.251339
#          Iterations: 36
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.081184
#          Iterations: 40
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.056225
#          Iterations: 71
#          Function evaluations: 149
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007126
#          Iterations: 36
#          Function evaluations: 76
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.123949
#          Iterations: 33
#          Function evaluations: 72
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.103834
#          Iterations: 134
#          Function evaluations: 263
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.111034
#          Iterations: 144
#          Function evaluations: 282
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.106659
#          Iterations: 39
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.215651
#          Iterations: 43
#          Function evaluations: 100
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.347602
#          Iterations: 37
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.149093
#          Iterations: 43
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.100011
#          Iterations: 74
#          Function evaluations: 155
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.023147
#          Iterations: 37
#          Function evaluations: 78
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.133740
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.115369
#          Iterations: 127
#          Function evaluations: 243
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.122478
#          Iterations: 143
#          Function evaluations: 279
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.117440
#          Iterations: 39
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.213177
#          Iterations: 41
#          Function evaluations: 95
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.347891
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.152407
#          Iterations: 39
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.105729
#          Iterations: 60
#          Function evaluations: 126
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034643
#          Iterations: 32
#          Function evaluations: 70
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.052805
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042635
#          Iterations: 104
#          Function evaluations: 199
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045100
#          Iterations: 123
#          Function evaluations: 239
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.156788
#          Iterations: 37
#          Function evaluations: 80
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.125378
#          Iterations: 41
#          Function evaluations: 97
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.221828
#          Iterations: 34
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.069924
#          Iterations: 39
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040833
#          Iterations: 67
#          Function evaluations: 140
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014574
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.017808
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012415
#          Iterations: 181
#          Function evaluations: 354
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.274576
#          Iterations: 42
#          Function evaluations: 92
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.067698
#          Iterations: 44
#          Function evaluations: 94
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.066186
#          Iterations: 35
#          Function evaluations: 74
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.021992
#          Iterations: 42
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009024
#          Iterations: 71
#          Function evaluations: 148
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076508
#          Iterations: 38
#          Function evaluations: 82
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.063178
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.052390
#          Iterations: 170
#          Function evaluations: 331
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055337
#          Iterations: 117
#          Function evaluations: 223
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.152293
#          Iterations: 42
#          Function evaluations: 93
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.134660
#          Iterations: 40
#          Function evaluations: 94
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.237854
#          Iterations: 37
#          Function evaluations: 81
# Gumbel is done.
# Optimization terminated successfully.
#          Current function value: 0.079839
#          Iterations: 44
#          Function evaluations: 97
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049524
#          Iterations: 74
#          Function evaluations: 148
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017518
#          Iterations: 36
#          Function evaluations: 77
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.022937
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022249
#          Iterations: 103
#          Function evaluations: 217
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022249
#          Iterations: 96
#          Function evaluations: 211
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.229952
#          Iterations: 41
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060776
#          Iterations: 42
#          Function evaluations: 96
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.123518
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024113
#          Iterations: 40
#          Function evaluations: 93
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.019350
#          Iterations: 69
#          Function evaluations: 147
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.045144
#          Iterations: 35
#          Function evaluations: 78
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.146548
#          Iterations: 33
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.141262
#          Iterations: 81
#          Function evaluations: 174
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.141689
#          Iterations: 190
#          Function evaluations: 370
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.076507
#          Iterations: 40
#          Function evaluations: 89
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.206492
#          Iterations: 40
#          Function evaluations: 90
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.405395
#          Iterations: 35
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.157988
#          Iterations: 42
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.137246
#          Iterations: 82
#          Function evaluations: 169
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027198
#          Iterations: 36
#          Function evaluations: 76
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.095005
#          Iterations: 30
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.079753
#          Iterations: 126
#          Function evaluations: 246
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.084613
#          Iterations: 107
#          Function evaluations: 207
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.115771
#          Iterations: 34
#          Function evaluations: 77
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.176279
#          Iterations: 37
#          Function evaluations: 84
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.304216
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.117579
#          Iterations: 38
#          Function evaluations: 87
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076671
#          Iterations: 70
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015046
#          Iterations: 33
#          Function evaluations: 70
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.043788
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040294
#          Iterations: 97
#          Function evaluations: 201
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040294
#          Iterations: 76
#          Function evaluations: 167
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.084834
#          Iterations: 38
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.099516
#          Iterations: 40
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.220635
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065951
#          Iterations: 43
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.040658
#          Iterations: 72
#          Function evaluations: 152
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.006827
#          Iterations: 36
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.087487
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.071730
#          Iterations: 140
#          Function evaluations: 273
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076629
#          Iterations: 143
#          Function evaluations: 274
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.122800
#          Iterations: 39
#          Function evaluations: 84
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.171527
#          Iterations: 41
#          Function evaluations: 96
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.291027
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.111400
#          Iterations: 42
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.069678
#          Iterations: 75
#          Function evaluations: 153
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014634
#          Iterations: 35
#          Function evaluations: 74
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.062201
#          Iterations: 33
#          Function evaluations: 71
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055577
#          Iterations: 89
#          Function evaluations: 194
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055733
#          Iterations: 139
#          Function evaluations: 262
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.081455
#          Iterations: 38
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.129035
#          Iterations: 40
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.261545
#          Iterations: 37
#          Function evaluations: 82
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.087892
#          Iterations: 41
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.055898
#          Iterations: 69
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003476
#          Iterations: 35
#          Function evaluations: 73
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.149389
#          Iterations: 31
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.144427
#          Iterations: 74
#          Function evaluations: 159
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.144692
#          Iterations: 89
#          Function evaluations: 176
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.061683
#          Iterations: 37
#          Function evaluations: 80
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.210049
#          Iterations: 39
#          Function evaluations: 88
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.416920
#          Iterations: 35
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.161511
#          Iterations: 40
#          Function evaluations: 90
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.141352
#          Iterations: 69
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022416
#          Iterations: 33
#          Function evaluations: 69
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.019173
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012519
#          Iterations: 133
#          Function evaluations: 254
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014256
#          Iterations: 116
#          Function evaluations: 216
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.209682
#          Iterations: 43
#          Function evaluations: 96
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.074540
#          Iterations: 43
#          Function evaluations: 96
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.110957
#          Iterations: 38
#          Function evaluations: 83
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025705
#          Iterations: 44
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009764
#          Iterations: 66
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036683
#          Iterations: 38
#          Function evaluations: 82
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.058140
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.048054
#          Iterations: 145
#          Function evaluations: 283
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050856
#          Iterations: 124
#          Function evaluations: 239
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.163524
#          Iterations: 42
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.126105
#          Iterations: 41
#          Function evaluations: 99
# Frank is done.
# Optimization terminated successfully.
#          Current function value: 0.224082
#          Iterations: 37
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.072154
#          Iterations: 42
#          Function evaluations: 96
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.044296
#          Iterations: 73
#          Function evaluations: 154
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.019842
#          Iterations: 37
#          Function evaluations: 80
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.030637
#          Iterations: 32
#          Function evaluations: 68
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030276
#          Iterations: 102
#          Function evaluations: 215
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030276
#          Iterations: 99
#          Function evaluations: 209
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.191237
#          Iterations: 37
#          Function evaluations: 82
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.072804
#          Iterations: 39
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.178400
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.036527
#          Iterations: 39
#          Function evaluations: 89
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029173
#          Iterations: 72
#          Function evaluations: 149
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026095
#          Iterations: 35
#          Function evaluations: 77
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.015048
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014218
#          Iterations: 88
#          Function evaluations: 190
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014218
#          Iterations: 90
#          Function evaluations: 194
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.231842
#          Iterations: 40
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.057609
#          Iterations: 40
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.118530
#          Iterations: 36
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.018977
#          Iterations: 41
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012530
#          Iterations: 65
#          Function evaluations: 138
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038634
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.140910
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.130800
#          Iterations: 159
#          Function evaluations: 301
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.133589
#          Iterations: 136
#          Function evaluations: 253
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.086228
#          Iterations: 39
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.207495
#          Iterations: 39
#          Function evaluations: 93
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.385939
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.153605
#          Iterations: 39
#          Function evaluations: 89
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.125292
#          Iterations: 77
#          Function evaluations: 152
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.026940
#          Iterations: 34
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.061019
#          Iterations: 33
#          Function evaluations: 72
# Gaussian is done.
#
# ...
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.056971
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.001720
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.063753
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.161128
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.098201
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.116166
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.061803
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.001429
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.059437
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.139023
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.089578
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.106716
#          Iterations: 10
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.060240
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.001464
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.051918
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.105671
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.074951
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.085571
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.050597
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.001216
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.055656
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.153904
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.092967
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.119023
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.052890
#          Iterations: 11
#          Function evaluations: 24
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.001197
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.057052
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.135974
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.087694
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.105217
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.056383
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.001420
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.059897
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.160053
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.097193
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.121925
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.058120
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.002108
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.071848
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.181452
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.114694
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.139876
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.069435
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.001378
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.054877
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.112961
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.079282
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.093056
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.056762
#          Iterations: 11
#          Function evaluations: 25
# Gaussian {'rho': 0.8608948981000001}
# t_Copula {'rho': 0.7880880526, 'nu': 2.0}
# t_Copula_Capped {'rho': 0.8243632869, 'nu': 4.0}
# Clayton {'theta': 5.1326845212}
# Frank {'theta': 19.343530255}
# Gumbel {'theta': 3.1623754487}
# Plackett {'theta': 51.2862056677}
# Gauss Mix Indep {'rho': 0.9890601318000001, 'p': 0.6905491303}
# rotGumbel {'theta': 2.7894053837}
# Optimization terminated successfully.
#          Current function value: 0.001182
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.057129
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.122151
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.084664
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.101553
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.058791
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.001630
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.064307
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.161232
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.099008
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.117344
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.062323
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.001357
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.060281
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.138977
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.090713
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.108234
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.061121
#          Iterations: 10
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.001353
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.051770
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.104462
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.074797
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.084896
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.048880
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.001201
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.057443
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.151609
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.095283
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.120335
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.055928
#          Iterations: 11
#          Function evaluations: 24
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.001148
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.058061
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.135563
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.089229
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.107603
#          Iterations: 15
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.057711
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.001375
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.061023
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.158352
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.098446
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.122731
#          Iterations: 11
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.059752
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.002159
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.074773
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.185908
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.118825
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.148417
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.070778
#          Iterations: 13
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.001304
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.055743
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.113896
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.080593
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.095119
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.057501
#          Iterations: 12
#          Function evaluations: 25
# get_OHR.py:115: FutureWarning: inplace is deprecated and will be removed in a future version.
#   display_best_h.columns.set_levels(date_range_arr, level=0, inplace=True)
# Done! Please find the OHR in ../results/BBT_future_Tiingo_ada/MM/
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Done! Please find the hedging effectiveness in ../results/BBT_future_Tiingo_ada/MM/

# %%
# !python calibration.py --config configs/BBT_future_Tiingo_eth_MM.json
# !python get_OHR.py --config configs/BBT_future_Tiingo_eth_MM.json
# !python get_HEs.py --config configs/BBT_future_Tiingo_eth_MM.json
# Out:
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.012301
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.012440
#          Iterations: 185
#          Function evaluations: 348
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012440
#          Iterations: 166
#          Function evaluations: 308
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.291680
#          Iterations: 49
#          Function evaluations: 106
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030772
#          Iterations: 54
#          Function evaluations: 118
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.061083
#          Iterations: 33
#          Function evaluations: 71
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008038
#          Iterations: 47
#          Function evaluations: 105
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012822
#          Iterations: 75
#          Function evaluations: 156
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.084922
#          Iterations: 35
#          Function evaluations: 76
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.030728
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.162549
#          Iterations: 40
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.067226
#          Iterations: 39
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.171614
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.032119
#          Iterations: 40
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029780
#          Iterations: 72
#          Function evaluations: 146
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015722
#          Iterations: 35
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.043782
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042712
#          Iterations: 97
#          Function evaluations: 206
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042712
#          Iterations: 89
#          Function evaluations: 193
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.140325
#          Iterations: 36
#          Function evaluations: 81
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.086099
#          Iterations: 41
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.188906
#          Iterations: 34
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047057
#          Iterations: 39
#          Function evaluations: 91
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.041145
#          Iterations: 68
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014620
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.022981
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022909
#          Iterations: 97
#          Function evaluations: 213
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022909
#          Iterations: 101
#          Function evaluations: 220
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.175368
#          Iterations: 40
#          Function evaluations: 86
# Clayton is done.
# Optimization terminated successfully.
#          Current function value: 0.065703
#          Iterations: 40
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.172111
#          Iterations: 35
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030067
#          Iterations: 41
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022910
#          Iterations: 69
#          Function evaluations: 153
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017049
#          Iterations: 36
#          Function evaluations: 78
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.052275
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051634
#          Iterations: 99
#          Function evaluations: 214
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.051634
#          Iterations: 101
#          Function evaluations: 216
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.109765
#          Iterations: 40
#          Function evaluations: 85
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.094228
#          Iterations: 45
#          Function evaluations: 103
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.218349
#          Iterations: 38
#          Function evaluations: 84
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.056250
#          Iterations: 42
#          Function evaluations: 96
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.050879
#          Iterations: 67
#          Function evaluations: 145
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.003128
#          Iterations: 36
#          Function evaluations: 77
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.129823
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.126867
#          Iterations: 84
#          Function evaluations: 179
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.127079
#          Iterations: 129
#          Function evaluations: 247
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.063876
#          Iterations: 34
#          Function evaluations: 75
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.176919
#          Iterations: 43
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.334633
#          Iterations: 35
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.132610
#          Iterations: 40
#          Function evaluations: 89
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.124829
#          Iterations: 67
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024022
#          Iterations: 34
#          Function evaluations: 71
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.126222
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.124200
#          Iterations: 78
#          Function evaluations: 171
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.124252
#          Iterations: 112
#          Function evaluations: 219
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.069080
#          Iterations: 34
#          Function evaluations: 76
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.167879
#          Iterations: 44
#          Function evaluations: 97
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.320963
#          Iterations: 33
#          Function evaluations: 70
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.126589
#          Iterations: 37
#          Function evaluations: 86
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.121665
#          Iterations: 67
#          Function evaluations: 143
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.027765
#          Iterations: 33
#          Function evaluations: 71
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.029938
#          Iterations: 32
#          Function evaluations: 66
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029851
#          Iterations: 112
#          Function evaluations: 234
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029851
#          Iterations: 111
#          Function evaluations: 232
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.164522
#          Iterations: 41
#          Function evaluations: 89
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.073863
#          Iterations: 43
#          Function evaluations: 100
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.187516
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.038377
#          Iterations: 43
#          Function evaluations: 96
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029798
#          Iterations: 73
#          Function evaluations: 156
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.016836
#          Iterations: 37
#          Function evaluations: 80
# rotGumbel is done.
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.049863
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049083
#          Iterations: 100
#          Function evaluations: 204
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049083
#          Iterations: 100
#          Function evaluations: 205
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.118774
#          Iterations: 40
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.090643
#          Iterations: 44
#          Function evaluations: 100
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.207438
#          Iterations: 36
#          Function evaluations: 78
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.052409
#          Iterations: 41
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047690
#          Iterations: 76
#          Function evaluations: 153
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007273
#          Iterations: 35
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.044280
#          Iterations: 31
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042947
#          Iterations: 76
#          Function evaluations: 168
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.042947
#          Iterations: 77
#          Function evaluations: 168
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.141948
#          Iterations: 35
#          Function evaluations: 79
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.087815
#          Iterations: 39
#          Function evaluations: 88
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.189603
#          Iterations: 34
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047845
#          Iterations: 36
#          Function evaluations: 84
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.041214
#          Iterations: 65
#          Function evaluations: 139
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015055
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.031172
#          Iterations: 30
#          Function evaluations: 65
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.031100
#          Iterations: 115
#          Function evaluations: 239
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.031100
#          Iterations: 102
#          Function evaluations: 221
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.172742
#          Iterations: 35
#          Function evaluations: 77
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065275
#          Iterations: 38
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.163541
#          Iterations: 35
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030936
#          Iterations: 38
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029900
#          Iterations: 69
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022653
#          Iterations: 34
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.010718
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.010840
#          Iterations: 129
#          Function evaluations: 249
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.010840
#          Iterations: 136
#          Function evaluations: 253
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.288062
#          Iterations: 39
#          Function evaluations: 88
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.032350
#          Iterations: 38
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.067325
#          Iterations: 33
#          Function evaluations: 72
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.008005
#          Iterations: 37
#          Function evaluations: 86
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.011161
#          Iterations: 65
#          Function evaluations: 136
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.078064
#          Iterations: 32
#          Function evaluations: 70
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.025223
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.173762
#          Iterations: 39
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.062898
#          Iterations: 39
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.161013
#          Iterations: 35
#          Function evaluations: 77
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.028199
#          Iterations: 39
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.024759
#          Iterations: 74
#          Function evaluations: 153
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017677
#          Iterations: 35
#          Function evaluations: 76
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.011922
#          Iterations: 30
#          Function evaluations: 63
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.012179
#          Iterations: 127
#          Function evaluations: 243
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012179
#          Iterations: 135
#          Function evaluations: 251
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.286950
#          Iterations: 40
#          Function evaluations: 91
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022785
#          Iterations: 38
#          Function evaluations: 89
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.077389
#          Iterations: 34
#          Function evaluations: 75
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.005004
#          Iterations: 36
#          Function evaluations: 82
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.012233
#          Iterations: 149
#          Function evaluations: 279
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.077389
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.101470
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.101062
#          Iterations: 101
#          Function evaluations: 214
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.101062
#          Iterations: 104
#          Function evaluations: 224
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.073888
#          Iterations: 40
#          Function evaluations: 90
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.137712
#          Iterations: 41
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.297187
#          Iterations: 36
#          Function evaluations: 81
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.101909
#          Iterations: 42
#          Function evaluations: 94
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.099438
#          Iterations: 67
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014448
#          Iterations: 33
#          Function evaluations: 71
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.063934
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060021
#          Iterations: 91
#          Function evaluations: 196
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.060449
#          Iterations: 110
#          Function evaluations: 212
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.119017
#          Iterations: 37
#          Function evaluations: 81
# Clayton is done.
# Optimization terminated successfully.
#          Current function value: 0.116218
#          Iterations: 38
#          Function evaluations: 86
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.220745
#          Iterations: 35
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.069849
#          Iterations: 36
#          Function evaluations: 82
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.058595
#          Iterations: 64
#          Function evaluations: 137
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014894
#          Iterations: 34
#          Function evaluations: 75
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.022979
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022916
#          Iterations: 111
#          Function evaluations: 244
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022916
#          Iterations: 102
#          Function evaluations: 228
# t_Copula_Capped is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:362: RuntimeWarning: invalid value encountered in power
#   return A ** B
# Optimization terminated successfully.
#          Current function value: 0.175355
#          Iterations: 40
#          Function evaluations: 87
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065492
#          Iterations: 39
#          Function evaluations: 91
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.172109
#          Iterations: 36
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030016
#          Iterations: 44
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.022912
#          Iterations: 67
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.017068
#          Iterations: 37
#          Function evaluations: 81
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.050258
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049285
#          Iterations: 103
#          Function evaluations: 218
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.049285
#          Iterations: 93
#          Function evaluations: 198
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.120067
#          Iterations: 40
#          Function evaluations: 86
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.092088
#          Iterations: 42
#          Function evaluations: 95
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.208030
#          Iterations: 36
#          Function evaluations: 79
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.053122
#          Iterations: 44
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.047757
#          Iterations: 69
#          Function evaluations: 144
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007600
#          Iterations: 35
#          Function evaluations: 79
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.030626
#          Iterations: 32
#          Function evaluations: 67
# Gaussian is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029001
#          Iterations: 73
#          Function evaluations: 168
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029001
#          Iterations: 74
#          Function evaluations: 161
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.160977
#          Iterations: 41
#          Function evaluations: 90
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.085438
#          Iterations: 39
#          Function evaluations: 92
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.187273
#          Iterations: 35
#          Function evaluations: 76
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.041703
#          Iterations: 41
#          Function evaluations: 92
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029280
#          Iterations: 69
#          Function evaluations: 147
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.009475
#          Iterations: 34
#          Function evaluations: 73
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.132796
#          Iterations: 30
#          Function evaluations: 62
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.132869
#          Iterations: 135
#          Function evaluations: 256
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.132869
#          Iterations: 135
#          Function evaluations: 257
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.076197
#          Iterations: 40
#          Function evaluations: 85
# Clayton is done.
# Optimization terminated successfully.
#          Current function value: 0.154801
#          Iterations: 42
#          Function evaluations: 95
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.343933
#          Iterations: 37
#          Function evaluations: 83
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.127935
#          Iterations: 42
#          Function evaluations: 98
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.132482
#          Iterations: 66
#          Function evaluations: 142
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.034133
#          Iterations: 34
#          Function evaluations: 74
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.014144
#          Iterations: 30
#          Function evaluations: 61
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula is done.
#
# Warning: Maximum number of function evaluations has been exceeded.
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.265334
#          Iterations: 37
#          Function evaluations: 83
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.025545
#          Iterations: 42
#          Function evaluations: 93
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.093286
#          Iterations: 36
#          Function evaluations: 80
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.007340
#          Iterations: 39
#          Function evaluations: 88
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.014500
#          Iterations: 113
#          Function evaluations: 219
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.065926
#          Iterations: 34
#          Function evaluations: 72
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.030636
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: overflow encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   fn = lambda s: s ** (self.nu - 1) * np.exp(-s ** 2 / 2) * self.MN.cdf(s * b / np.sqrt(self.nu))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:56: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return 2 ** (1 - (self.nu / 2)) / gamma(self.nu / 2) * scipy.integrate.quad(fn, 0, np.inf)[0]
# Optimization terminated successfully.
#          Current function value: 0.030545
#          Iterations: 123
#          Function evaluations: 267
# t_Copula is done.
#
# Optimization terminated successfully.
#          Current function value: 0.030545
#          Iterations: 118
#          Function evaluations: 270
# t_Copula_Capped is done.
#
# Optimization terminated successfully.
#          Current function value: 0.162188
#          Iterations: 37
#          Function evaluations: 84
# Clayton is done.
#
# Optimization terminated successfully.
#          Current function value: 0.066810
#          Iterations: 36
#          Function evaluations: 83
# Frank is done.
#
# Optimization terminated successfully.
#          Current function value: 0.171486
#          Iterations: 33
#          Function evaluations: 73
# Gumbel is done.
#
# Optimization terminated successfully.
#          Current function value: 0.032051
#          Iterations: 36
#          Function evaluations: 85
# Plackett is done.
#
# Optimization terminated successfully.
#          Current function value: 0.029771
#          Iterations: 69
#          Function evaluations: 141
# Gauss Mix Indep is done.
#
# Optimization terminated successfully.
#          Current function value: 0.015646
#          Iterations: 33
#          Function evaluations: 73
# rotGumbel is done.
#
# /Users/francis/Google Drive/00_IRTG1792/copula/src/copulae1.py:167: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   m_hat = np.array([self.tau()] + [self._lambda(q) for q in q_arr])
# Optimization terminated successfully.
#          Current function value: 0.018183
#          Iterations: 31
#          Function evaluations: 64
# Gaussian is done.
#
# ...
#          Iterations: 13
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.047669
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000988
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.046619
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.104841
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.069716
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.082362
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.048465
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.000988
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.046619
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.104841
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.069716
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.082362
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.048465
#          Iterations: 12
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.001086
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.039052
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.081850
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.057064
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.065070
#          Iterations: 15
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.035891
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.001049
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.046569
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.133294
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.078191
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.101028
#          Iterations: 14
#          Function evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.044971
#          Iterations: 12
#          Function evaluations: 25
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000925
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.047767
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.115946
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.073910
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.088597
#          Iterations: 11
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.048093
#          Iterations: 10
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.001184
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.050066
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.136852
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.081786
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.103257
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.048899
#          Iterations: 14
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.001143
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.049512
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.127603
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.077378
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.094220
#          Iterations: 13
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.048556
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.001092
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.044297
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.092431
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.064481
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.075014
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.046168
#          Iterations: 13
#          Function evaluations: 29
# Gaussian {'rho': 0.8861720689}
# t_Copula {'rho': 0.8601907122, 'nu': 4.4176273958}
# t_Copula_Capped {'rho': 0.8601907203, 'nu': 4.41762756}
# Clayton {'theta': 9.9716297066}
# Frank {'theta': 22.4515292425}
# Gumbel {'theta': 3.5237376498}
# Plackett {'theta': 65.6789979088}
# Gauss Mix Indep {'rho': 0.9470347973000001, 'p': 0.8537223032}
# rotGumbel {'theta': 3.2006207109}
# Optimization terminated successfully.
#          Current function value: 0.000856
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.046753
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.099279
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.069623
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.082173
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.049498
#          Iterations: 10
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000947
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.048865
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.111314
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.073723
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.087337
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.050566
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000947
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.048865
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.111314
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.073723
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.087337
#          Iterations: 11
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.050566
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.000903
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.038035
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.080020
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.055410
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.061025
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.032119
#          Iterations: 12
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.000972
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.047664
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.129602
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.079814
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.101754
#          Iterations: 12
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.047494
#          Iterations: 11
#          Function evaluations: 23
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:294: RuntimeWarning: invalid value encountered in power
#   part2 = np.sin(self.alpha * (U + xi)) / (np.cos(U) ** (1 / self.alpha))
# /Users/francis/Google Drive/00_IRTG1792/copula/src/toolbox.py:295: RuntimeWarning: invalid value encountered in power
#   part3 = (np.cos(U - self.alpha * (U + xi)) / W) ** ((1 - self.alpha) / self.alpha)
# Optimization terminated successfully.
#          Current function value: 0.000789
#          Iterations: 10
#          Function evaluations: 20
# Optimization terminated successfully.
#          Current function value: 0.046465
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.109932
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.071673
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.086450
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.047034
#          Iterations: 12
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.001074
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.050503
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.134028
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.082190
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.102818
#          Iterations: 13
#          Function evaluations: 31
# Optimization terminated successfully.
#          Current function value: 0.049742
#          Iterations: 11
#          Function evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.001245
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.054095
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.142971
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.087923
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.106918
#          Iterations: 15
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.049579
#          Iterations: 10
#          Function evaluations: 23
# Optimization terminated successfully.
#          Current function value: 0.000971
#          Iterations: 11
#          Function evaluations: 22
# Optimization terminated successfully.
#          Current function value: 0.045161
#          Iterations: 12
#          Function evaluations: 24
# Optimization terminated successfully.
#          Current function value: 0.091458
#          Iterations: 14
#          Function evaluations: 28
# Optimization terminated successfully.
#          Current function value: 0.065573
#          Iterations: 13
#          Function evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.075681
#          Iterations: 13
#          Function evaluations: 27
# Optimization terminated successfully.
#          Current function value: 0.046920
#          Iterations: 11
#          Function evaluations: 23
# get_OHR.py:115: FutureWarning: inplace is deprecated and will be removed in a future version.
#   display_best_h.columns.set_levels(date_range_arr, level=0, inplace=True)
# Done! Please find the OHR in ../results/BBT_future_Tiingo_eth/MM/
# /Users/francis/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Done! Please find the hedging effectiveness in ../results/BBT_future_Tiingo_eth/MM/
